# %% [markdown]
# # The Associated Press and Life Expectancy
#
# **Story:** [AP analysis: Unemployment, income affect life expectancy](https://www.apnews.com/66ac44186b6249709501f07a7eab36da)
#
# **Author:** Nicky Forster, Associated Press
#
# **Topics:** Census Data, Linear Regression
#
# **Datasets**
#
# * **R12221544_SL140.csv:** ACS 2015 5-year, tract level, from [Social Explorer](https://www.socialexplorer.com)
#     - Table B23025: Employment Status
#     - **R12221544.txt** is the data dictionary
# * **R12221544_SL140.csv:** ACS 2015 5-year, tract level, from [Social Explorer](https://www.socialexplorer.com)
#     - Table B23025: Employment Status
#     - Table B06009: Educational Attainment
#     - Table B03002: Race
#     - Table B19013: Median income
#     - Table C17002: Ratio of income to poverty level
#     - **R12221544.txt** is the data dictionary
# * **US_A.CSV:** life expectancy by census tract, from [USALEEP](https://www.cdc.gov/nchs/nvss/usaleep/usaleep.html)
#     - **Record_Layout_CensusTract_Life_Expectancy.pdf** is data dictionary
#
# # What's the story?
#
# We're trying to figure out how the **life expectancy in a census tract** is related to other factors like unemployment, income, and others.

# %% [markdown]
# # PREPWORK BONUS!
#
# Download the data yourself from Social Explorer and USALEEP (linked above) instead of relying on the data included.

# %% [markdown]
# ## Reading in our data
#
# ### Read in `USA_A.CSV`
#
# Rename any columns with weird or not-understandable names as something more descriptive.

# %%
import pandas as pd
import requests
import matplotlib
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re
import time
import pandas as pd
import statsmodels.api as sm
from statsmodels.sandbox.regression.predstd import wls_prediction_std
sns.set(style='whitegrid',palette='husl')
matplotlib.rcParams['pdf.fonttype'] = 42

# %%
df=pd.read_csv('US_A.CSV',encoding='latin-1')

# %%
df=df.rename(columns={'e(0)':'life_expectancy','se(e(0))':'std_error'})

# %%
df.head(3)
# Out:
#      Tract ID  STATE2KX  CNTY2KX  TRACT2KX  life_expectancy  std_error  \
# 0  1001020100         1        1     20100             73.1     2.2348
# 1  1001020200         1        1     20200             76.9     3.3453
# 2  1001020400         1        1     20400             75.4     1.0216
#
#    Abridged life table flag
# 0                         3
# 1                         3
# 2                         3

# %% [markdown]
# ### Open `R12221544_SL140.csv`
#
# You'll need to give an option to `pd.read_csv` to make sure it's read in successfully.

# %%
df1=pd.read_csv('R12221544_SL140.csv',encoding='latin-1')

# %% [markdown]
# #### Filter out any columns we aren't interestd in

# %%
df1 = df1[['Geo_FIPS', 'Geo_GEOID', 'Geo_NAME', 'Geo_STUSAB', 'Geo_GEOCOMP', 'Geo_FILEID', 'Geo_LOGRECNO', 'Geo_US',
      'Geo_REGION', 'Geo_DIVISION', 'Geo_STATECE', 'Geo_STATE', 'Geo_COUNTY','Geo_TRACT', 'ACS15_5yr_B23025001',
      'ACS15_5yr_B23025002', 'ACS15_5yr_B23025003', 'ACS15_5yr_B23025004',
      'ACS15_5yr_B23025005', 'ACS15_5yr_B23025006', 'ACS15_5yr_B23025007',
      'ACS15_5yr_B23025001s', 'ACS15_5yr_B23025002s', 'ACS15_5yr_B23025003s',
      'ACS15_5yr_B23025004s', 'ACS15_5yr_B23025005s', 'ACS15_5yr_B23025006s',
# 73989  Census Tract 9900, Yabucoa Municipio, Puerto Rico         pr
# 73990  Census Tract 7501.01, Yauco Municipio, Puerto ...         pr
# 73991  Census Tract 7501.02, Yauco Municipio, Puerto ...         pr
# 73992  Census Tract 7502.01, Yauco Municipio, Puerto ...         pr
# 73993  Census Tract 7502.02, Yauco Municipio, Puerto ...         pr
# 73994    Census Tract 7503, Yauco Municipio, Puerto Rico         pr
# 73995    Census Tract 7504, Yauco Municipio, Puerto Rico         pr
# 73996  Census Tract 7505.01, Yauco Municipio, Puerto ...         pr
# 73997  Census Tract 7505.02, Yauco Municipio, Puerto ...         pr
# 73998  Census Tract 7505.03, Yauco Municipio, Puerto ...         pr
# 73999  Census Tract 7506.01, Yauco Municipio, Puerto ...         pr
# 74000  Census Tract 7506.02, Yauco Municipio, Puerto ...         pr
#
#        Geo_GEOCOMP Geo_FILEID  Geo_LOGRECNO  Geo_US  Geo_REGION  Geo_DIVISION  \
# 0                0      ACSSF          1760     NaN         NaN           NaN
# 1                0      ACSSF          1761     NaN         NaN           NaN
# 2                0      ACSSF          1762     NaN         NaN           NaN
# 3                0      ACSSF          1763     NaN         NaN           NaN
# 4                0      ACSSF          1764     NaN         NaN           NaN
# 5                0      ACSSF          1765     NaN         NaN           NaN
# 6                0      ACSSF          1766     NaN         NaN           NaN
# 7                0      ACSSF          1767     NaN         NaN           NaN
# 8                0      ACSSF          1768     NaN         NaN           NaN
# 9                0      ACSSF          1769     NaN         NaN           NaN
# 10               0      ACSSF          1770     NaN         NaN           NaN
# 11               0      ACSSF          1771     NaN         NaN           NaN
# 12               0      ACSSF          1772     NaN         NaN           NaN
# 13               0      ACSSF          1773     NaN         NaN           NaN
# 14               0      ACSSF          1774     NaN         NaN           NaN
# 15               0      ACSSF          1775     NaN         NaN           NaN
# 16               0      ACSSF          1776     NaN         NaN           NaN
# 17               0      ACSSF          1777     NaN         NaN           NaN
# 18               0      ACSSF          1778     NaN         NaN           NaN
# 19               0      ACSSF          1779     NaN         NaN           NaN
# 20               0      ACSSF          1780     NaN         NaN           NaN
# 21               0      ACSSF          1781     NaN         NaN           NaN
# 22               0      ACSSF          1782     NaN         NaN           NaN
# 23               0      ACSSF          1783     NaN         NaN           NaN
# 24               0      ACSSF          1784     NaN         NaN           NaN
# 25               0      ACSSF          1785     NaN         NaN           NaN
# 26               0      ACSSF          1786     NaN         NaN           NaN
# 27               0      ACSSF          1787     NaN         NaN           NaN
# 28               0      ACSSF          1788     NaN         NaN           NaN
# 29               0      ACSSF          1789     NaN         NaN           NaN
# ...            ...        ...           ...     ...         ...           ...
# 73971            0      ACSSF          3494     NaN         NaN           NaN
# 73972            0      ACSSF          3495     NaN         NaN           NaN
# 73973            0      ACSSF          3496     NaN         NaN           NaN
# 73974            0      ACSSF          3497     NaN         NaN           NaN
# 73975            0      ACSSF          3498     NaN         NaN           NaN
# 73976            0      ACSSF          3499     NaN         NaN           NaN
# 73977            0      ACSSF          3500     NaN         NaN           NaN
# 73978            0      ACSSF          3501     NaN         NaN           NaN
# 73979            0      ACSSF          3502     NaN         NaN           NaN
# 73980            0      ACSSF          3503     NaN         NaN           NaN
# 73981            0      ACSSF          3504     NaN         NaN           NaN
# 73982            0      ACSSF          3505     NaN         NaN           NaN
# 73983            0      ACSSF          3506     NaN         NaN           NaN
# 73984            0      ACSSF          3507     NaN         NaN           NaN
# 73985            0      ACSSF          3508     NaN         NaN           NaN
# 73986            0      ACSSF          3509     NaN         NaN           NaN
# 73987            0      ACSSF          3510     NaN         NaN           NaN
# 73988            0      ACSSF          3511     NaN         NaN           NaN
# 73989            0      ACSSF          3512     NaN         NaN           NaN
# 73990            0      ACSSF          3513     NaN         NaN           NaN
# 73991            0      ACSSF          3514     NaN         NaN           NaN
# 73992            0      ACSSF          3515     NaN         NaN           NaN
# 73993            0      ACSSF          3516     NaN         NaN           NaN
# 73994            0      ACSSF          3517     NaN         NaN           NaN
# 73995            0      ACSSF          3518     NaN         NaN           NaN
# 73996            0      ACSSF          3519     NaN         NaN           NaN
# 73997            0      ACSSF          3520     NaN         NaN           NaN
# 73998            0      ACSSF          3521     NaN         NaN           NaN
# 73999            0      ACSSF          3522     NaN         NaN           NaN
# 74000            0      ACSSF          3523     NaN         NaN           NaN
#
#        ...  Pop_in_Civilian_Labor_Force_unemployed  \
# 0      ...                                      54
# 1      ...                                     116
# 2      ...                                      91
# 3      ...                                     216
# 4      ...                                     221
# 5      ...                                     190
# 6      ...                                     150
# 7      ...                                     135
# 8      ...                                     415
# 9      ...                                     194
# 10     ...                                      85
# 11     ...                                     117
# 12     ...                                     158
# 13     ...                                     113
# 14     ...                                     254
# 15     ...                                     215
# 16     ...                                     154
# 17     ...                                      84
# 18     ...                                     133
# 19     ...                                     195
# 20     ...                                     179
# 21     ...                                     267
# 22     ...                                     323
# 23     ...                                     264
# 24     ...                                     294
# 25     ...                                     350
# 26     ...                                      48
# 27     ...                                     199
# 28     ...                                     244
# 29     ...                                     187
# ...    ...                                     ...
# 73971  ...                                       0
# 73972  ...                                     121
# 73973  ...                                     277
# 73974  ...                                       0
# 73975  ...                                     494
# 73976  ...                                     747
# 73977  ...                                     192
# 73978  ...                                     336
# 73979  ...                                     325
# 73980  ...                                     280
# 73981  ...                                     476
# 73982  ...                                     261
# 73983  ...                                     313
# 73984  ...                                     423
# 73985  ...                                     243
# 73986  ...                                     176
# 73987  ...                                     335
# 73988  ...                                     365
# 73989  ...                                       0
# 73990  ...                                     193
# 73991  ...                                     399
# 73992  ...                                     317
# 73993  ...                                     451
# 73994  ...                                     342
# 73995  ...                                     232
# 73996  ...                                     450
# 73997  ...                                     140
# 73998  ...                                     177
# 73999  ...                                     498
# 74000  ...                                     125
#
#        Pop_in_Labor_Force_Armed_Forces  Pop_Not_in_Labor_Force   Error_Pop  \
# 0                                    0                     557   92.121212
# 1                                   15                     847  143.030303
# 2                                    8                     990  169.090909
# 3                                   15                    1411  197.575758
# 4                                  203                    2737  321.818182
# 5                                   52                    1053  206.060606
# 6                                    0                     796  163.636364
# 7                                   28                     854  127.272727
# 68571  Census Tract 201, Northumberland County, Virginia         va
# 68864        Census Tract 201, Tazewell County, Virginia         va
# 68875          Census Tract 201, Warren County, Virginia         va
# 68970           Census Tract 201, Bristol city, Virginia         va
# 68990        Census Tract 201, Chesapeake city, Virginia         va
# 69343          Census Tract 201, Richmond city, Virginia         va
# 69797      Census Tract 201, Franklin County, Washington         wa
# 70006          Census Tract 201, King County, Washington         wa
# 71102    Census Tract 201, Fayette County, West Virginia         wv
# 71265     Census Tract 201, Marion County, West Virginia         wv
# 71401     Census Tract 201, Putnam County, West Virginia         wv
# 71464      Census Tract 201, Wayne County, West Virginia         wv
# 71574          Census Tract 201, Brown County, Wisconsin         wi
# 71611        Census Tract 201, Calumet County, Wisconsin         wi
# 72259      Census Tract 201, Milwaukee County, Wisconsin         wi
#
#        Geo_GEOCOMP Geo_FILEID  Geo_LOGRECNO  Geo_US  Geo_REGION  Geo_DIVISION  \
# 0                0      ACSSF          1760     NaN         NaN           NaN
# 168              0      ACSSF          1928     NaN         NaN           NaN
# 229              0      ACSSF          1989     NaN         NaN           NaN
# 326              0      ACSSF          2086     NaN         NaN           NaN
# 1147             0      ACSSF          2907     NaN         NaN           NaN
# 1452             0      ACSSF           823     NaN         NaN           NaN
# 3018             0      ACSSF          3525     NaN         NaN           NaN
# 3136             0      ACSSF          3643     NaN         NaN           NaN
# 3243             0      ACSSF          3750     NaN         NaN           NaN
# 9916             0      ACSSF          9059     NaN         NaN           NaN
# 12881            0      ACSSF           496     NaN         NaN           NaN
# 16625            0      ACSSF          4412     NaN         NaN           NaN
# 16684            0      ACSSF          4471     NaN         NaN           NaN
# 18612            0      ACSSF          2465     NaN         NaN           NaN
# 18938            0      ACSSF          2791     NaN         NaN           NaN
# 19790            0      ACSSF          3643     NaN         NaN           NaN
# 19858            0      ACSSF          3711     NaN         NaN           NaN
# 20217            0      ACSSF          4070     NaN         NaN           NaN
# 20310            0      ACSSF           270     NaN         NaN           NaN
# 20795            0      ACSSF           794     NaN         NaN           NaN
# 21109            0      ACSSF          5868     NaN         NaN           NaN
# 22813            0      ACSSF          7572     NaN         NaN           NaN
# 23541            0      ACSSF          8300     NaN         NaN           NaN
# 23729            0      ACSSF          8488     NaN         NaN           NaN
# 23981            0      ACSSF          8740     NaN         NaN           NaN
# 24305            0      ACSSF          3297     NaN         NaN           NaN
# 24706            0      ACSSF          3698     NaN         NaN           NaN
# 25439            0      ACSSF          4431     NaN         NaN           NaN
# 25494            0      ACSSF          4486     NaN         NaN           NaN
# 25656            0      ACSSF          4772     NaN         NaN           NaN
# ...            ...        ...           ...     ...         ...           ...
# 56505            0      ACSSF          7252     NaN         NaN           NaN
# 58498            0      ACSSF          9245     NaN         NaN           NaN
# 58813            0      ACSSF          1175     NaN         NaN           NaN
# 59086            0      ACSSF          1448     NaN         NaN           NaN
# 59366            0      ACSSF          1728     NaN         NaN           NaN
# 59495            0      ACSSF          1857     NaN         NaN           NaN
# 60121            0      ACSSF          3052     NaN         NaN           NaN
# 60132            0      ACSSF          2766     NaN         NaN           NaN
# 61667            0      ACSSF          4328     NaN         NaN           NaN
# 61709            0      ACSSF          4370     NaN         NaN           NaN
# 63184            0      ACSSF          5845     NaN         NaN           NaN
# 65125            0      ACSSF          7786     NaN         NaN           NaN
# 65709            0      ACSSF          8370     NaN         NaN           NaN
# 67562            0      ACSSF           730     NaN         NaN           NaN
# 68545            0      ACSSF          2960     NaN         NaN           NaN
# 68571            0      ACSSF          2986     NaN         NaN           NaN
# 68864            0      ACSSF          3279     NaN         NaN           NaN
# 68875            0      ACSSF          3290     NaN         NaN           NaN
# 68970            0      ACSSF          3385     NaN         NaN           NaN
# 68990            0      ACSSF          3405     NaN         NaN           NaN
# 69343            0      ACSSF          3758     NaN         NaN           NaN
# 69797            0      ACSSF          1534     NaN         NaN           NaN
# 70006            0      ACSSF          1743     NaN         NaN           NaN
# 71102            0      ACSSF          1124     NaN         NaN           NaN
# 71265            0      ACSSF          1287     NaN         NaN           NaN
# 71401            0      ACSSF          1423     NaN         NaN           NaN
# 71464            0      ACSSF          1486     NaN         NaN           NaN
# 71574            0      ACSSF          4217     NaN         NaN           NaN
# 71611            0      ACSSF          4254     NaN         NaN           NaN
# 72259            0      ACSSF          4902     NaN         NaN           NaN
#
#        ...  Pop_in_Labor_Force_Armed_Forces  Pop_Not_in_Labor_Force  \
# 0      ...                                0                     557
# 168    ...                                0                    1505
# 229    ...                                0                    1359
# 326    ...                                0                    1228
# 1147   ...                                0                    1271
# 1452   ...                                0                    1305
# 3018   ...                                7                    2470
# 3136   ...                                0                    2289
# 3243   ...                                0                     957
# 9916   ...                                0                    1797
# 12881  ...                               15                    1355
# 16625  ...                                0                    1251
# 16684  ...                               16                    2415
# 18612  ...                               20                    1024
# 18938  ...                                0                     317
# 19790  ...                               51                    1599
# 19858  ...                                0                    1928
# 20217  ...                                0                    2391
# 20310  ...                                0                    1796
# 20795  ...                                0                     377
# 21109  ...                                0                    1223
# 22813  ...                                2                    1444
# 23541  ...                                2                    2184
# 23729  ...                               11                     732
# 23981  ...                                0                    1161
# 24305  ...                                0                    1233
# 24706  ...                                0                    1657
# 25439  ...                                0                    1019
# 25494  ...                               11                    1021
# 25656  ...                               12                     728
# ...    ...                              ...                     ...
# 56505  ...                                0                    1047
# 58498  ...                               71                     800
# 58813  ...                                0                    1403
# 59086  ...                                0                     939
# 59366  ...                                0                     983
# 59495  ...                                0                     734
# 60121  ...                                6                    1035
# 60132  ...                                0                     922
# 61667  ...                                0                     853
# 61709  ...                                0                    1957
# 63184  ...                                0                     621
# 65125  ...                               87                    1542
# 65709  ...                               21                     568
# 67562  ...                                0                     900
# 68545  ...                                0                    6617
# 68571  ...                                0                    1433
# 68864  ...                                0                    1935
# 68875  ...                                0                    1926
# 68970  ...                               15                    1458
# 68990  ...                               88                     927
# 69343  ...                               13                     608
# 69797  ...                               22                    1808
# 70006  ...                                0                    1114
# 71102  ...                                0                    2275
# 71265  ...                                0                     708
# 71401  ...                                0                    2026
# 71464  ...                                0                     848
# 71574  ...                                0                    1485
# 71611  ...                                0                     971
# 72259  ...                                0                    1110
# 60132        0.072563
# 61667        0.020355
# 61709        0.019627
# 63184        0.064009
# 65125        0.042656
# 65709        0.024334
# 67562        0.070975
# 68545        0.047939
# 68571        0.048008
# 68864        0.019856
# 68875        0.035407
# 68970        0.040183
# 68990        0.071362
# 69343        0.053415
# 69797        0.077066
# 70006        0.028195
# 71102        0.014567
# 71265        0.037037
# 71401        0.004684
# 71464        0.026641
# 71574        0.020870
# 71611        0.018702
# 72259        0.044990
#
# [104 rows x 29 columns]

# %%
df.head(3)
# Out:
#      Tract ID  STATE2KX  CNTY2KX  TRACT2KX  life_expectancy  std_error  \
# 0  1001020100         1        1     20100             73.1     2.2348
# 1  1001020200         1        1     20200             76.9     3.3453
# 2  1001020400         1        1     20400             75.4     1.0216
#
#    Abridged life table flag
# 0                         3
# 1                         3
# 2                         3

# %% [markdown]
# ## Merging the data
#
# Merge the dataframes together based on their census tract.

# %%
merged=df.merge(df1,left_on='TRACT2KX',right_on='TRACT')

# %%
merged.head(3)
# Out:
#      Tract ID  STATE2KX  CNTY2KX  TRACT2KX  life_expectancy  std_error  \
# 0  1001020100         1        1     20100             73.1     2.2348
# 1  1001020100         1        1     20100             73.1     2.2348
# 2  1001020100         1        1     20100             73.1     2.2348
#
#    Abridged life table flag    Geo_FIPS           Geo_GEOID  \
# 0                         3  1001020100  14000US01001020100
# 1                         3  1033020100  14000US01033020100
# 2                         3  1045020100  14000US01045020100
#
#                                     Geo_NAME  ...  \
# 0  Census Tract 201, Autauga County, Alabama  ...
# 1  Census Tract 201, Colbert County, Alabama  ...
# 2     Census Tract 201, Dale County, Alabama  ...
#
#   Pop_in_Labor_Force_Armed_Forces  Pop_Not_in_Labor_Force   Error_Pop  \
# 0                               0                     557   92.121212
# 1                               0                    1505  135.151515
# 2                               0                    1359  156.363636
#
#    Error_Pop_in_Labor_Force  Error_Pop_in_Civilian_Labor_Force  \
# 0                 85.454545                          85.454545
# 1                115.151515                         115.151515
# 2                143.030303                         143.030303
#
#    Error_Pop_in_Civilian_Labor_Force_Employed  \
# 0                                   83.636364
# 1                                  108.484848
# 2                                  132.727273
#
#    Error_Pop_in_Civilian_Labor_Force_Unemployed  \
# 0                                     18.787879
# 1                                     53.939394
# 2                                     40.606061
#
#    Error_Pop_in_Labor_Force_Armed_Forces  Error_Pop_Not_in_Labor_Force  \
# 0                               6.666667                     67.878788
# 1                               6.666667                    124.848485
# 2                               6.666667                    115.757576
#
#    pct_unemployed
# 0        0.034749
# 1        0.046770
# 2        0.040129
#
# [3 rows x 36 columns]

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2729847 entries, 0 to 2729846
# Data columns (total 36 columns):
# Tract ID                                        int64
# STATE2KX                                        int64
# CNTY2KX                                         int64
# TRACT2KX                                        int64
# life_expectancy                                 float64
# std_error                                       float64
# Abridged life table flag                        int64
# Geo_FIPS                                        int64
# Geo_GEOID                                       object
# Geo_NAME                                        object
# Geo_STUSAB                                      object
# Geo_GEOCOMP                                     int64
# Geo_FILEID                                      object
# Geo_LOGRECNO                                    int64
# Geo_US                                          float64
# Geo_REGION                                      float64
# Geo_DIVISION                                    float64
# Geo_STATECE                                     float64
# Geo_STATE                                       int64
# Geo_COUNTY                                      int64
# TRACT                                           int64
# Pop                                             int64
# Pop_in_Labor_Force                              int64
# Pop_in_Civilian_Labor_Force                     int64
# Pop_in_Civilian_Labor_Force_employed            int64
# Pop_in_Civilian_Labor_Force_unemployed          int64
# Pop_in_Labor_Force_Armed_Forces                 int64
# Pop_Not_in_Labor_Force                          int64
# Error_Pop                                       float64
# Error_Pop_in_Labor_Force                        float64
# Error_Pop_in_Civilian_Labor_Force               float64
# Error_Pop_in_Civilian_Labor_Force_Employed      float64
# Error_Pop_in_Civilian_Labor_Force_Unemployed    float64
# Error_Pop_in_Labor_Force_Armed_Forces           float64
# Error_Pop_Not_in_Labor_Force                    float64
# pct_unemployed                                  float64
# dtypes: float64(14), int64(18), object(4)
# memory usage: 770.6+ MB

# %% [markdown]
# ## Running the regression
#
# Using the `statsmodels` package, run a linear regression to find the coefficient relating unemployment and life expectancy.

# %%
X = merged[['pct_unemployed']]*100
X = sm.add_constant(X)
mod = sm.OLS(merged.life_expectancy, X, missing='drop')
res = mod.fit()

# %%
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        life_expectancy   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     2293.
# Date:                Wed, 17 Jul 2019   Prob (F-statistic):               0.00
# Time:                        16:22:43   Log-Likelihood:            -7.7548e+06
# No. Observations:             2728570   AIC:                         1.551e+07
# Df Residuals:                 2728568   BIC:                         1.551e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             77.2391      0.005   1.59e+04      0.000      77.230      77.249
# pct_unemployed    -0.0365      0.001    -47.884      0.000      -0.038      -0.035
# ==============================================================================
# Omnibus:                     8361.520   Durbin-Watson:                   0.038
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9710.959
# Skew:                          -0.082   Prob(JB):                         0.00
# Kurtosis:                       3.242   Cond. No.                         12.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# Translate that into the form **"every X percentage point change in unemployment translates to a Y change in life expectancy"**

# %%
#every 25 percentage point change in unemployment translates to a 1 year decrease in life expectancy

# %% [markdown]
# ## Bringing more columns into the mix
#
# Only dealing with unemployment seems kind of narrow-minded, let's expand our reach a bit.

# %% [markdown]
# ### Read in `R12221550_SL140.csv`
#
# It's also from the Census, and has many, many, many more columns available to you compared to the list dataset.

# %%
df2=pd.read_csv('R12221550_SL140.csv',encoding='latin-1')

# %% [markdown]
# Using this census data, create a new dataframe that includes the following columns:
#
# * Percent unemployed
# * Percents Black, White, and Hispanic
# * Median Income (in increments of 10,000 dollars)
# * Percent of the population with less than a high school education
# * Percent of the population between 1-1.5x the poverty line
#
# If you have to many any editorial decisions about which columns you choose or how you do your math, please explain them.

# %%
df2 = df2[['Geo_FIPS', 'Geo_GEOID', 'Geo_NAME', 'Geo_STUSAB', 'Geo_GEOCOMP', 'Geo_FILEID', 'Geo_LOGRECNO', 'Geo_US',
      'Geo_REGION', 'Geo_DIVISION', 'Geo_STATECE', 'Geo_STATE', 'Geo_COUNTY','Geo_TRACT', 'ACS15_5yr_B03002003',
      'ACS15_5yr_B03002004', 'ACS15_5yr_B03002012', 'ACS15_5yr_B23025004',
      'ACS15_5yr_B19013001', 'ACS15_5yr_B06009008', 'ACS15_5yr_C17002004',
      'ACS15_5yr_C17002005']]
df2 = df2.rename(columns={'Geo_TRACT':'TRACT', 'ACS15_5yr_B03002004':'black_pop', 'ACS15_5yr_B03002012':'hispanic_pop', 
      'ACS15_5yr_B19013001':'median_income', 'ACS15_5yr_B06009008':'Pop_less_hs', 'ACS15_5yr_C17002004':'pop_poverty1124',
      'ACS15_5yr_C17002005':'pop_poverty1245', 'ACS15_5yr_B03002003':'white_pop'})

# %%
df2['median_income']=df2['median_income']/10000

# %% [markdown]
# ### Join your datasets
#
# Combine your life expectancy dataset with this census dataset to create a new dataframe.

# %%
merged1=pd.merge(merged,df2, on='Geo_FIPS')

# %%
merged1
# Out:
#             Tract ID  STATE2KX  CNTY2KX  TRACT2KX  life_expectancy  std_error  \
# 0         1001020100         1        1     20100             73.1     2.2348
# 1         1033020100         1       33     20100             72.3     1.4305
# 2         1045020100         1       45     20100             75.0     1.5468
# 3         1057020100         1       57     20100             72.6     1.4231
# 4         1127020100         1      127     20100             68.6     1.3919
# 5         4012020100         4       12     20100             78.9     1.3106
# 6         5033020100         5       33     20100             76.4     1.8804
# 7         5059020100         5       59     20100             73.4     1.2765
# 8         5091020100         5       91     20100             72.9     1.3771
# 9         6075020100         6       75     20100             75.7     2.0606
# 10        9001020100         9        1     20100             80.8     1.9289
# 11       12086020100        12       86     20100             82.8     2.5012
# 12       12091020100        12       91     20100             74.8     0.9766
# 13       13053020100        13       53     20100             73.4     2.1260
# 14       13089020100        13       89     20100             79.7     2.5809
# 15       13177020100        13      177     20100             77.2     1.4785
# 16       13195020100        13      195     20100             73.4     1.0261
# 17       13295020100        13      295     20100             74.1     1.2032
# 18       15001020100        15        1     20100             79.7     0.7744
# 19       16027020100        16       27     20100             72.5     1.8678
# 20       17031020100        17       31     20100             79.7     1.5711
# 21       17085020100        17       85     20100             83.0     1.5630
# 22       17161020100        17      161     20100             80.3     2.1978
# 23       17179020100        17      179     20100             76.3     1.2469
# 24       17199020100        17      199     20100             78.7     1.6103
# 25       18033020100        18       33     20100             83.5     2.1017
# 26       18089020100        18       89     20100             76.3     1.3522
# 27       18159020100        18      159     20100             78.5     2.0203
# 28       18165020100        18      165     20100             76.2     1.5862
# 29       19015020100        19       15     20100             87.9     3.8538
# ...              ...       ...      ...       ...              ...        ...
# 2729817  54003972101        54        3    972101             84.4     3.5070
# 2729818  54003972102        54        3    972102             76.1     1.1366
# 2729819  54005958501        54        5    958501             75.4     1.9079
# 2729820  54005958502        54        5    958502             73.0     1.2499
# 2729821  54037972201        54       37    972201             82.1     2.1229
# 2729822  54037972203        54       37    972203             84.1     3.4833
# 2729823  54037972204        54       37    972204             79.5     2.2713
# 2729824  54037972401        54       37    972401             71.3     2.1963
# 2729825  54037972402        54       37    972402             75.9     1.6835
# 2729826  54037972501        54       37    972501             82.4     2.1247
# 2729827  54037972503        54       37    972503             78.9     1.9430
# 2729828  54037972505        54       37    972505             74.6     1.4190
# 2729829  54037972506        54       37    972506             76.1     1.5528
# 2729836   954503      2620       1035           239                 1007
# 2729837   954504      4444         76             0                 1119
# 2729838   954801      3067         23             0                  975
# 2729839   954801        18          0          4061                  930
# 2729840   954802      4198          5             0                 1688
# 2729841   954802         0          0          1916                  398
# 2729842   955101      1717        121            21                  714
# 2729843   955101      2730          0           147                  986
# 2729844   940202      1672          8           286                 1901
# 2729845   967701      1841          7           522                 1585
# 2729846   967702      5019          0          1461                 4212
#
#          median_income  Pop_less_hs  pop_poverty1124  pop_poverty1245
# 0               6.1838        118.0               81              101
# 1               6.1838        118.0               81              101
# 2               6.1838        118.0               81              101
# 3               6.1838        118.0               81              101
# 4               6.1838        118.0               81              101
# 5               6.1838        118.0               81              101
# 6               6.1838        118.0               81              101
# 7               6.1838        118.0               81              101
# 8               6.1838        118.0               81              101
# 9               6.1838        118.0               81              101
# 10              6.1838        118.0               81              101
# 11              6.1838        118.0               81              101
# 12              6.1838        118.0               81              101
# 13              6.1838        118.0               81              101
# 14              6.1838        118.0               81              101
# 15              6.1838        118.0               81              101
# 16              6.1838        118.0               81              101
# 17              6.1838        118.0               81              101
# 18              6.1838        118.0               81              101
# 19              6.1838        118.0               81              101
# 20              6.1838        118.0               81              101
# 21              6.1838        118.0               81              101
# 22              6.1838        118.0               81              101
# 23              6.1838        118.0               81              101
# 24              6.1838        118.0               81              101
# 25              6.1838        118.0               81              101
# 26              6.1838        118.0               81              101
# 27              6.1838        118.0               81              101
# 28              6.1838        118.0               81              101
# 29              6.1838        118.0               81              101
# ...                ...          ...              ...              ...
# 2729817         6.3221        216.0              222              153
# 2729818         6.3125        372.0              636              442
# 2729819         3.6000        458.0              182              194
# 2729820         4.6085        225.0              113               61
# 2729821         8.2563         64.0              128               18
# 2729822         8.0774         79.0                5               15
# 2729823         3.9063         51.0               94              132
# 2729824         3.3173        130.0              295              113
# 2729825         5.2200        436.0              445              382
# 2729826         9.1638        255.0                0              320
# 2729827         8.2973         31.0               41               81
# 2729828         3.7241        154.0              104              108
# 2729829         7.0229         89.0                4              133
# 2729830         5.3750        109.0              122               94
# 2729831         9.4118         63.0              357              205
# 2729832         6.0729        114.0              117               20
# 2729833         6.6961        131.0              105              159
# 2729834         4.1324       1007.0              467              545
# 2729835         4.3125        304.0              156              169
# 2729836         2.8559        514.0              192               52
# 2729837         2.3210       1027.0              454              332
# 2729838         3.5168        263.0              201              145
# 2729839         1.5683          NaN              402              343
# 2729840         3.6894        337.0              182              299
# 2729841         1.3503          NaN              224              115
# 2729842         3.1417        205.0              143               85
# 2729843         3.2143        217.0               78              260
# 2729844         5.9167        225.0              400              180
# 2729845         6.3977          0.0               73               28
# 2729846         7.4583          0.0              273              183
#
# [2729847 rows x 57 columns]

# %%
merged1['pct_black']=merged1['black_pop']/merged1['Pop']*100
merged1['pct_hispanic']=merged1['hispanic_pop']/merged1['Pop']*100
merged1['pct_white']=merged1['hispanic_pop']/merged1['Pop']*100
merged1['pct_unemployed']=merged1['pct_unemployed']*100

# %%
merged1.dtypes
# Out:
# Tract ID                                          int64
# STATE2KX                                          int64
# CNTY2KX                                           int64
# TRACT2KX                                          int64
# life_expectancy                                 float64
# std_error                                       float64
# Abridged life table flag                          int64
# Geo_FIPS                                          int64
# Geo_GEOID_x                                      object
# Geo_NAME_x                                       object
# Geo_STUSAB_x                                     object
# Geo_GEOCOMP_x                                     int64
# Geo_FILEID_x                                     object
# Geo_LOGRECNO_x                                    int64
# Geo_US_x                                        float64
# Geo_REGION_x                                    float64
# Geo_DIVISION_x                                  float64
# Geo_STATECE_x                                   float64
# Geo_STATE_x                                       int64
# Geo_COUNTY_x                                      int64
# TRACT_x                                           int64
# Pop                                               int64
# Pop_in_Labor_Force                                int64
# Pop_in_Civilian_Labor_Force                       int64
# Pop_in_Civilian_Labor_Force_employed              int64
# Pop_in_Civilian_Labor_Force_unemployed            int64
# Pop_in_Labor_Force_Armed_Forces                   int64
# Pop_Not_in_Labor_Force                            int64
# Error_Pop                                       float64
# Error_Pop_in_Labor_Force                        float64
# Error_Pop_in_Civilian_Labor_Force               float64
# Error_Pop_in_Civilian_Labor_Force_Employed      float64
# Error_Pop_in_Civilian_Labor_Force_Unemployed    float64
# Error_Pop_in_Labor_Force_Armed_Forces           float64
# Error_Pop_Not_in_Labor_Force                    float64
# pct_unemployed                                  float64
# Geo_GEOID_y                                      object
# Geo_NAME_y                                       object
# Geo_STUSAB_y                                     object
# Geo_GEOCOMP_y                                     int64
# Geo_FILEID_y                                     object
# Geo_LOGRECNO_y                                    int64
# Geo_US_y                                        float64
# Geo_REGION_y                                    float64
# Geo_DIVISION_y                                  float64
# Geo_STATECE_y                                   float64
# Geo_STATE_y                                       int64
# Geo_COUNTY_y                                      int64
# TRACT_y                                           int64
# white_pop                                         int64
# black_pop                                         int64
# hispanic_pop                                      int64
# ACS15_5yr_B23025004                               int64
# median_income                                   float64
# Pop_less_hs                                     float64
# pop_poverty1124                                   int64
# pop_poverty1245                                   int64
# pct_black                                       float64
# pct_hispanic                                    float64
# pct_white                                       float64
# dtype: object

# %%
merged1['pct_pov']=(merged1['pop_poverty1124']+merged1['pop_poverty1245'])/merged['Pop']*100

# %% [markdown]
# ## Running your multivariate regression
#
# Using the `statsmodels` package and this new dataframe, run a multivariate linear regression to find the coefficient relating your columns and life expectancy.

# %%
X = sm.add_constant(merged1[['pct_unemployed', 'white_pop','black_pop','hispanic_pop','Pop_less_hs','pct_pov', 'median_income']])
y = merged1['life_expectancy']
mod = sm.OLS(y, X, missing='drop')
res = mod.fit()
res.summary()
# Out:
# ---------------------------------------------------------------------------
# MissingDataError                          Traceback (most recent call last)
# <ipython-input-51-40427651fee9> in <module>
#       1 X = sm.add_constant(merged1[['pct_unemployed', 'white_pop','black_pop','hispanic_pop','Pop_less_hs','pct_pov', 'median_income']])
#       2 y = merged1['life_expectancy']
# ----> 3 mod = sm.OLS(y, X, missing='drop')
#       4 res = mod.fit()
#       5 res.summary()
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     836                  **kwargs):
#     837         super(OLS, self).__init__(endog, exog, missing=missing,
# --> 838                                   hasconst=hasconst, **kwargs)
#     839         if "weights" in self._init_keys:
#     840             self._init_keys.remove("weights")
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     682             weights = weights.squeeze()
#     683         super(WLS, self).__init__(endog, exog, missing=missing,
# --> 684                                   weights=weights, hasconst=hasconst, **kwargs)
#     685         nobs = self.exog.shape[0]
#     686         weights = self.weights
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, **kwargs)
#     194     """
#     195     def __init__(self, endog, exog, **kwargs):
# --> 196         super(RegressionModel, self).__init__(endog, exog, **kwargs)
#     197         self._data_attr.extend(['pinv_wexog', 'wendog', 'wexog', 'weights'])
#     198
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/statsmodels/base/model.py in __init__(self, endog, exog, **kwargs)
#     214
#     215     def __init__(self, endog, exog=None, **kwargs):
# --> 216         super(LikelihoodModel, self).__init__(endog, exog, **kwargs)
#     217         self.initialize()
#     218
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/statsmodels/base/model.py in __init__(self, endog, exog, **kwargs)
#      66         hasconst = kwargs.pop('hasconst', None)
#      67         self.data = self._handle_data(endog, exog, missing, hasconst,
# ---> 68                                       **kwargs)
#      69         self.k_constant = self.data.k_constant
#      70         self.exog = self.data.exog
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/statsmodels/base/model.py in _handle_data(self, endog, exog, missing, hasconst, **kwargs)
#      89
#      90     def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# ---> 91         data = handle_data(endog, exog, missing, hasconst, **kwargs)
#      92         # kwargs arrays could have changed, easier to just attach here
#      93         for key in kwargs:
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/statsmodels/base/data.py in handle_data(endog, exog, missing, hasconst, **kwargs)
#     633     klass = handle_data_class_factory(endog, exog)
#     634     return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
# --> 635                  **kwargs)
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/statsmodels/base/data.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#      78         self.const_idx = None
#      79         self.k_constant = 0
# ---> 80         self._handle_constant(hasconst)
#      81         self._check_integrity()
#      82         self._cache = {}
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/statsmodels/base/data.py in _handle_constant(self, hasconst)
#     124             ptp_ = np.ptp(self.exog, axis=0)
#     125             if not np.isfinite(ptp_).all():
# --> 126                 raise MissingDataError('exog contains inf or nans')
#     127             const_idx = np.where(ptp_ == 0)[0].squeeze()
#     128             self.k_constant = const_idx.size
#
# MissingDataError: exog contains inf or nans

# %% [markdown]
# Translate some of your coefficients into the form **"every X percentage point change in unemployment translates to a Y change in life expectancy."** Do this with numbers that are meaningful, and in a way that is easily understandable to your reader.
