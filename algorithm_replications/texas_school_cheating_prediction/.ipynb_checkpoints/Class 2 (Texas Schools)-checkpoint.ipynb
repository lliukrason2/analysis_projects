# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import numpy as np
from statsmodels.sandbox.regression.predstd import wls_prediction_std

# %% [markdown]
# # Texas School Cheating

# %% [markdown]
# ### Read in the data (cfy03e3.csv and cfy04e4.csv)
# When you're reading the data
# - set the 'campus' column to be the index
# - make sure to add suffix to each column based on the grade (3rd or 4th)

# %%
df = pd.read_csv("cfy03e3.csv").set_index('CAMPUS').add_suffix('_third')
df2 = pd.read_csv("cfy04e4.csv").set_index('CAMPUS').add_suffix('_fourth')

df.columns
# Out:
# Index(['DISTRICT_third', 'MONTH_third', 'YEAR_third', 'GRADE_third',
#        'REGION_third', 'DNAME_third', 'CNAME_third', 'STATE_third',
#        'a_docs_third', 'a_tst_n_third',
#        ...
#        'M_obj2_RI_third', 'M_obj3_NI_third', 'M_obj3_RI_third',
#        'M_obj4_NI_third', 'M_obj4_RI_third', 'M_obj5_NI_third',
#        'M_obj5_RI_third', 'M_obj6_NI_third', 'M_obj6_RI_third',
#        'a_not_n_third'],
#       dtype='object', length=1626)

# %% [markdown]
# ## Join the datasets above horizontally

# %%
merged = df.join(df2)

# %%
merged.head(15)
# Out:
#          DISTRICT_third  MONTH_third  YEAR_third  GRADE_third  REGION_third  \
# CAMPUS
# 1902103            1902            3           3            3             7
# 1903101            1903            4           3            3             7
# 1904102            1904            4           3            3             7
# 1906102            1906            4           3            3             7
# 1907110            1907            4           3            3             7
# 1908101            1908            4           3            3             7
# 1909101            1909            3           3            3             7
# 2901101            2901            3           3            3            18
# 2901103            2901            4           3            3            18
# 2901104            2901            4           3            3            18
# 2901105            2901            3           3            3            18
# 3801001            3801            3           3            3             7
# 3902102            3902            3           3            3             7
# 3903120            3903            4           3            3             7
# 3903121            3903            4           3            3             7
#
#              DNAME_third      CNAME_third  STATE_third  a_docs_third  \
# CAMPUS
# 1902103       CAYUGA ISD        CAYUGA EL            1            41
# 1903101      ELKHART ISD       ELKHART EL            1            73
# 1904102    FRANKSTON ISD     FRANKSTON EL            1            70
# 1906102       NECHES ISD        NECHES EL            1            17
# 1907110    PALESTINE ISD         STORY EL            1           262
# 1908101     WESTWOOD ISD      WESTWOOD EL            1           135
# 1909101       SLOCUM ISD        SLOCUM EL            1            25
# 2901101      ANDREWS ISD    DEVONIAN ELEM            1            51
# 2901103      ANDREWS ISD  SAN ANDRES ELEM            1            52
# 2901104      ANDREWS ISD   UNDERWOOD ELEM            1            40
# 2901105      ANDREWS ISD     CLEARFORK EL            1            53
# 3801001  PINEYWOODS COMM  PINEYWOODS COMM            1            22
# 3902102       HUDSON ISD        HUDSON EL            1           140
# 3903120       LUFKIN ISD      ANDERSON EL            1           112
# 3903121       LUFKIN ISD       BRANDON EL            1           153
#
#          a_tst_n_third       ...        a_wc4_eco1_R_fourth  \
# CAMPUS                       ...
# 1902103             36       ...                        0.0
# 1903101             62       ...                        0.0
# 1904102             64       ...                        0.0
# 1906102             14       ...                        NaN
# 1907110            246       ...                        0.0
# 1908101            123       ...                        0.0
# 1909101             23       ...                        0.0
# 2901101             51       ...                        NaN
# 2901103             49       ...                        NaN
# 2901104             35       ...                        0.0
# 2901105             44       ...                        NaN
# 3801001             20       ...                        0.0
# 3902102            125       ...                        2.0
# 3903120             99       ...                        0.0
# 3903121            139       ...                        0.0
#
#          a_wc4_eco2_R_fourth  a_wc4_eco9_R_fourth  a_wc4_voce_R_fourth  \
# CAMPUS
# 1902103                  NaN                  NaN                  NaN
# 1903101                  0.0                  NaN                  NaN
# 1904102                  0.0                  NaN                  NaN
# 1906102                  NaN                  NaN                  NaN
# 1907110                  0.0                  NaN                  NaN
# 1908101                  0.0                  NaN                  NaN
# 1909101                  NaN                  NaN                  NaN
# 2901101                  NaN                  NaN                  NaN
# 2901103                  NaN                  NaN                  NaN
# 2901104                  0.0                  0.0                  NaN
# 2901105                  NaN                  NaN                  NaN
# 3801001                  NaN                  NaN                  NaN
# 3902102                  7.0                  NaN                  NaN
# 3903120                  0.0                  NaN                  NaN
# 3903121                 11.0                  NaN                  NaN
#
#          a_wc4_vocs_R_fourth  a_wc4_vocp_R_fourth  a_wc4_ecoy_R_fourth  \
# CAMPUS
# 1902103                  NaN                  NaN                  0.0
# 1903101                  NaN                  NaN                  0.0
# 1904102                  NaN                  NaN                  0.0
# 1906102                  NaN                  NaN                  0.0
# 1907110                  NaN                  NaN                  0.0
# 1908101                  NaN                  NaN                  0.0
# 1909101                  NaN                  NaN                  0.0
# 2901101                  NaN                  NaN                  NaN
# 2901103                  NaN                  NaN                  NaN
# 2901104                  NaN                  NaN                  0.0
# 2901105                  NaN                  NaN                  NaN
# 3801001                  NaN                  NaN                  0.0
# 3902102                  NaN                  NaN                  3.0
# 3903120                  NaN                  NaN                  0.0
# 3903121                  NaN                  NaN                  1.0
#
#          a_wc4_econ_R_fourth  a_wc4_ecov_R_fourth  a_not_n_fourth
# CAMPUS
# 1902103                  0.0                  NaN             NaN
# 1903101                  0.0                  NaN             NaN
# 1904102                  6.0                  NaN             NaN
# 1906102                  0.0                  NaN             NaN
# 1907110                  0.0                  NaN             NaN
# 1908101                  0.0                  NaN             NaN
# 1909101                 33.0                  NaN             NaN
# 2901101                  NaN                  NaN             NaN
# 2901103                  NaN                  NaN             NaN
# 2901104                  3.0                  NaN             NaN
# 2901105                  NaN                  NaN             NaN
# 3801001                  0.0                  NaN             NaN
# 3902102                 13.0                  NaN             NaN
# 3903120                  4.0                  NaN             NaN
# 3903121                  9.0                  NaN             NaN
#
# [15 rows x 3778 columns]

# %% [markdown]
# ## Drop emty campus names for both grades

# %%
merged = merged.dropna(subset=['CNAME_third', 'CNAME_fourth'])
merged.shape
# Out:
# (3555, 3778)

# %% [markdown]
# ## Plot the resulting DF using regplot in seaborn
# for x use 'r_all_rs_third'
# for y use 'r_all_rs_fourth'

# %%
fig, ax = plt.subplots(figsize=(4,4))

ax.set_xlim(2000, 2500)
ax.set_ylim(1900, 2500)
ax.set_facecolor('lightgrey')
ax.grid(True, color='white')
ax.set_axisbelow(True)

sns.regplot('r_all_rs_third',
            'r_all_rs_fourth',
            data=merged,
            marker='.', 
            line_kws={"color": "black", "linewidth": 1},
            scatter_kws={"color": "grey"})
harr = merged.loc[57905115]
plt.plot(harr.r_all_rs_third, harr.r_all_rs_fourth, 'ro')
# Out:
# /Users/elizabetdoliar/.pyenv/versions/3.6.5/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## Based on the graph above find the name of the outlier school

# %%
merged[(merged.r_all_rs_fourth > 2450) & (merged.r_all_rs_third < 2200)][['CNAME_third', 'r_all_rs_third', 'r_all_rs_fourth']]
# Out:
#               CNAME_third  r_all_rs_third  r_all_rs_fourth
# CAMPUS
# 57905115  HARRELL BUDD EL          2140.0           2470.0

# %% [markdown]
# ## Try to predict 4th graders' scores based on their third grade performance using a linear regression
# !!! Make sure both score columns have no null values

# %%
merged = merged[merged.r_all_rs_fourth.notnull() & merged.r_all_rs_third.notnull()]

## Fit a regression using sm.OLS(Y,X)
## With the intercept
# X = merged[['r_all_rs_third']]
# X = sm.add_constant(X)
# mod = sm.OLS(merged.r_all_rs_fourth, X)
# res = mod.fit()

## or without the intercept 
X = merged[['r_all_rs_third']]
mod = sm.OLS(merged.r_all_rs_fourth, X)
res = mod.fit()

# %% [markdown]
# ## Print regression results using the .summary () method

# %%
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:        r_all_rs_fourth   R-squared (uncentered):                   1.000
# Model:                            OLS   Adj. R-squared (uncentered):              1.000
# Method:                 Least Squares   F-statistic:                          8.067e+06
# Date:                Fri, 12 Jul 2019   Prob (F-statistic):                        0.00
# Time:                        18:36:27   Log-Likelihood:                         -18403.
# No. Observations:                3501   AIC:                                  3.681e+04
# Df Residuals:                    3500   BIC:                                  3.681e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# r_all_rs_third     0.9905      0.000   2840.184      0.000       0.990       0.991
# ==============================================================================
# Omnibus:                      363.602   Durbin-Watson:                   1.866
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1604.827
# Skew:                           0.420   Prob(JB):                         0.00
# Kurtosis:                       6.209   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
res.params
# Out:
# r_all_rs_third    0.990451
# dtype: float64

# %% [markdown]
# ## If we would to predict the score of the 4th graders at HARRELL BUDD EL based on the results of 3rd graders?

# %%
res.predict([2140.0])
# Out:
# array([2119.56592325])

# %% [markdown]
# ## How far is HARRELL BUDD EL score from the prediction

# %%
##Finidng standard deviation
#take the square root of (square the residuals and take the mean)
st_dev = np.sqrt(np.mean(res.resid**2))
st_dev
# Out:
# 46.41737610431789

# %% [markdown]
# ## Sort by how many standard deviations aways they are to find the CHEATERS

# %%
#Compute the Standard Deviation of the data set
std_dev = np.sqrt(res.mse_resid)

# %%
# Calculate standard deviation every school 
## In Stats terms: How spread out the points are around the line

merged['std_dev'] = res.resid / std_dev

# %%
# Select only these columns ['CNAME_fourth', 'r_all_rs_fourth', 'r_all_rs_third', 'std_dev']
important_cols = merged[['CNAME_fourth', 'r_all_rs_fourth', 'r_all_rs_third', 'std_dev']]

# %%
# Then we'll sort by the standard deviation
# We want the top and the bottom, right? So we'll abs-value it?
std_dev_order = important_cols.std_dev.abs().sort_values(ascending=False).index
important_cols.reindex(std_dev_order)
# Out:
#               CNAME_fourth  r_all_rs_fourth  r_all_rs_third   std_dev
# CAMPUS
# 57905115   HARRELL BUDD EL           2470.0          2140.0  7.548553
# 123803101  TEKOA ACADEMY O           2313.0          2021.0  6.705535
# 15803101   HIGGS/CARTER/KI           2349.0          2097.0  5.859543
# 101912172   HENDERSON N EL           2324.0          2093.0  5.406369
# 139908101        ROXTON EL           2130.0          2388.0 -5.066298
# 57825001   PINNACLE SCHOOL           2274.0          2068.0  4.862712
# 101823101   CHILDREN FIRST           2252.0          2066.0  4.431489
# 47905001     SIDNEY SCHOOL           2208.0          2024.0  4.379769
# 105802041  SAN MARCOS PREP           2025.0          2245.0 -4.277169
# 101909104  LAKEWOOD ELEMEN           2275.0          2104.0  4.116196
# 57905185   WILLIAM B MILLE           2295.0          2129.0  4.013636
# 101840101   TWO DIMENSIONS           2076.0          2275.0 -3.818646
# 180901101  MIMI FARLEY ELE           2448.0          2294.0  3.789086
# 101912108       BASTIAN EL           2260.0          2105.0  3.771753
# 90905101   GRANDVIEW-HOPKI           2149.0          2346.0 -3.760962
# 108912110  JOSE DE ESCANDO           2166.0          2360.0 -3.693460
# 226903111     FT CONCHO EL           2196.0          2386.0 -3.601950
# 108902115  LE NOIR ELEMENT           2242.0          2099.0  3.512032
# 101912134      CRAWFORD EL           2056.0          2240.0 -3.502736
# 101912140         DOGAN EL           1972.0          2150.0 -3.392004
# 161801101  EOAC WACO CHART           2166.0          2030.0  3.347056
# 57905263     J P STARKS EL           2231.0          2096.0  3.339090
# 101912254        WESLEY EL           2292.0          2470.0 -3.326186
# 19901102         DEKALB EL           2356.0          2223.0  3.322131
# 57905142      J N ERVIN EL           2233.0          2099.0  3.318166
# 50901101          EVANT EL           2169.0          2345.0 -3.308815
# 15819001   SHEKINAH RADIAN           1976.0          2149.0 -3.284507
# 103902001   HARTLEY SCHOOL           2288.0          2159.0  3.222805
# 61911111   PRAIRIE VIEW EL           2389.0          2261.0  3.222244
# 123907105           LEE EL           2292.0          2165.0  3.180958
# ...                    ...              ...             ...       ...
# 101803101  WEST HOUSTON CH           2238.0          2260.0 -0.009049
# 101917131        SPARKS EL           2222.0          2243.0  0.008995
# 49902101       MUENSTER EL           2323.0          2345.0  0.008434
# 43910129       GULLEDGE EL           2320.0          2342.0  0.007817
# 57905276   GILBERT CUELLAR           2112.0          2132.0  0.007705
# 240901104       DAICHES EL           2141.0          2162.0 -0.007665
# 101912189        KOLTER EL           2349.0          2372.0 -0.007553
# 108903102  SANTIAGO GARCIA           2142.0          2163.0 -0.007460
# 250906101   ALBA-GOLDEN EL           2249.0          2271.0 -0.006786
# 57905210   LESLIE A STEMMO           2148.0          2169.0 -0.006226
# 15907121      DE ZAVALA EL           2148.0          2169.0 -0.006226
# 57905153   VICTOR H HEXTER           2206.0          2227.0  0.005704
# 161903105  SOUTH BOSQUE EL           2359.0          2382.0 -0.005496
# 194902101         AVERY EL           2204.0          2225.0  0.005293
# 249904101       CHICO ELEM           2201.0          2222.0  0.004676
# 75901102       FLATONIA EL           2302.0          2324.0  0.004115
# 227901183  COWAN ELEMENTAR           2262.0          2284.0 -0.004113
# 1903101         ELKHART EL           2263.0          2285.0 -0.003907
# 152907103   NORTH RIDGE EL           2297.0          2319.0  0.003086
# 220905135  VAN ZANDT-GUINN           2165.0          2186.0 -0.002729
# 20905104    O A FLEMING EL           2190.0          2211.0  0.002413
# 111901107  MAMBRINO SCHOOL           2293.0          2315.0  0.002264
# 15916112     CANDLEWOOD EL           2169.0          2190.0 -0.001906
# 79907135   COMMONWEALTH EL           2394.0          2417.0  0.001703
# 221901112       JACKSON EL           2285.0          2307.0  0.000618
# 239901103  KRAUSE ELEMENTA           2279.0          2301.0 -0.000616
# 101912269     SCROGGINS EL           2181.0          2202.0  0.000562
# 220902109  SOUTH BIRDVILLE           2181.0          2202.0  0.000562
# 233901105     EAST SIDE EL           2176.0          2197.0 -0.000466
# 84910110     P H GREENE EL           2284.0          2306.0  0.000413
#
# [3501 rows x 4 columns]
