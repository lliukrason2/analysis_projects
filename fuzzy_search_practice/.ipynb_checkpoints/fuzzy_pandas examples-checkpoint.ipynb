# %% [markdown]
# ## Fuzzy Matching and Fuzzy Pandas
#
# [Max Harlow](https://twitter.com/maxharlow), a journalist at the Financial Times, wrote this library `csvmatch`, and he's been adding new algorithms to facilitate fuzzy matching across datasets. He's used it for a bunch of stories, including:
# - https://www.theguardian.com/uk-news/2014/jul/09/offshore-tax-dealings-celebrities-sportsmen-leaked-jersey-files
# - https://www.theguardian.com/politics/2014/jul/08/offshore-secrets-wealthy-political-donors
#
# Similar techniques have also been used in other stories like:
# - https://www.globalwitness.org/en/campaigns/oil-gas-and-mining/myanmarjade
# - https://www.irinnews.org/investigation/2016/09/02/exclusive-un-paying-blacklisted-diamond-company-central-african-republic
#
# But, wait, first:
#
# ### What is Fuzzy Matching?
#
# Automating the look-up for names in documents is [inherently imprecise](https://www.elastic.co/blog/found-fuzzy-search). The computer can't _know_ that different representations of the same _thing_ refer to the same _thing_. For example:
# - _Apple Inc._; _Apple Computer Company_; _Apple Computer, Inc._; and _Apple_ all refer to the fruit company.
# - _Samuel Langhorne Clemens_, _Samuel L. Clemens_, _Samuel Clemens_ and Mark Twain all refer to the same person.
# - _Robert Ford_, _Rob Ford_, and _Robert Frod_ refer to the same person **probably**.
#
# When you're working with unstructured data, you can't take anything for granted. Least of all, you can't assume that:
# - documents will have correct spellings
# - first, last, and middle names will exist in all documents
# - the abbreviated/shortened names of people won't make an appearance (e.g. Jon instead of Jonathan, Tom instead of Thomas, Phil instead of Philip, etc.)
#
# So, when you're living in an uncertain world, you try to make things slightly more _certain_ with **Fuzzy Matching**. You might not hit 100 percent, but at least you'll hit more than what you would without fuzzy matching.
#
# There are multiple algorithms that try to minimise the uncertainty/enable fuzzy matching. The library we are going to be look at today incorporates a bunch of these, instead of just doing one thing.
#
# This notebook's predominantly based on an [awesome NICAR2019 presentation](https://docs.google.com/presentation/d/1djKgqFbkYDM8fdczFhnEJLwapzmt4RLuEjXkJZpKves/) where Max Harlow (the aforementioned news app developer at the Financial Times) demonstrated [csvmatch](https://github.com/maxharlow/csvmatch). And, then, Soma basically created a library to make it with Pandas.
#
# Worth remembering that there are no shortcuts in life, and few panaceas. Depending on the project you're working on, you might be more inclined to use one algorithm or the other. Or, you know, try a few of them and see what happens. And, also, remember: all computational tools you use need to hand-in-hand with traditional reporting. People share names, there's more than one John Smith, etc.

# %%
# Make sure you `pip install fuzzy_pandas` first. 

import pandas as pd
import fuzzy_pandas as fpd

# %% [markdown]
# ### A Toy Example
#
# We'll be working with two toy datasets first, just to get going and get an idea as to what's possible. The names of the files are not terribly imaginative: `data1.csv` and `data2.csv`. And, they both contain structured data: names, code names and locations of characters from John le Carré's spy thriller: Tinker Tailor Soldier Spy.
#
# Right, let's have a look.

# %%
df1 = pd.read_csv("data/data1.csv")
df2 = pd.read_csv("data/data2.csv")

# %%
df1.sort_values("name")
# Out:
#              name  location   codename
# 5     Bill Haydon    London     Tailor
# 8    Connie Sachs    Oxford       none
# 0   George Smiley    London  Beggerman
# 7    Jim Prideaux  Slovakia       none
# 6    Oliver Lacon    London       none
# 1  Percy Alleline    London     Tinker
# 4   Peter Guillam   Brixton       none
# 2       Roy Bland    London    Soldier
# 3  Toby Esterhase    Vienna    Poorman

# %%
df2.sort_values("Person Name")
# Out:
#                   Person Name Location
# 8           Claus Kretzschmar  Hamburg
# 2               George SMILEY   London
# 4                  Konny Saks   Oxford
# 0  Maria Andreyevna Ostrakova   Russia
# 1                Otto Leipzig  Estonia
# 3               Peter Guillam  Brixton
# 6                 Sam Collins  Vietnam
# 5                Saul Enderby   London
# 7              Tony Esterhase   Vienna

# %% [markdown]
# ### Exact matches
#
# We start with doing "exact matches", i.e. both tables should have the exact same name. Capitalisation matters, accents matter. With this function, for example:
# - John le Carre will not match with John le Carré
# - George SMILEY will not match with George Smiley
#
# Based on what you see in the data frames above, how many matches do you expect?

# %%
fpd.fuzzy_merge(df1, df2, left_on='name', right_on='Person Name')
# Out:
#             name location codename    Person Name Location
# 0  Peter Guillam  Brixton     none  Peter Guillam  Brixton

# %% [markdown]
# Right, so, we only find one match as expected. But, are there any other matches that a _smarter_ algorithm could find? Let's try something called **Levenshtein**, a nifty simple algorithm that's pretty common. It's the basis for a bunch of spellcheck algorithms, amongst other things, and the way it works is it checks the number of characters that are different between two inputs, and if the _distance_ is small enough, it assumes the two words are the same.
#
# For example, in the above two data frames, you have Toby Esterhase and Tony Esterhase, which means the Levenshtein distance is 1 (The 'b' v. 'n' in To(b,n)y.).

# %%
fpd.fuzzy_merge(df1, df2, left_on='name', right_on='Person Name', method='levenshtein')
# Out:
#              name location   codename     Person Name Location
# 0   George Smiley   London  Beggerman   George SMILEY   London
# 1  Toby Esterhase   Vienna    Poorman  Tony Esterhase   Vienna
# 2   Peter Guillam  Brixton       none   Peter Guillam  Brixton

# %% [markdown]
# The other thing you'll notice above is that, by default, the _Levenshtein_ algorithm doesn't care about case.
#
# However, are we still missing potential matches?
#
# When we work with any algorithms, we need a confidence threshold that we decide on. By default, the `csvmatch` algorithm has a `threshold` of 0.6, i.e. only if the algorithm returns a match score greater than or equal to 0.6 will it return a match.
#
# The score, in this case, is calculated using the below formula:
#
# > `1 - (distance/maximum(value1, value2))`
#
# We can be slightly more conservative with the threshold, and we get a Brand New Result in our output.

# %%
fpd.fuzzy_merge(df1, df2, left_on='name', right_on='Person Name', method='levenshtein', threshold=0.5)
# Out:
#              name location   codename     Person Name Location
# 0   George Smiley   London  Beggerman   George SMILEY   London
# 1  Toby Esterhase   Vienna    Poorman  Tony Esterhase   Vienna
# 2   Peter Guillam  Brixton       none   Peter Guillam  Brixton
# 3    Connie Sachs   Oxford       none      Konny Saks   Oxford

# %% [markdown]
# This is _cool_. By changing the threshold, we found another match based on what the pronunciation of the two names are: Connie and Konny. **But, what could be cooler?**

# %%
fpd.fuzzy_merge(df1, df2, left_on='name', right_on='Person Name', method='metaphone')
# Out:
#             name location   codename    Person Name Location
# 0  George Smiley   London  Beggerman  George SMILEY   London
# 1  Peter Guillam  Brixton       none  Peter Guillam  Brixton
# 2   Connie Sachs   Oxford       none     Konny Saks   Oxford

# %% [markdown]
# The **metaphone** algorithm does phonetic matching, and gives you results based on that.
#
# Note: In theory, the documentation says that you can combine a couple of these algorithms if you're so inclined. But, it looks like when you combine two algorithms, it doesn't _quite_ work. ¯\_(ツ)_/¯

# %%
fpd.fuzzy_merge(df1, df2, left_on='name', right_on='Person Name', method=['levenshtein', 
                                                                          'metaphone'])

## swap the methods around and then look at the results, too.
# Out:
#              name location   codename     Person Name Location
# 0   George Smiley   London  Beggerman   George SMILEY   London
# 1  Toby Esterhase   Vienna    Poorman  Tony Esterhase   Vienna
# 2   Peter Guillam  Brixton       none   Peter Guillam  Brixton

# %% [markdown]
# What do you think is happening here?
#
# This is important—you're often going to be using tools built by other folks, but where there's code, there are bugs. You should make sure that you play with the tool a bit to make sure it's doing _exactly_ what you think it's doing. And, if it's not, you know where it falls short.

# %% [markdown]
# ### Less Fictional Datasets
#
# We are going to be using the same datasets Max Harlow used for this exercise. As he explains in his presentation [here](https://docs.google.com/presentation/d/1djKgqFbkYDM8fdczFhnEJLwapzmt4RLuEjXkJZpKves/edit#slide=id.g3512a0ce6b_1_22), there are a bunch of files:
# - a list of world billionaires published by Bloomberg
# - a similar list published by Forbes
# - a list also published by Forbes that only includes Chinese individuals
# - a list published by the CIA of chiefs of state and cabinet members of foreign governments
# - a list of all the people that attended the World Economic Forum conference in Davos this year
# - a list of all the people and companies that have been sanctioned by the United Nations

# %%
## Read in the two billionaire lists (Forbes + Bloomberg)

df1 = pd.read_csv("data/forbes-billionaires.csv")
df2 = pd.read_csv("data/bloomberg-billionaires.csv")

# %% [markdown]
# Can you find out how many billionaires appear in both lists (exact matching)?

# %%
df1.sample(30)
# Out:
#                                  name                lastName  \
# 1820                  Clayton Riddell                 Riddell
# 669                     Sheldon Solow                   Solow
# 472                      Andrei Skoch                   Skoch
# 1102              Caroline Hagen Kjos              Hagen Kjos
# 2150                     Satish Mehta                   Mehta
# 1449                      James Dinan                   Dinan
# 1107                 Guenther Lehmann                 Lehmann
# 466                    Richard Kinder                  Kinder
# 966                Jean-Pierre Cayard                  Cayard
# 1172               Radhakishan Damani                  Damani
# 613                       Lu Zhiqiang                      Lu
# 1666                    David Einhorn                 Einhorn
# 898                       Lottie Tham                    Tham
# 384                  Alain Wertheimer              Wertheimer
# 1747      Joao Alves de Queiroz Filho  Alves de Queiroz Filho
# 1975                     Gleb Fetisov                 Fetisov
# 236            Vinod & Anil Rai Gupta                   Gupta
# 142                       Lee Joon-ho                     Lee
# 1156  Julio Mario Santo Domingo, III.           Santo Domingo
# 358                       Harold Hamm                    Hamm
# 932                   Clifford Asness                  Asness
# 2290            Albert Shigaboutdinov          Shigaboutdinov
# 257                      Zeng Fangqin                    Zeng
# 325                         Ray Dalio                   Dalio
# 2283                    Erik Paulsson                Paulsson
# 2094                     Arnold Clark                   Clark
# 1084                        Zhang Jin                   Zhang
# 2064                      Zhou Guohui                    Zhou
# 783                   Hussain Sajwani                 Sajwani
# 746                 Stephen Bisciotti               Bisciotti
#
#                                 uri                       imageUri  \
# 1820                clayton-riddell                         no-pic
# 669                   sheldon-solow                  sheldon-solow
# 472                    andrei-skoch                   andrei-skoch
# 1102            caroline-hagen-kjos            caroline-hagen-kjos
# 2150                   satish-mehta                   satish-mehta
# 1449                    james-dinan                    james-dinan
# 1107               guenther-lehmann                         no-pic
# 466                  richard-kinder                 richard-kinder
# 966              jean-pierre-cayard                         no-pic
# 1172             radhakishan-damani                         no-pic
# 613                     lu-zhiqiang                    lu-zhiqiang
# 1666                  david-einhorn                  david-einhorn
# 898                     lottie-tham                  no-pic-female
# 384                alain-wertheimer               alain-wertheimer
# 1747    joao-alves-de-queiroz-filho                         no-pic
# 1975                   gleb-fetisov                   gleb-fetisov
# 236            vinod-anil-rai-gupta           vinod-anil-rai-gupta
# 142                     lee-joon-ho                    lee-joon-ho
# 1156  julio-mario-santo-domingo-iii  julio-mario-santo-domingo-iii
# 358                     harold-hamm                    harold-hamm
# 932                 clifford-asness                         no-pic
# 2290          albert-shigaboutdinov          albert-shigaboutdinov
# 257                    zeng-fangqin                  no-pic-female
# 325                       ray-dalio                      ray-dalio
# 2283                  erik-paulsson                         no-pic
# 2094                   arnold-clark                         no-pic
# 1084                      zhang-jin                         no-pic
# 2064                    zhou-guohui                    zhou-guohui
# 783                 hussain-sajwani                hussain-sajwani
# 746               stephen-bisciotti              stephen-bisciotti
#
#       worthChange                      source                 industry gender  \
# 1820          NaN                   oil & gas                   Energy      M
# 669         0.000                 real estate              Real Estate      M
# 472         0.000                       steel          Metals & Mining      M
# 1102        0.490                conglomerate              Diversified      F
# 2150        0.000             pharmaceuticals               Healthcare      M
# 1449        0.000                 hedge funds  Finance and Investments      M
# 1107        0.000                  drugstores         Fashion & Retail      M
# 466        24.680                   pipelines                   Energy      M
# 966         0.000                     spirits        Food and Beverage      M
# 1172       -3.327         investments, retail  Finance and Investments      M
# 613        47.448                 real estate              Real Estate      M
# 1666       -0.500                 hedge funds  Finance and Investments      M
# 898        -8.712                         H&M         Fashion & Retail      F
# 384         0.000                      Chanel         Fashion & Retail      M
# 1747        2.248             pharmaceuticals              Diversified      M
# 1975        0.000                 investments                  Telecom      M
# 236       -21.950        electrical equipment            Manufacturing    NaN
# 142        11.461                online games               Technology      M
# 1156        7.165                        beer        Food and Beverage      M
# 358       116.634                   oil & gas                   Energy      M
# 932         0.000       Investment Management  Finance and Investments      M
# 2290        0.795         refinery, chemicals              Diversified      M
# 257        81.048       smartphone components               Technology      F
# 325         0.000                 hedge funds  Finance and Investments      M
# 2283        0.826   construction, real estate              Real Estate      M
# 2094          NaN    Arnold Clark Automobiles               Automotive      M
# 1084        0.000                 diversified              Diversified      M
# 2064          NaN                   logistics                Logistics      M
# 783      -167.658                 real estate              Real Estate      M
# 746         0.000  staffing, Baltimore Ravens                   Sports      M
#
#                    country      timestamp  realTimeWorth  realTimeRank  \
# 1820                Canada  1521466410439            NaN           NaN
# 669          United States  1547575201867       5163.850         324.0
# 472                 Russia  1547574901333       4582.297         399.0
# 1102                Norway  1547574901333       2253.529        1015.0
# 2150                 India  1547574901334       1005.719        1998.0
# 1449         United States  1547574901333       2176.000        1056.0
# 1107               Germany  1547574901334       1913.345        1199.0
# 466          United States  1547575201867       6485.505         234.0
# 966                 France  1547574901333       4144.414         469.0
# 1172                 India  1547575201867      10677.728         130.0
# 613                  China  1547574901333       3597.068         580.0
# 1666         United States  1547574901334       1310.361        1655.0
# 898                 Sweden  1547574901333       2214.740        1041.0
# 384                 France  1547575201866      13074.286          94.0
# 1747                Brazil  1547574901334       1807.076        1252.0
# 1975                Russia  1547574901334       1211.000        1759.0
# 236                  India  1547574901333       2649.596         833.0
# 142            South Korea  1547574901334       1066.986        1938.0
# 1156         United States  1547574901334       1661.916        1345.0
# 358          United States  1547575201866      13478.995          88.0
# 932          United States  1547574901333       3600.000         577.0
# 2290                Russia  1547574901334       1192.356        1790.0
# 257                  China  1547574901334       1851.627        1225.0
# 325          United States  1547575201866      18100.000          57.0
# 2283                Sweden  1547574901334       1555.037        1429.0
# 2094        United Kingdom  1518126146636            NaN           NaN
# 1084                 China  1547574901333       4580.645         400.0
# 2064                 China  1518126091386            NaN           NaN
# 783   United Arab Emirates  1547574901334       1761.074        1278.0
# 746          United States  1547574901333       4084.876         483.0
#
#       realTimePosition                                        squareImage
# 1820               NaN  //specials-images.forbesimg.com/imageserve/5a7...
# 669              324.0  //specials-images.forbesimg.com/imageserve/5ba...
# 472              399.0  //specials-images.forbesimg.com/imageserve/5a8...
# 1102            1015.0  //specials-images.forbesimg.com/imageserve/58a...
# 2150            1998.0  http://specials-images.forbesimg.com/imageserv...
# 1449            1056.0  //specials-images.forbesimg.com/imageserve/5ba...
# 1107            1199.0                                                NaN
# 466              234.0  //specials-images.forbesimg.com/imageserve/5ba...
# 966              469.0  //specials-images.forbesimg.com/imageserve/58c...
# 1172             130.0  //specials-images.forbesimg.com/imageserve/59d...
# 613              580.0  //specials-images.forbesimg.com/imageserve/5bc...
# 1666            1655.0  //specials-images.forbesimg.com/imageserve/5a9...
# 898             1041.0  //specials-images.forbesimg.com/imageserve/5a8...
# 384               94.0  //specials-images.forbesimg.com/imageserve/5a7...
# 1747            1252.0                                                NaN
# 1975            1759.0  //specials-images.forbesimg.com/imageserve/5a8...
# 236              833.0  //specials-images.forbesimg.com/imageserve/57d...
# 142             1938.0  //specials-images.forbesimg.com/imageserve/11c...
# 1156            1345.0  //specials-images.forbesimg.com/imageserve/57e...
# 358               88.0  //specials-images.forbesimg.com/imageserve/5ba...
# 932              577.0  //specials-images.forbesimg.com/imageserve/58c...
# 2290            1790.0  //specials-images.forbesimg.com/imageserve/5a8...
# 257             1225.0                                                NaN
# 325               57.0  //specials-images.forbesimg.com/imageserve/5ba...
# 2283            1429.0  //specials-images.forbesimg.com/imageserve/5a8...
# 2094               NaN  //specials-images.forbesimg.com/imageserve/58a...
# 1084             400.0                                                NaN
# 2064               NaN  //specials-images.forbesimg.com/imageserve/56c...
# 783             1278.0  //specials-images.forbesimg.com/imageserve/56d...
# 746              483.0  //specials-images.forbesimg.com/imageserve/5ba...

# %%
df2.sample(30)
# Out:
#      Rank                          Name Total_net_worth             Country  \
# 29     30                   Elon R Musk          $25.5B       United States
# 36     37              Leonid Mikhelson          $20.1B  Russian Federation
# 368   369            Thomas Kristiansen          $4.58B             Denmark
# 365   366             Whitney MacMillan          $4.58B       United States
# 155   156                     Xu Shihui          $8.46B               China
# 10     11  Francoise Bettencourt Meyers          $45.5B              France
# 172   173                  Stan Kroenke          $8.04B       United States
# 363   364             Agnete Thinggaard          $4.59B             Denmark
# 395   396                     Bob Kraft          $4.36B       United States
# 147   148               Carlos Sicupira          $9.02B              Brazil
# 235   236                 Patrick Drahi          $6.38B              France
# 80     81                John Menard Jr          $13.7B       United States
# 208   209                  Gong Hongjia          $6.89B               China
# 66     67                Leonard Lauder          $14.8B       United States
# 226   227                    Frank Wang          $6.42B               China
# 231   232                  Seo Jung-Jin          $6.41B  Korea, Republic of
# 339   340             Trevor Rees-Jones          $4.75B       United States
# 271   272                  Henry Kravis          $5.68B       United States
# 33     34            Jorge Paulo Lemann          $21.3B              Brazil
# 55     56               Thomas Peterffy          $16.5B       United States
# 494   495                  Sergei Popov          $3.73B  Russian Federation
# 201   202                Gustaf Douglas          $7.04B              Sweden
# 109   110                  Hans Rausing          $11.4B              Sweden
# 423   424              Sumet Jiaravanon          $4.17B            Thailand
# 416   417                 Maja Hoffmann          $4.23B         Switzerland
# 280   281                  John Paulson          $5.48B       United States
# 439   440                 Jeremy Jacobs          $4.09B       United States
# 334   335                  Francis Choi          $4.78B           Hong Kong
# 164   165                    Joseph Lau          $8.30B           Hong Kong
# 59     60                  Lukas Walton          $15.6B       United States
#
#             Industry
# 29        Technology
# 36            Energy
# 368         Consumer
# 365      Commodities
# 155  Food & Beverage
# 10          Consumer
# 172      Real Estate
# 363         Consumer
# 395    Entertainment
# 147  Food & Beverage
# 235  Media & Telecom
# 80            Retail
# 208       Technology
# 66          Consumer
# 226       Technology
# 231      Health Care
# 339           Energy
# 271          Finance
# 33   Food & Beverage
# 55           Finance
# 494      Diversified
# 201      Diversified
# 109      Diversified
# 423      Diversified
# 416      Health Care
# 280          Finance
# 439  Food & Beverage
# 334      Real Estate
# 164      Real Estate
# 59            Retail

# %%
results = fpd.fuzzy_merge(df1, df2, left_on='name', right_on='Name')

print("Found", results.shape)
results.head(5)
# Out:
# Found (354, 19)
#                name   lastName               uri imageUri  worthChange  \
# 0    Alexander Otto       Otto    alexander-otto   no-pic        2.120
# 1     Ben Ashkenazy  Ashkenazy     ben-ashkenazy   no-pic        0.000
# 2  Giovanni Ferrero    Ferrero  giovanni-ferrero   no-pic        0.000
# 3       Henry Cheng      Cheng     henry-cheng-1   no-pic        3.542
# 4      Henry Laufer     Laufer      henry-laufer   no-pic        0.000
#
#                 source                 industry gender        country  \
# 0          real estate              Real Estate      M        Germany
# 1          real estate              Real Estate      M  United States
# 2  Nutella, chocolates        Food and Beverage      M          Italy
# 3             property              Diversified      M      Hong Kong
# 4          hedge funds  Finance and Investments      M  United States
#
#        timestamp  realTimeWorth  realTimeRank  realTimePosition  \
# 0  1547575201867      10821.927         126.0             126.0
# 1  1547574901333       4000.000         499.0             499.0
# 2  1547575201866      22673.165          38.0              38.0
# 3  1547574901334       1334.282        1630.0            1630.0
# 4  1547574901333       2000.000        1141.0            1142.0
#
#                                          squareImage  Rank              Name  \
# 0  //specials-images.forbesimg.com/imageserve/5a7...   323    Alexander Otto
# 1  //specials-images.forbesimg.com/imageserve/59e...   447     Ben Ashkenazy
# 2  //specials-images.forbesimg.com/imageserve/5b1...    33  Giovanni Ferrero
# 3  //specials-images.forbesimg.com/imageserve/5a7...    79       Henry Cheng
# 4                                                NaN   463      Henry Laufer
#
#   Total_net_worth        Country         Industry
# 0          $4.94B        Germany      Real Estate
# 1          $4.05B  United States      Real Estate
# 2          $22.6B          Italy  Food & Beverage
# 3          $14.1B      Hong Kong           Retail
# 4          $3.95B  United States          Finance

# %% [markdown]
# Now, can you find the ones where the ranks aren't the same across the two datasets? What about the ones that are the same?

# %%
results = fpd.fuzzy_merge(df1, df2, left_on='name', right_on='Name', 
                          keep_left=["realTimeRank", "name"], 
                          keep_right=["Rank"])
results[results.realTimeRank == results.Rank]
# Out:
#      realTimeRank              name  Rank
# 13            2.0        Bill Gates     2
# 14            3.0    Warren Buffett     3
# 15            1.0        Jeff Bezos     1
# 21            4.0   Bernard Arnault     4
# 23           10.0       Sergey Brin    10
# 27           23.0   Sheldon Adelson    23
# 37           17.0     Mukesh Ambani    17
# 47           54.0     Stefan Quandt    54
# 88          135.0     Aliko Dangote   135
# 131         177.0  Cyrus Poonawalla   177
# 149         139.0      Gordon Moore   139
# 204         235.0      Ralph Lauren   235

# %% [markdown]
# ### Fuzzy matching with non-fictional data
#
# In the above couple of cells, we've conducted "exact matching", i.e. the equivalent of you running a `Cmd+F`/`Ctrl+F` on your text editor. But, this is _almost_ worse as it's case sensitive, i.e. "Tom" and "tom" are treated differently.
#
# We've gone through some of this already, but what are the things we can ignore when it comes to name-matching? Harlow, in his presentation, identified:
# - case
# - title (Mr., Mrs., etc.)
# - non-latin characters (é, å, ß, etc.)
# - the order of the names
# - non-alphanumerics (e.g. hyphenated names)
#
# Now, you don't _have to_ ignore _anything_, but sometimes, it might make your life far easier. Other times, you'll end up with false positives and whatnot.
#
# The library `csvmatch`—and by extension `fuzzy_pandas`—support a bunch of the above parameters, which you can just pass in to the function. Passing in a bunch of these parameters would allow you to go from `Orbán, Viktor` to `Viktor Orban`, which is quite useful. (Again, the example's from Harlow's slides)
#
# For this bit, we'll move on to two of the other datasets: `cia-world-leaders.csv` and `davos-attendees-2019.csv`. As always, read in the data and figure out which columns the exact match should run on.

# %%
cia_world_leaders = pd.read_csv('data/cia-world-leaders.csv')
davos_attendees = pd.read_csv('data/davos-attendees-2019.csv')
print(f"Our CIA World Leaders df has these columns: {cia_world_leaders.columns} \
      \n The Davos attendees have these: {davos_attendees.columns}")
# Out:
# Our CIA World Leaders df has these columns: Index(['country', 'role', 'name'], dtype='object')
#  The Davos attendees have these: Index(['full_name', 'position_short_name', 'org_name', 'org_country'], dtype='object')

# %%
cia_world_leaders.sort_values('name').head(20)
# Out:
#                    country                                               role  \
# 384             Bangladesh                            Min. of Foreign Affairs
# 499                 Belize                             Governor, Central Bank
# 4721               Somalia              Min. of Public Works & Reconstruction
# 4451          Saudi Arabia                                   Min. of Interior
# 2625                Jordan                                               King
# 4193                 Qatar                                        Deputy Amir
# 4213                 Qatar                                         Prime Min.
# 4205                 Qatar                                   Min. of Interior
# 4194                 Qatar                       Governor, Qatar Central Bank
# 5482  United Arab Emirates  Min. of Foreign Affairs and International Coop...
# 5487  United Arab Emirates                 Min. of Infrastructure Development
# 1809              Ethiopia                                         Prime Min.
# 1732               Eritrea                               Min. of Public Works
# 4891                 Sudan                      Min. of Guidance & Endowments
# 1799              Ethiopia                                    Min. of Revenue
# 5139              Thailand                                      Min. of Labor
# 394             Bangladesh                                   Min. of Planning
# 366                Bahrain      Min. of the Royal Court for Follow-Up Affairs
# 4199                 Qatar                            Min. of Economy & Trade
# 353                Bahrain                                    Min. of Finance
#
#                                                    name
# 384                                   A. H. Mahmood ALI
# 499                                        A. Joy GRANT
# 4721                     ABAS Abdullahi Sheikh "Siraji"
# 4451  ABD AL-AZIZ bin Saud bin Nayif bin Abd al-Aziz...
# 2625                                        ABDALLAH II
# 4193                        ABDALLAH bin Hamad Al Thani
# 4213            ABDALLAH bin Nasir bin Khalifa Al Thani
# 4205            ABDALLAH bin Nasir bin Khalifa Al Thani
# 4194                         ABDALLAH bin Saud Al Thani
# 5482                     ABDALLAH bin Zayid Al Nuhayyan
# 5487             ABDULLAH bin Muhammad Belhaf al-Nuaymi
# 1809                                         ABIY Ahmed
# 1732                                      ABRAHA Asfaha
# 4891                            ABU-BAKR Uthman Ibrahim
# 1799                                      ADANECH Abebe
# 5139                      ADUN Saengsingkaew, Pol. Gen.
# 394                                   AHM Mostafa KAMAL
# 366                    AHMAD BIN ATIYATALLAH Al Khalifa
# 4199              AHMAD bin Jasim bin Muhammad Al Thani
# 353   AHMAD bin Muhammad bin Hamad bin Abdallah Al K...

# %%
davos_attendees.sort_values('full_name').head(20)
# Out:
#                           full_name  \
# 1864                 Aaron Karczmer
# 2532               Aaron Motsoaledi
# 422              Aarthi Subramanian
# 2074            Abdelkader Messahel
# 897            Abdulaziz Al Judaimi
# 888            Abdulaziz Al Subeaei
# 35            Abdulaziz Al-Helaissi
# 903             Abdulaziz Al-Jarbou
# 2641               Abdulla Al Basti
# 809              Abdulla Al Khalifa
# 1228             Abdulla Bin Desmal
# 804   Abdulla Bin Mohammed Al Thani
# 2638               Abdulla Bin Touq
# 2660          Abdulla Nasser Lootah
# 2071              Abdullah Abdullah
# 895          Abdulmajeed Al Mobarak
# 663                Abdulsamad Rabiu
# 2428                     Abeer Odeh
# 2297               Abha Joshi-Ghani
# 695                       Abid Butt
#
#                                     position_short_name  \
# 1864  Executive Vice-President; Chief Risk, Complian...
# 2532                 Minister of Health of South Africa
# 422              Executive Director, Board of Directors
# 2074             Minister of Foreign Affairs of Algeria
# 897                   Senior Vice-President, Downstream
# 888                                            Chairman
# 35                  Group Chief Executive Officer (GIB)
# 903                               Chairman of the Board
# 2641  General Secretary, Executive Council of Dubai,...
# 809                             Chief Executive Officer
# 1228                    Director, Commercial Operations
# 804                                            Chairman
# 2638  Secretary-General, Cabinet of the United Arab ...
# 2660  Director-General, Federal Competitiveness and ...
# 2071  Chief Executive of the Islamic Republic of Afg...
# 895                             Chief Executive Officer
# 663                Chairman and Chief Executive Officer
# 2428  Minister of National Economy of the Palestinia...
# 2297  Senior Adviser, Infrastructure, Public- Privat...
# 695                             Chief Executive Officer
#
#                                                org_name  \
# 1864                                             PayPal
# 2532                 Ministry of Health of South Africa
# 422                           Tata Consultancy Services
# 2074             Ministry of Foreign Affairs of Algeria
# 897                                        Saudi Aramco
# 888                     Jabal Omar Development Company
# 35                          Gulf International Bank BSC
# 903                 Saudi Basic Industries Corporation
# 2641                         Executive Council of Dubai
# 809                        Qatar National Bank Q.P.S.C.
# 1228                                   DP World Limited
# 804                                             Ooredoo
# 2638                Cabinet of the United Arab Emirates
# 2660  The Federal Competitiveness and Statistics Aut...
# 2071                             Afghanistan Government
# 895                                          Riyad Bank
# 663                                           BUA Group
# 2428  Ministry of National Economy of the Palestinia...
# 2297                                     The World Bank
# 695                         e2e Supply Chain Management
#
#                   org_country
# 1864                      USA
# 2532             South Africa
# 422                     India
# 2074                  Algeria
# 897              Saudi Arabia
# 888              Saudi Arabia
# 35                    Bahrain
# 903              Saudi Arabia
# 2641     United Arab Emirates
# 809                     Qatar
# 1228     United Arab Emirates
# 804                     Qatar
# 2638     United Arab Emirates
# 2660     United Arab Emirates
# 2071              Afghanistan
# 895              Saudi Arabia
# 663                   Nigeria
# 2428  Palestinian Territories
# 2297                      INT
# 695                  Pakistan

# %%
# Let's start by seeing what an exact match would look like. 
results = fpd.fuzzy_merge(cia_world_leaders, davos_attendees, left_on='name', right_on='full_name')

# %% [markdown]
# Apparently, there are no matches. What do you reckon? What _should_ the overlap between CIA's list of world leaders and Davos attendees be?
#
# Let's try some _fuzzy matching_.

# %%
results = fpd.fuzzy_merge(cia_world_leaders, davos_attendees, left_on='name', 
                          right_on='full_name', 
                          ignore_case=True)

# %%
print(results.shape)
results
# Out:
# (119, 7)
#             country                                               role  \
# 0           Algeria  Min. of Foreign Affairs & International Cooper...
# 1         Argentina                          Min. of Production & Work
# 2         Argentina                                Pres., Central Bank
# 3           Armenia                                         Prime Min.
# 4         Australia                          Min. for Defense Industry
# ..              ...                                                ...
# 114  United Kingdom  Sec. of State for Intl. Trade & President of t...
# 115         Vietnam                           Min. of Industry & Trade
# 116         Vietnam            Min. of Natural Resources & Environment
# 117         Vietnam                                         Prime Min.
# 118        Zimbabwe             Min. of Finance & Economic Development
#
#                     name            full_name  \
# 0    Abdelkader MESSAHEL  Abdelkader Messahel
# 1             Dante SICA           Dante Sica
# 2        Guido SANDLERIS      Guido Sandleris
# 3        Nikol PASHINYAN      Nikol Pashinyan
# 4           Steven CIOBO         Steven Ciobo
# ..                   ...                  ...
# 114             Liam FOX             Liam Fox
# 115        Tran Tuan ANH        Tran Tuan Anh
# 116         Tran Hong HA         Tran Hong Ha
# 117     Nguyen Xuan PHUC     Nguyen Xuan Phuc
# 118         Mthuli NCUBE         Mthuli Ncube
#
#                                    position_short_name  \
# 0               Minister of Foreign Affairs of Algeria
# 1         Minister of Industry and Labour of Argentina
# 2            Governor of the Central Bank of Argentina
# 3            Prime Minister of the Republic of Armenia
# 4            Minister of Defence Industry of Australia
# ..                                                 ...
# 114  Secretary of State for International Trade of ...
# 115         Minister of Industry and Trade of Viet Nam
# 116  Minister of Natural Resources and Environment ...
# 117                         Prime Minister of Viet Nam
# 118  Minister of Finance and Economic Development o...
#
#                                               org_name     org_country
# 0               Ministry of Foreign Affairs of Algeria         Algeria
# 1         Ministry of Industry and Labour of Argentina       Argentina
# 2                            Central Bank of Argentina       Argentina
# 3    Office of the Prime Minister of the Republic o...         Armenia
# 4                   Department of Defence of Australia       Australia
# ..                                                 ...             ...
# 114                 Department for International Trade  United Kingdom
# 115         Ministry of Industry and Trade of Viet Nam        Viet Nam
# 116  Ministry of Natural Resources and Environment ...        Viet Nam
# 117               Office of the Government of Viet Nam        Viet Nam
# 118  Ministry of Finance and Economic Development o...        Zimbabwe
#
# [119 rows x 7 columns]

# %% [markdown]
# OK, we have more matches, but this is also pretty boring. There's nothing super-smart about ignoring cases to get matches. Your word processors have been doing that for _decades_.
#
# But, now, let's start adding some of our other parameters discussed above, and see what happens

# %%
results = fpd.fuzzy_merge(cia_world_leaders, davos_attendees, left_on='name', 
                          right_on='full_name', 
                          ignore_case=True, 
                          ignore_nonalpha=True,
                          ignore_nonlatin=True,
                          ignore_order_words=True,
                          ignore_titles=True,
                         )

# %%
print(results.shape)
results
# Out:
# (138, 7)
#             country                                               role  \
# 0           Algeria  Min. of Foreign Affairs & International Cooper...
# 1         Argentina                          Min. of Production & Work
# 2         Argentina                         Min. of Treasury & Finance
# 3         Argentina                                Pres., Central Bank
# 4           Armenia                                         Prime Min.
# ..              ...                                                ...
# 133  United Kingdom  Sec. of State for Intl. Trade & President of t...
# 134         Vietnam                           Min. of Industry & Trade
# 135         Vietnam            Min. of Natural Resources & Environment
# 136         Vietnam                                         Prime Min.
# 137        Zimbabwe             Min. of Finance & Economic Development
#
#                     name            full_name  \
# 0    Abdelkader MESSAHEL  Abdelkader Messahel
# 1             Dante SICA           Dante Sica
# 2        Nicolas DUJOVNE      Nicolás Dujovne
# 3        Guido SANDLERIS      Guido Sandleris
# 4        Nikol PASHINYAN      Nikol Pashinyan
# ..                   ...                  ...
# 133             Liam FOX             Liam Fox
# 134        Tran Tuan ANH        Tran Tuan Anh
# 135         Tran Hong HA         Tran Hong Ha
# 136     Nguyen Xuan PHUC     Nguyen Xuan Phuc
# 137         Mthuli NCUBE         Mthuli Ncube
#
#                                    position_short_name  \
# 0               Minister of Foreign Affairs of Algeria
# 1         Minister of Industry and Labour of Argentina
# 2                Minister of the Treasury of Argentina
# 3            Governor of the Central Bank of Argentina
# 4            Prime Minister of the Republic of Armenia
# ..                                                 ...
# 133  Secretary of State for International Trade of ...
# 134         Minister of Industry and Trade of Viet Nam
# 135  Minister of Natural Resources and Environment ...
# 136                         Prime Minister of Viet Nam
# 137  Minister of Finance and Economic Development o...
#
#                                               org_name     org_country
# 0               Ministry of Foreign Affairs of Algeria         Algeria
# 1         Ministry of Industry and Labour of Argentina       Argentina
# 2                Ministry of the Treasury of Argentina       Argentina
# 3                            Central Bank of Argentina       Argentina
# 4    Office of the Prime Minister of the Republic o...         Armenia
# ..                                                 ...             ...
# 133                 Department for International Trade  United Kingdom
# 134         Ministry of Industry and Trade of Viet Nam        Viet Nam
# 135  Ministry of Natural Resources and Environment ...        Viet Nam
# 136               Office of the Government of Viet Nam        Viet Nam
# 137  Ministry of Finance and Economic Development o...        Zimbabwe
#
# [138 rows x 7 columns]

# %% [markdown]
# Right, 19 more results. Baby steps, but at least steps in the right direction. Now, let's start using the more _intelligent_ algorithms in place—this one named after a Russian mathematician: Levenshtein.
#
# All *Levenshtein* does is look at how many characters are different between two inputs? For example:

# %%
from jellyfish._jellyfish import damerau_levenshtein_distance

damerau_levenshtein_distance("Évry", "Every")
# Out:
# 2

# %% [markdown]
# Let's quickly use the algorithm directly to see the output. The above cell imports something called `jellyfish`, which is another package that `csvmatch` uses. Typically, you wouldn't call the function directly (you could if you wanted to), but this is just to give you an idea of how the algorithm works.
#
# Right, now let's use this with our above data, and see if we have better luck.
#
# Remember: the threshold specified by us is 0.6, and it's calculated by: `1-(distance/max(value1, value2))`. In the case of `Évry` and `Every` above, our calculation would be:
#
# `1 - (2/5)` = `3/5` = `0.6`
#
# So, in this case, the two would lead to a fuzzy match.

# %%
results = fpd.fuzzy_merge(cia_world_leaders, davos_attendees, left_on='name', 
                          right_on='full_name', 
                          ignore_case=True, 
                          ignore_nonalpha=True,
                          ignore_nonlatin=True,
                          ignore_order_words=True,
                          ignore_titles=True,
                          method='levenshtein'
                         )

# %%
results.shape
# Out:
# (1952, 7)

# %% [markdown]
# **WAIT, WHAT?!** Have we just gone from 138 matches to 1952? Is that overtly optimistic?

# %%
results.sample(50)
# Out:
#                     country  \
# 112               Australia
# 1859         United Kingdom
# 1146                   Mali
# 1315            New Zealand
# 339                Cameroon
# 852                  Israel
# 877                   Japan
# 1682           South Africa
# 1228                 Monaco
# 524                 Czechia
# 963            Korea, North
# 1742            Switzerland
# 1487       Papua New Guinea
# 220                  Belize
# 624                  France
# 998            Korea, South
# 726                  Guyana
# 911                  Jordan
# 512                 Czechia
# 1811                 Uganda
# 1047                  Libya
# 1917                  Yemen
# 1940                 Zambia
# 1041                Liberia
# 991            Korea, North
# 1222                Moldova
# 1247             Mozambique
# 1299            Netherlands
# 1424                   Oman
# 370                  Canada
# 1833         United Kingdom
# 1890             Uzbekistan
# 1105                 Malawi
# 602                Ethiopia
# 648                   Gabon
# 349                  Canada
# 1137               Maldives
# 656             Gambia, The
# 1539                  Qatar
# 1565  Saint Kitts and Nevis
# 1200       Marshall Islands
# 955            Korea, North
# 1793                Tunisia
# 1880                Uruguay
# 979            Korea, North
# 1892             Uzbekistan
# 355                  Canada
# 1404                Nigeria
# 561      Dominican Republic
# 183                Barbados
#
#                                                    role  \
# 112            Min. for Industry, Science, & Technology
# 1859  Sec. of State for Environment, Food, & Rural A...
# 1146        Min. of Foreign Affairs & Intl. Cooperation
# 1315  Min. Responsible for the Government Communicat...
# 339                          Min. of National Education
# 852                           Min. of Strategic Affairs
# 877                                  Chief Cabinet Sec.
# 1682       Min. of Justice & Constitutional Development
# 1228       Permanent Representative to the UN, New York
# 524                             Min. of the Environment
# 963                               Member, SPA Presidium
# 1742                         Pres., Swiss Confederation
# 1487                    Min. for Works & Implementation
# 220                                Ambassador to the US
# 624                                     Min. of Culture
# 998   Min. of Science & ICT (Information & Communica...
# 726                               Min. of Public Health
# 911                                          Prime Min.
# 512                                     Dep. Prime Min.
# 1811                   Min. of State for Public Service
# 1047                                    Dep. Prime Min.
# 1917               Min. of Planning & Intl. Cooperation
# 1940               Min. of Mines & Minerals Development
# 1041             Min. of State for Presidential Affairs
# 991                               Vice Premier, Cabinet
# 1222     Min. of Foreign Affairs & European Integration
# 1247                 Min. of Transport & Communications
# 1299                                         Prime Min.
# 1424                Dep. Prime Min. for Cabinet Affairs
# 370      Min. of Public Safety & Emergency Preparedness
# 1833                         Chief Sec. to the Treasury
# 1890                                    Dep. Prime Min.
# 1105                                    Min. of Defense
# 602                             Min. of Foreign Affairs
# 648                                       Min. of State
# 349                   Leader of the Govt. in the Senate
# 1137         Min. of National Planning & Infrastructure
# 656        Permanent Representative to the UN, New York
# 1539                       Governor, Qatar Central Bank
# 1565  Min. of Tourism, Intl. Trade, Industry, & Comm...
# 1200                                    Min. of Justice
# 955                                         Member, SAC
# 1793                                         Prime Min.
# 1880                                    Min. of Defense
# 979        Permanent Representative to the UN, New York
# 1892                              Min. of Public Health
# 355   Min. of Border Security & Organized Crime Redu...
# 1404                                    Min. of Defense
# 561     Min. of Higher Education, Science, & Technology
# 183     Min. of the Creative Economy, Culture, & Sports
#
#                             name                           full_name  \
# 112                Karen ANDREWS                       Andrew Morlet
# 1859                Michael GOVE                    Michael Goltzman
# 1146              Kamissa CAMARA                          Mary Kawar
# 1315               Andrew LITTLE                         Andrea Illy
# 339                Alim YOUSSOUF                          Yusuff Ali
# 852                  Gilad ERDAN                       Brian Gilvary
# 877               Yoshihide SUGA                      Yoshihito Suda
# 1682             Michael MASUTHA                     Michael Latimer
# 1228              Isabelle PICCO                     Isabelle Kocher
# 524               Richard BRABEC                     Richard Baldwin
# 963                KIM Yong Chol                       Yong Hyun Kim
# 1742                Alain BERSET                       Alain Bejjani
# 1487                Michael NALI                        Michael Ryan
# 220              Daniel GUTIEREZ                       Daniel Glaser
# 624               Franck RIESTER                        Frank Roseen
# 998                YOU Young-min                        Youngmin Joo
# 726           George NORTON, Dr.                        George Soros
# 911               Omar al-RAZZAZ                    Eman Abdulrazzaq
# 512               Richard BRABEC                     Richard Ambrose
# 1811             David KARUBANGA                       David Nabarro
# 1047            Fathi al-MAJBARI                       Sami Alangari
# 1917         Muhammad al-MAYTAMI                  Mohammed Al-Jadaan
# 1940             Richard MUSUKWA                     Richard Hookway
# 1041             Clarence MONIBA                       Monica Flores
# 991                   RI Mu Yong                          Wong Ai Ai
# 1222           Tudor ULIANOVSCHI                   Tudor Ulianovschi
# 1247             Carlos MESQUITA                    Carlos M. Jarque
# 1299                  Mark RUTTE                          Mark Rutte
# 1424     FAHD bin Mahmud Al Said        Saeed bin Mohammed Al Ghamdi
# 370                Ralph GOODALE                        Jane Goodall
# 1833             Elizabeth TRUSS                      Elizabeth ODay
# 1890            Alisher SULTONOV                  Alisher B. Usmanov
# 1105             Peter MUTHARIKA                       Peter McBride
# 602             WORKNEH Gebeyehu             Workneh Gebeyehu Negewo
# 648              Denise MEKAM'NE                       Denis Mukwege
# 349                 Peter HARDER                       Peter Matlare
# 1137               Mohamed ASLAM                     Mohammad Jaafar
# 656                   Lang YABOU                             Long Yu
# 1539  ABDALLAH bin Saud Al Thani  Mohammed Bin  Abdulrahman Al Thani
# 1565               Lindsay GRANT                         Don Lindsay
# 1200                Thomas HEINE                       Thomas Aeschi
# 955                   RI Su Yong                            Qiu Yong
# 1793              Youssef CHAHED                      Youssef Chahed
# 1880              Jorge MENENDEZ                        Børge Brende
# 979                  JA Song Nam                         Song Juntao
# 1892           Alisher SHODMONOV                  Alisher B. Usmanov
# 355                William BLAIR                       William Burns
# 1404     Mansur Mohammed DAN-ALI              Mohammad Mansoor Akbar
# 561        Andres NAVARRO Garcia                Ignacio Garcia Alves
# 183                    John KING                          John Riady
#
#                                     position_short_name  \
# 112                             Chief Executive Officer
# 1859  Vice-President, Global Public Policy, Environm...
# 1146  Minister of Planning and International Coopera...
# 1315                                           Chairman
# 339                      Chairman and Managing Director
# 852                       Group Chief Financial Officer
# 877           Executive Officer, Chief Research Officer
# 1682                            Chief Executive Officer
# 1228                            Chief Executive Officer
# 524   Professor of International Economics, Graduate...
# 963                             Chief Executive Officer
# 1742                            Chief Executive Officer
# 1487                            Chief Executive Officer
# 220               President and Chief Executive Officer
# 624             Executive Director, Member of the Board
# 998                                   Growth Consultant
# 726                                            Chairman
# 911   Head, Strategy and Planning, Middle East, Nort...
# 512   Executive Vice-President, Space Systems System...
# 1811                                           Director
# 1047          Vice-Chairman and Chief Executive Officer
# 1917                Minister of Finance of Saudi Arabia
# 1940                 Chief Executive, Centrica Business
# 1041                           President, Latin America
# 991   Member, Global Executive Committee; Deputy Cha...
# 1222  Minister of Foreign Affairs and European Integ...
# 1247  Executive Director, International Affairs, Gov...
# 1299                  Prime Minister of the Netherlands
# 1424                                           Chairman
# 370                Founder, Jane Goodall Institute, USA
# 1833                Founder and Chief Executive Officer
# 1890                                            Founder
# 1105  National Geographic Explorer, National Geograp...
# 602             Minister of Foreign Affairs of Ethiopia
# 648              Founder, Panzi Hospital and Foundation
# 349                      Deputy Chief Executive Officer
# 1137               Chairman and Chief Executive Officer
# 656   Chief Human Resources Officer and General Counsel
# 1539  Deputy Prime Minister and Minister of Foreign ...
# 1565              President and Chief Executive Officer
# 1200  Member of the National Council, Swiss Parliame...
# 955                                           President
# 1793                          Prime Minister of Tunisia
# 1880            President; Member of the Managing Board
# 979   Global Head, International Business Affairs an...
# 1892                                            Founder
# 355                                           President
# 1404     Co-Founder, Bridge to Afghanistan, Afghanistan
# 561                Chairman and Chief Executive Officer
# 183                            Group Executive Director
#
#                                                org_name  \
# 112                          Ellen MacArthur Foundation
# 1859                              The Coca-Cola Company
# 1146             Office of the Prime Minister of Jordan
# 1315                                      illycaffè SpA
# 339                        Lulu Group International LLC
# 852                                              BP Plc
# 877                            Suntory Holdings Limited
# 1682                   OMERS Administration Corporation
# 1228                                        ENGIE Group
# 524   The Graduate Institute of International and De...
# 963                             Hanwha Asset Management
# 1742                           Majid Al Futtaim Holding
# 1487        Qatar Financial Centre Regulatory Authority
# 220                          Marsh & McLennan Companies
# 624                                       Aroundtown SA
# 998                                         Google Inc.
# 726                           Soros Fund Management LLC
# 911                       HSBC Bank Middle East Limited
# 512                               Lockheed Martin Space
# 1811                                                4SD
# 1047                                    AlGihaz Holding
# 1917                       Ministry of Finance of Saudi
# 1940                                       Centrica Plc
# 1041                                      ManpowerGroup
# 991                                      Baker McKenzie
# 1222  Ministry of Foreign Affairs and European Integ...
# 1247                            América Movil SAB de CV
# 1299    Office of the Prime Minister of the Netherlands
# 1424                      The National Commercial Bank
# 370                              Jane Goodall Institute
# 1833                                Olaris Therapeutics
# 1890                               USM Holdings Limited
# 1105                        National Geographic Society
# 602             Ministry of Foreign Affairs of Ethiopia
# 648                       Panzi Hospital and Foundation
# 349                                  Absa Group Limited
# 1137              The Kuwaiti Danish Dairy Company KCSC
# 656                                              JD.COM
# 1539               Ministry of Foreign Affairs of Qatar
# 1565                             Teck Resources Limited
# 1200                                   Swiss Parliament
# 955                                 Tsinghua University
# 1793        Office of the Head of Government of Tunisia
# 1880                               World Economic Forum
# 979                                       Alibaba Group
# 1892                               USM Holdings Limited
# 355          Carnegie Endowment for International Peace
# 1404                              Bridge to Afghanistan
# 561                                    Arthur D. Little
# 183                                         Lippo Group
#
#                        org_country
# 112                 United Kingdom
# 1859                           USA
# 1146                        Jordan
# 1315                         Italy
# 339           United Arab Emirates
# 852                 United Kingdom
# 877                          Japan
# 1682                        Canada
# 1228                        France
# 524                    Switzerland
# 963              Republic of Korea
# 1742          United Arab Emirates
# 1487                         Qatar
# 220                            USA
# 624                     Luxembourg
# 998              Republic of Korea
# 726                            USA
# 911           United Arab Emirates
# 512                            USA
# 1811                   Switzerland
# 1047                  Saudi Arabia
# 1917                  Saudi Arabia
# 1940                United Kingdom
# 1041                        Mexico
# 991                      Singapore
# 1222                       Moldova
# 1247                        Mexico
# 1299                   Netherlands
# 1424                  Saudi Arabia
# 370                            USA
# 1833                           USA
# 1890            Russian Federation
# 1105                           USA
# 602                       Ethiopia
# 648   Democratic Republic of Congo
# 349                   South Africa
# 1137                        Kuwait
# 656     People's Republic of China
# 1539                         Qatar
# 1565                        Canada
# 1200                   Switzerland
# 955     People's Republic of China
# 1793                       Tunisia
# 1880                   Switzerland
# 979     People's Republic of China
# 1892            Russian Federation
# 355                            USA
# 1404                   Afghanistan
# 561                         France
# 183                      Indonesia

# %% [markdown]
# Why, yes. Yes, it is. This is why you _always_ confirm what an algorithm does. Right, maybe let's bump up our threshold and see what happens.

# %%
results = fpd.fuzzy_merge(cia_world_leaders, davos_attendees, left_on='name', 
                          right_on='full_name', 
                          ignore_case=True, 
                          ignore_nonalpha=True,
                          ignore_nonlatin=True,
                          ignore_order_words=True,
                          ignore_titles=True,
                          method='levenshtein', 
                          threshold=0.8
                         )

# %%
results.shape
# Out:
# (186, 7)

# %% [markdown]
# OK, that seems more reasonable. Let's sanity check.

# %%
results.sample(50)
# Out:
#                   country                                               role  \
# 176        United Kingdom             Sec. of State for Health & Social Care
# 107                Malawi    Min. of Information & Communications Technology
# 55                Georgia                                         Prime Min.
# 185              Zimbabwe                 Min. of Mines & Mining Development
# 119           New Zealand                            Min. for Climate Change
# 25                  Burma              Min. of the Office of the Union Govt.
# 81                  Italy                            Min. of Foreign Affairs
# 97                Lebanon                               Prime Min.-Designate
# 137                Rwanda                                     Min. of Health
# 155           Switzerland                    Chief, Federal Dept. of Finance
# 49                Finland                                    Dep. Prime Min.
# 134                Poland                                         Prime Min.
# 52                 France                  Min. for Europe & Foreign Affairs
# 91                  Kenya   Cabinet Sec. for Industry, Trade, & Cooperatives
# 142                Serbia                                              Pres.
# 59                Germany                                    Min. of Defense
# 170               Ukraine                                              Pres.
# 40                Denmark                                   Min. for Finance
# 95                 Kosovo                                              Pres.
# 17                Belgium                                    Dep. Prime Min.
# 62                  India                          Min. of Corporate Affairs
# 158           Switzerland                                 Federal Chancellor
# 92           Korea, South                        Dep. Prime Min. for Economy
# 58                Germany   Min. for Transportation & Digital Infrastructure
# 38                Czechia                                         Prime Min.
# 36                Croatia                                         Prime Min.
# 60                  Ghana                                         Vice Pres.
# 35          Cote d'Ivoire                          Min. of Economy & Finance
# 67                   Iraq                            Min. of Foreign Affairs
# 27                 Canada                           Governor, Bank of Canada
# 13                Bahrain      Min. of Justice, Islamic Affairs, & Endowment
# 171  United Arab Emirates             Min. of Cabinet Affairs and the Future
# 31                  China          Min. of Human Resources & Social Security
# 116           Netherlands  Min. of Infrastructure, Public Works, & Water ...
# 144             Singapore  Coordinating Min. for Economic & Social Polici...
# 132                Poland                            Min. of Foreign Affairs
# 66              Indonesia                                   Min. of Industry
# 84                  Japan          Min. in Charge of Regional Revitalization
# 120           New Zealand          Min. for National Security & Intelligence
# 68                   Iraq                                              Pres.
# 32                  China          Min. of Industry & Information Technology
# 34             Costa Rica                                              Pres.
# 117           Netherlands                                         Prime Min.
# 168                Uganda                                              Pres.
# 147             Singapore                                   Min. for Finance
# 114           Netherlands                              Min. for Medical Care
# 73                Ireland               Min. for Public Expenditure & Reform
# 74                Ireland                         Tanaiste (Dep. Prime Min.)
# 98          Liechtenstein            Min. of General Govt. Affairs & Finance
# 47               Ethiopia                                         Prime Min.
#
#                              name                     full_name  \
# 176                  Matt HANCOCK                  Matt Hancock
# 107                Nicholas DAUSI                Nicholas Davis
# 55               Mamuka BAKHTADZE              Mamuka Bakhtadze
# 185              Winston CHITANDO               Wiston Chitando
# 119                    James SHAW                    James Shea
# 25                        MIN THU                       Min Zhu
# 81          Enzo MOAVERO Milanesi         Enzo Moavero Milanesi
# 97                Sa'ad al-HARIRI                   Saad Hariri
# 137           Diane GASHUMBA, Dr.                Diane Gashumba
# 155                   Ueli MAURER                   Ueli Maurer
# 49                     Timo SOINI                    Timo Soini
# 134            Mateusz MORAWIECKI            Mateusz Morawiecki
# 52             Jean-Yves LE DRIAN            Jean-Yves Le Drian
# 91                    Peter MUNYA                   Peter Munya
# 142              Aleksandar VUCIC              Aleksandar Vučić
# 59           Ursula VON DER LEYEN          Ursula von der Leyen
# 170              Petro POROSHENKO              Petro Poroshenko
# 40                Kristian JENSEN               Kristian Jensen
# 95                   Hashim THACI                  Hashim Thaci
# 17                   Kris PEETERS                  Kris Peeters
# 62                   Arun JAITLEY                  Arun Jaitley
# 158              Walter THURNHERR              Walter Thurnherr
# 92                  KIM Dong-yeon                  Dong-Won Kim
# 58                Andreas SCHEUER               Andreas Scheuer
# 38                   Andrej BABIS                  Andrej Babiš
# 36               Andrej PLENKOVIC              Andrej Plenković
# 60               Mahamudu BAWUMIA              Mahamudu Bawumia
# 35                     Adama KONE                    Adama Koné
# 67          Muhammad Ali al-HAKIM           Mohamed Ali Alhakim
# 27                  Stephen POLOZ              Stephen S. Poloz
# 13      KHALID bin Ali Al Khalifa   Khalid Bin Ahmed Al Khalifa
# 171  Muhammad Abdallah al-GARGAWI  Mohammad Abdullah Al Gergawi
# 31                    ZHANG Jinan                     Zhang Jin
# 116        Cora VAN NIEUWENHUIZEN         Jan van Nieuwenhuizen
# 144        Tharman SHANMUGARATNAM        Tharman Shanmugaratnam
# 132             Jacek CZAPUTOWICZ             Jacek Czaputowicz
# 66             AIRLANGGA Hartarto            Airlangga Hartarto
# 84               Satsuki KATAYAMA              Satsuki Katayama
# 120                Jacinda ARDERN                Jacinda Ardern
# 68                   Barham SALIH                  Barham Salih
# 32                       MIAO Wei                      Miao Wei
# 34        Carlos ALVARADO Quesada       Carlos Alvarado Quesada
# 117                    Mark RUTTE                    Mark Rutte
# 168        Yoweri Kaguta MUSEVENI        Yoweri Kaguta Museveni
# 147                HENG Swee Keat                Heng Swee Keat
# 114                  Bruno BRUINS                  Bruno Bruins
# 73                Paschal DONOHOE               Paschal Donohoe
# 74                  Simon COVENEY                 Simon Coveney
# 98                  Adrian HASLER                 Adrian Hasler
# 47                     ABIY Ahmed                    Abiy Ahmed
#
#                                    position_short_name  \
# 176  Secretary of State for Health and Social Care ...
# 107  Head of Society and Innovation; Member of the ...
# 55                           Prime Minister of Georgia
# 185  Minister of Mines and Mining Development of Zi...
# 119      Chief Executive Officer, Commercial Insurance
# 25   Chairman, National Institute of Financial Rese...
# 81   Minister of Foreign Affairs and International ...
# 97    President of the Council of Ministers of Lebanon
# 137                       Minister of Health of Rwanda
# 155  President of the Swiss Confederation 2019 and ...
# 49              Minister of Foreign Affairs of Finland
# 134                           Prime Minister of Poland
# 52    Minister of Europe and Foreign Affairs of France
# 91   Cabinet Secretary for Trade, Industry and Coop...
# 142                                President of Serbia
# 59              Federal Minister of Defence of Germany
# 170                               President of Ukraine
# 40                      Minister of Finance of Denmark
# 95   President of Kosovo (This designation is witho...
# 17   Deputy Prime Minister and Minister of Employme...
# 62   Minister of Finance and Corporate Affairs of I...
# 158      Federal Chancellor of the Swiss Confederation
# 92    Chief Innovation Officer; Senior Vice- President
# 58   Federal Minister of Transport and Digital Infr...
# 38   Prime Minister of the Czech Republic the Czech...
# 36                           Prime Minister of Croatia
# 60                             Vice-President of Ghana
# 35   Minister of Economics and Finance of Côte d'Iv...
# 67                 Minister of Foreign Affairs of Iraq
# 27                      Governor of the Bank of Canada
# 13              Minister of Foreign Affairs of Bahrain
# 171  Minister of Cabinet Affairs and the Future of ...
# 31                               Chairman of the Board
# 116                       Member of the Managing Board
# 144  Deputy Prime Minister and Coordinating Ministe...
# 132              Minister of Foreign Affairs of Poland
# 66                   Minister of Industry of Indonesia
# 84   Minister of State for Regional Revitalization ...
# 120                      Prime Minister of New Zealand
# 68                                   President of Iraq
# 32   Minister of Industry and Information Technolog...
# 34                             President of Costa Rica
# 117                  Prime Minister of the Netherlands
# 168                                President of Uganda
# 147                  Minister for Finance of Singapore
# 114       Minister for Medical Care of the Netherlands
# 73                     Minister for Finance of Ireland
# 74   Tánaiste and Minister for Foreign Affairs and ...
# 98                     Prime Minister of Liechtenstein
# 47                          Prime Minister of Ethiopia
#
#                                               org_name  \
# 176         Department of Health of the United Kingdom
# 107                               World Economic Forum
# 55             Office of the Prime Minister of Georgia
# 185  Ministry of Mines and Mining Development of Zi...
# 119                       Zurich Insurance Company Ltd
# 25            National Institute of Financial Research
# 81   Ministry of Foreign Affairs and International ...
# 97   Presidency of the Council of Ministers of Lebanon
# 137                       Ministry of Health of Rwanda
# 155       Federal Department of Finance of Switzerland
# 49              Ministry of Foreign Affairs of Finland
# 134        Chancellery of the Prime Minister of Poland
# 52    Ministry of Europe and Foreign Affairs of France
# 91   Ministry of Trade, Industry and Cooperatives o...
# 142                  Office of the President of Serbia
# 59              Federal Ministry of Defence of Germany
# 170                    Office of the President Ukraine
# 40                      Ministry of Finance of Denmark
# 95                   Office of the President of Kosovo
# 17      Office of the Deputy Prime Minister of Belgium
# 62                        Ministry of Finance of India
# 158                 Federal Chancellery of Switzerland
# 92                       Hanwha Life Insurance Co. Ltd
# 58   Federal Ministry of Transport and Digital Infr...
# 38      Office of the Prime Minister of Czech Republic
# 36             Office of the Prime Minister of Croatia
# 60   Office of the Vice-President, Vice-President S...
# 35   Ministry of Economics and Finance of Côte d'Iv...
# 67   Ministry of Foreign Affairs of the Republic of...
# 27                                      Bank of Canada
# 13              Ministry of Foreign Affairs of Bahrain
# 171  Ministry of Cabinet Affairs and the Future of ...
# 31                                Cedar Holdings Group
# 116                                     Rabobank Group
# 144          Office of the Prime Minister of Singapore
# 132                        Ministry of Foreign Affairs
# 66                   Ministry of Industry of Indonesia
# 84                             Cabinet Office of Japan
# 120                             New Zealand Government
# 68                     Office of the President of Iraq
# 32   Ministry of Industry and Information Technolog...
# 34               Office of the President of Costa Rica
# 117    Office of the Prime Minister of the Netherlands
# 168                     Office of the President Uganda
# 147                   Ministry of Finance of Singapore
# 114  Ministry of Health, Welfare and Sport of the N...
# 73                    Department of Finance of Ireland
# 74   Department of Foreign Affairs and Trade of Ire...
# 98     Government of the Principality of Liechtenstein
# 47            Office of the Prime Minister of Ethiopia
#
#                     org_country
# 176              United Kingdom
# 107                 Switzerland
# 55                      Georgia
# 185                    Zimbabwe
# 119                 Switzerland
# 25   People's Republic of China
# 81                        Italy
# 97                      Lebanon
# 137                      Rwanda
# 155                 Switzerland
# 49                      Finland
# 134                      Poland
# 52                       France
# 91                        Kenya
# 142                      Serbia
# 59                      Germany
# 170                     Ukraine
# 40                      Denmark
# 95                       Kosovo
# 17                      Belgium
# 62                        India
# 158                 Switzerland
# 92            Republic of Korea
# 58                      Germany
# 38               Czech Republic
# 36                      Croatia
# 60                        Ghana
# 35                Côte d'Ivoire
# 67                         Iraq
# 27                       Canada
# 13                      Bahrain
# 171        United Arab Emirates
# 31   People's Republic of China
# 116                 Netherlands
# 144                   Singapore
# 132                      Poland
# 66                    Indonesia
# 84                        Japan
# 120                 New Zealand
# 68                         Iraq
# 32   People's Republic of China
# 34                   Costa Rica
# 117                 Netherlands
# 168                      Uganda
# 147                   Singapore
# 114                 Netherlands
# 73                      Ireland
# 74                      Ireland
# 98                Liechtenstein
# 47                     Ethiopia

# %% [markdown]
# Next question, one for you guys to do:
#
# Which names from the CIA world leaders list are also on the Forbes billionaires list?
#
# Who can get the best result?

# %%
forbes_df = df1

results = fpd.fuzzy_merge(cia_world_leaders, forbes_df, left_on='name', 
                          right_on='name', 
#                           ignore_case=True, 
#                           ignore_nonalpha=True,
#                           ignore_nonlatin=True,
#                           ignore_order_words=True,
#                           ignore_titles=True,
                          method='levenshtein', 
                         )

# %%
results.shape
# Out:
# (323, 17)

# %% [markdown]
# So in what scenarios do you reckon Levenshtein will perform badly?

# %% [markdown]
# Next up: **metaphone**.
#
# Metaphone's great for names which sound similar, which wouldn't be caught by Levenshtein. It's especially handy when you're working with transcript data. But, it too comes with its pitfalls.
#
# Let's look at an example and then discuss what the possible pitfalls could be.
#
# Which names from the CIA world leaders list are also on the United Nations sanctions list?

# %%
un_sanctions = pd.read_csv("data/un-sanctions.csv")

# %%
results = fpd.fuzzy_merge(cia_world_leaders, un_sanctions, left_on='name', 
                          right_on='name', 
                          method='metaphone', 
                         )

# %%
results.shape
# Out:
# (18, 22)

# %%
## How does this compare to our other algorithms? 
results = fpd.fuzzy_merge(cia_world_leaders, un_sanctions, left_on='name', 
                          right_on='name', 
                          method='levenshtein', 
                         )
# Out:
# ------------------------------------------------------------------------
# ValueError                             Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/fuzzylevenshtein.py in damerau_levenshtein_distance(a, b)
#      10     try:
# ---> 11         return jellyfish.damerau_levenshtein_distance(a, b)
#      12     except ValueError: # c implementation can't deal with unicode, fall back to (slower) python
#
# ValueError: Encountered unsupported code point in string.
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                      Traceback (most recent call last)
# <ipython-input-108-57c7172c9427> in <module>
#       2 results = fpd.fuzzy_merge(cia_world_leaders, un_sanctions, left_on='name',
#       3                           right_on='name',
# ----> 4                           method='levenshtein',
#       5                          )
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/fuzzy_pandas/fuzzy_merge.py in fuzzy_merge(df1, df2, on, left_on, right_on, keep, keep_left, keep_right, method, threshold, **kwargs)
#     131         output=output,
#     132         methods=method,
# --> 133         **kwargs)
#     134
#     135     return pd.DataFrame(results, columns=keys)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/csvmatch.py in run(data1, headers1, data2, headers2, fields1, fields2, ignore_case, ignore_titles, ignore_custom, ignore_nonlatin, ignore_nonalpha, ignore_order_words, methods, thresholds, output, join, ticker)
#      49     matches = matcher(processed1, processed2)
#      50     outputs = format(output, headers1, headers2, fields1, fields2)
# ---> 51     results = connect(join, data1, headers1, data2, headers2, list(matches), outputs)
#      52     keys = [key for _, key in outputs]
#      53     return results, keys
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/csvmatch.py in executor(data1, data2)
#     123                 degrees = []
#     124                 for i, matcher in enumerate(matchers):
# --> 125                     degree = matcher['method'](row1[i], row2[i])
#     126                     if degree < matcher['threshold']: break
#     127                     else: degrees.append(degree)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/fuzzylevenshtein.py in match(value1, value2)
#       4 def match(value1, value2):
#       5     maximum = float(max(len(value1), len(value2)))
# ----> 6     distance = damerau_levenshtein_distance(value1, value2)
#       7     return 1 - distance / maximum
#       8
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/fuzzylevenshtein.py in damerau_levenshtein_distance(a, b)
#      11         return jellyfish.damerau_levenshtein_distance(a, b)
#      12     except ValueError: # c implementation can't deal with unicode, fall back to (slower) python
# ---> 13         return py_jellyfish.damerau_levenshtein_distance(a, b)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/jellyfish/_jellyfish.py in damerau_levenshtein_distance(s1, s2)
#     141             j1 = db
#     142             cost = 1
# --> 143             if s1[i-1] == s2[j-1]:
#     144                 cost = 0
#     145                 db = j
#
# KeyboardInterrupt:

# %%
results.shape

# %%
## How does this compare to our other algorithms? 
results = fpd.fuzzy_merge(cia_world_leaders, un_sanctions, left_on='name', 
                          right_on='name', 
                          ignore_case=True
                         )

# %%
results.shape
# Out:
# (6, 22)

# %% [markdown]
# Finally, we get to **Bilenko**. And, yes, this uses machine learning, where you train your own data. So, now you have human *smarts* being involved in the process of matching up names across documents.
#
# Let's look at an example:
#
# Which names from the CIA world leaders list are also on the Davos attendees list?

# %%
results = fpd.fuzzy_merge(cia_world_leaders, davos_attendees, left_on='name', 
                          right_on='full_name', 
                          method='bilenko', 
                         )
# Out:
# Answer questions as follows:
#  y - yes
#  n - no
#  s - skip
#  f - finished
#
# name: Michael MCCORMACK
#
# name: Michael Nally
#
# Do these records refer to the same thing? [y/n/s/f]
# n
# name: Angel Francisco ESTEVEZ Bourdierd
#
# name: Angel Gurría
#
# Do these records refer to the same thing? [y/n/s/f]
# n
# name: Vladimir PADRINO Lopez, Gen.
#
# name: Vladimir Lisin
#
# Do these records refer to the same thing? [y/n/s/f]
# n
# name: Carlos Gustavo FERNANDEZ Valdovinos
#
# name: Carlos Brito
#
# Do these records refer to the same thing? [y/n/s/f]
# n
# name: Reyes MAROTO Illera
#
# name: Reyes Maroto Illera
#
# Do these records refer to the same thing? [y/n/s/f]
# y
# name: Sigrid KAAG
#
# name: Sigrid Kaag
#
# Do these records refer to the same thing? [y/n/s/f]
# y
# name: Isam bin Saad bin SAYID
#
# name: Zhao Ying
#
# Do these records refer to the same thing? [y/n/s/f]
# n
# name: Angelo de Barros Veiga TAVARES
#
# name: Angel Gurría
#
# Do these records refer to the same thing? [y/n/s/f]
# n
# name: James HOTH MAI, Gen.
#
# name: James Shea
#
# Do these records refer to the same thing? [y/n/s/f]
# n
# name: Christian SANCHEZ
#
# name: Christian Dorer
#
# Do these records refer to the same thing? [y/n/s/f]
# n
# name: Ali bin Masud bin Ali al-SUNAIDI
#
# name: Ali bin Masoud bin Ali Al Sunaidy
#
# Do these records refer to the same thing? [y/n/s/f]
# y
# name: Tran Hong HA
#
# name: Tran Hong Ha
#
# Do these records refer to the same thing? [y/n/s/f]
# f
# INFO:dedupe.training:Final predicate set:
# INFO:dedupe.training:(SimplePredicate: (doubleMetaphone, name), TfidfTextSearchPredicate: (0.6, name))
# INFO:rlr.crossvalidation:using cross validation to find optimum alpha...
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/rlr/crossvalidation.py:122: RuntimeWarning: invalid value encountered in double_scalars
#   * (true_distinct + false_distinct)))
# INFO:rlr.crossvalidation:optimum alpha: 0.000010, score 1.6326809185664067e-18
# INFO:dedupe.training:Final predicate set:
# INFO:dedupe.training:(SimplePredicate: (doubleMetaphone, name), TfidfTextSearchPredicate: (0.6, name))
# INFO:dedupe.api:0 records
# INFO:dedupe.api:100 records
# INFO:dedupe.api:200 records
# INFO:dedupe.api:300 records
# INFO:dedupe.api:400 records
# INFO:dedupe.api:500 records
# INFO:dedupe.api:600 records
# INFO:dedupe.api:700 records
# INFO:dedupe.api:800 records
# INFO:dedupe.api:900 records
# INFO:dedupe.api:1000 records
# INFO:dedupe.api:1100 records
# INFO:dedupe.api:1200 records
# INFO:dedupe.api:1300 records
# INFO:dedupe.api:1400 records
# INFO:dedupe.api:1500 records
# INFO:dedupe.api:1600 records
# INFO:dedupe.api:1700 records
# INFO:dedupe.api:Maximum expected recall and precision
# INFO:dedupe.api:recall: 0.613
# INFO:dedupe.api:precision: 0.535
# INFO:dedupe.api:With threshold: 0.296
# INFO:dedupe.api:0 records
# INFO:dedupe.api:100 records
# INFO:dedupe.api:200 records
# INFO:dedupe.api:300 records
# INFO:dedupe.api:400 records
# INFO:dedupe.api:500 records
# INFO:dedupe.api:600 records
# INFO:dedupe.api:700 records
# INFO:dedupe.api:800 records
# INFO:dedupe.api:900 records
# INFO:dedupe.api:1000 records
# INFO:dedupe.api:1100 records
# INFO:dedupe.api:1200 records
# INFO:dedupe.api:1300 records
# INFO:dedupe.api:1400 records
# INFO:dedupe.api:1500 records
# INFO:dedupe.api:1600 records
# INFO:dedupe.api:1700 records

# %%
results.shape
# Out:
# (19, 7)
