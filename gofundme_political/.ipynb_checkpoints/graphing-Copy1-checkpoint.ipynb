# %%
import pandas as pd
import requests
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import re
from datetime import datetime, timedelta
import time
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support import expected_conditions as EC
import seaborn as sns
import nltk
nltk.download('punkt')
nltk.download('stopwords')
sns.set(style='whitegrid',palette='pastel')
matplotlib.rcParams['pdf.fonttype'] = 42

# %matplotlib inline
# Out:
# [nltk_data] Downloading package punkt to /Users/lilyliu-
# [nltk_data]     krason/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/lilyliu-
# [nltk_data]     krason/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# !pip install nltk

# %%
df=pd.read_csv('merged_final_07172019.csv',thousands=',')

# %%
df=df.drop(columns=['raised','goal'])

# %%
df.head(3)
# Out:
#    Unnamed: 0                                               link  \
# 0           0  https://www.gofundme.com/steven-crowder-live-a...
# 1           1  https://www.gofundme.com/reopen-a-nc-republica...
# 2           2            https://www.gofundme.com/troopersanchez
#
#         location                                            summary  \
# 0     Dallas, TX  SMU College Republicans is bringing comedian S...
# 1  Brookline, MA  NOTE: We reached our goal and then some in les...
# 2    Mcallen, TX  ￼ Moises Sanchez, a Texas State Trooper, was s...
#
#                                 title              created_date  tag state  \
# 0         Steven Crowder Live at SMU!     Created March 7, 2018  rep    TX
# 1  Dems help reopen a NC Repub office  Created October 16, 2016  rep    MA
# 2    Funds for Trooper Moises Sanchez     Created April 7, 2019  rep    TX
#
#    goal_int  raised_int
# 0    6500.0      2710.0
# 1   10000.0     12857.0
# 2   20000.0     13021.0

# %%
#getting a look at how many campaigns with word "democrat" vs "republican"
df.tag.value_counts()
# Out:
# rep    864
# dem    850
# Name: tag, dtype: int64

# %%
#overlap count
df.link.value_counts()[df.link.value_counts()==2].count()
# Out:
# 254

# %%
#converting dates
df['created_date']=df.created_date.str.replace('Created ','')

# df['date']=pd.to_datetime(df.created_date,infer_datetime_format=True)

# %%
#you'll have to drop the 1 day ago, 3 days ago...
ago_df=df[df.created_date.str.contains('ago')==True]
ago_df['created_date']=ago_df.created_date.str.replace(' ago','')
# Out:
# /Users/lilyliu-krason/.pyenv/versions/3.7.1/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
ago_df.head(3)
# Out:
#      Unnamed: 0                                               link  \
# 467         531  https://www.gofundme.com/defeat-the-hijackers-...
# 670         765  https://www.gofundme.com/1planet-climate-champ...
# 744         848     https://www.gofundme.com/AMassiveParadigmShift
#
#             location                                            summary  \
# 467  Grand Blanc, MI  For the last seven years I have been the subje...
# 670   Alexandria, VA  The Republican Majority in the Virginia Genera...
# 744       Boston, MA  The September 11th Attacks... put America on a...
#
#                                               title created_date  tag state  \
# 467  Hijacking America: The Book, ExplCmte Joe4Prez        1 day  rep    MI
# 670                  1Planet Climate Champions Fund       6 days  rep    VA
# 744                   HELP SAVE THE AMERICAN DREAM!      3 hours  rep    MA
#
#        goal_int  raised_int
# 467      5000.0        51.0
# 670      3000.0       100.0
# 744  50000000.0         0.0

# %%
# turn hours ago to 1 day ago
ago_df.loc[ago_df.created_date.str.contains("hour"), 'created_date']='1 day'

# %%
# extract the date difference
ago_df['data_diff'] = ago_df.created_date.str.extract(r'(\d+)', expand=False).astype(int)
# Out:
# /Users/lilyliu-krason/.pyenv/versions/3.7.1/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#since this data was grabbed 7/17 we'll have to subtract a few more days
ago_df['created_actual']=ago_df['data_diff'].apply(lambda x: pd.datetime.now().date()-timedelta(days=x+5))
# Out:
# /Users/lilyliu-krason/.pyenv/versions/3.7.1/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
ago_df=ago_df.drop(columns=['created_date','data_diff'])

# %%
ago_df=ago_df.rename(columns={'created_actual':'created_date'})

# %%
df=df[df.created_date.str.contains('ago')==False]

# %%
df=df.append(ago_df)

# %%
#convert to datetime and add Year, Month, Weekday
df['year']=pd.to_datetime(df.created_date).dt.year
df['month']=pd.to_datetime(df.created_date).dt.month
df['weekday_name'] =pd.to_datetime(df.created_date).dt.weekday_name

# %% [markdown]
# # Using Crosstab to Compare "Democrat" vs "Republican"

# %%
pd.crosstab(index=df.year,columns=df.tag).plot(kind='barh',stacked=True,title='Campaigns Created By Year Containing Word')

# %%
overlap=df[df.link.isin(df.link.value_counts()[df.link.value_counts()==2].index)]

# %%
overlap.year.value_counts().plot(kind='barh',title='campaigns created with both words')

# %%
pd.crosstab(index=df.month,columns=df.tag).plot(kind='barh',stacked=True,width=0.7,title='Campaigns Created By Month Containing Word',figsize=(10,10))

# %%
pd.crosstab(index=df['weekday_name'],columns=df.tag).plot(kind='barh',stacked=True,width=0.7,title='Campaigns Created By Day of Week Containing Word',figsize=(10,10))

# %%
df.groupby('tag')['goal_int'].median()
# Out:
# tag
# dem    5000.0
# rep    9250.0
# Name: goal_int, dtype: float64

# %%
overlap.goal_int.median()
# Out:
# 10000.0

# %%
sns.lmplot(x='month',y='goal_int',hue='tag',data=df)

# %%
df.state.value_counts().sort_values(ascending=True).plot(kind='barh',figsize=(20,10),title='campaigns created by state')

# %%
plt.figure(figsize=(20,5))
sns.barplot(x='state',y='raised_int',ci=0,data=df)

# %%
plt.figure(figsize=(20,5))
sns.barplot(x='state',y='raised_int',ci=0,data=overlap)

# %% [markdown]
# # Aggregate Graphs

# %%
# #using seaborn time series formatting
# sns.set(rc={'figure.figsize':(11, 4)})

# %%
df['Weekday Name'] = pd.Categorical(df['Weekday Name'], categories=
    ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday', 'Sunday'],
    ordered=True)

# %%
created_by_day = df['Weekday Name'].value_counts()
created_by_day = created_by_day.sort_index(ascending=False)
created_by_day.plot(kind='barh',width=0.8,title= "Day of the Week Campaigns Are Created")
plt.savefig("agg_day_of_week.pdf")

# %%
rep_year=df[df['tag']=='rep'].Year.value_counts().rename_axis('Year').reset_index(name='rep_counts')
dem_year =df[df['tag']=='dem'].Year.value_counts().rename_axis('Year').reset_index(name='dem_counts')

# %%
#total amount raised
#what is this scale though? How do I change this?
df.groupby('Year')['raised_int'].sum().plot(kind='barh',title='Total Amount Raised by Campaigns that Mention "Democrat" or "Republican"')

# plt.savefig("total_amount_raised.pdf")

# %%
data=pd.DataFrame(df.groupby('Year')['tag'].value_counts())

# %%
df.groupby('tag')['raised_int'].sum().plot(kind='barh',title='Total Raised by Campaigns by Word Mention')

# %%
#another way not as good as crosstab
year_df=rep_year.merge(dem_year, left_on='Year',right_on='Year')
year_df.sort_values('Year').set_index('Year').plot(kind='barh',stacked=True,width=0.8,title='Campaigns Created By Word Mention',figsize=(10,10))
# plt.savefig("campaigns_stacked.pdf")

# %%
# #some other BS I did
rep_Month=df[df['tag']=='rep'].Month.value_counts().rename_axis('Month').reset_index(name='rep_counts')
dem_Month =df[df['tag']=='dem'].Month.value_counts().rename_axis('Month').reset_index(name='dem_counts')
Month_df=rep_Month.merge(dem_Month, left_on='Month',right_on='Month')
Month_df.sort_values('Month').set_index('Month').sort_values(by='Month',ascending=False).plot(kind='barh',stacked=True,width=0.7,title='Campaigns Created By Word Mention')
plt.savefig("campaigns_stacked2.1.pdf")

# %%
df.sample(5, random_state=0)
# Out:
#       Unnamed: 0                                               link  \
# 799          903  https://www.gofundme.com/establish-hitchens-cu...
# 1047         249          https://www.gofundme.com/greenforbernie16
# 1436         878  https://www.gofundme.com/recall-mayor-of-los-a...
# 54            61                https://www.gofundme.com/1oi4td52o0
# 793          894  https://www.gofundme.com/xbhak-trump-loves-imm...
#
#                 location                                            summary  \
# 799       Greensboro, NC  “We have deeply held beliefs in rational think...
# 1047         Marrero, LA  Hello, I'm Kyle Green. In May, I was elected b...
# 1436  Canyon Country, CA  Eric Garcetti has failed to protect the people...
# 54            Dallas, TX  My goal is to train our youth in the art of gu...
# 793     Grand Rapids, MI  MISSION: TO EMPOWER THE REPUBLICAN IMMIGRANTS ...
#
#                                           title  tag    created_date  \
# 799                    Hitchens Cultural Center  rep    June 1, 2019
# 1047         Louisiana Delegate for Bernie Fund  dem   June 22, 2016
# 1436  Recall Mayor of Los Angeles Eric Garcetti  dem   June 11, 2019
# 54           Gun Training For Young Republicans  rep   June 27, 2019
# 793                      TRUMP LOVES IMMIGRANTS  rep    June 6, 2019
#
#        goal_int  raised_int       date  Year  Month Weekday Name
# 799     10000.0         0.0 2019-06-01  2019      6     Saturday
# 1047     3300.0      3352.0 2016-06-22  2016      6    Wednesday
# 1436  1000000.0         0.0 2019-06-11  2019      6      Tuesday
# 54      10000.0         0.0 2019-06-27  2019      6     Thursday
# 793      1000.0         0.0 2019-06-06  2019      6     Thursday

# %%
rep_Weekday_Name=df[df['tag']=='rep']['Weekday Name'].value_counts().rename_axis('Weekday Name').reset_index(name='rep_counts')
dem_Weekday_Name =df[df['tag']=='dem']['Weekday Name'].value_counts().rename_axis('Weekday Name').reset_index(name='dem_counts')
Weekday_Name_df=rep_Weekday_Name.merge(dem_Weekday_Name, left_on='Weekday Name',right_on='Weekday Name')
Weekday_Name_df.sort_values('Weekday Name').set_index('Weekday Name').plot(kind='barh',stacked=True,width=0.8,title='Campaigns Created By Word Mention')

plt.savefig("output.pdf")

# %%
df.groupby('tag')['Weekday Name'].value_counts()
# Out:
# tag  Weekday Name
# dem  Tuesday         110
#      Wednesday        97
#      Monday           93
#      Thursday         89
#      Sunday           87
#      Friday           73
#      Saturday         69
# rep  Tuesday         139
#      Thursday        136
#      Wednesday       133
#      Monday          130
#      Saturday        116
#      Sunday          112
#      Friday          110
# Name: Weekday Name, dtype: int64

# %%
#playing with groupbys 
df.groupby('tag')['Weekday Name'].value_counts().plot(kind='barh',stacked=True,width=0.8,title='Campaigns Created By Word Mention')

# %%
df.sample(3, random_state=0)
# Out:
#       Unnamed: 0                                               link  \
# 799          903  https://www.gofundme.com/establish-hitchens-cu...
# 1047         249          https://www.gofundme.com/greenforbernie16
# 1436         878  https://www.gofundme.com/recall-mayor-of-los-a...
#
#                 location                                            summary  \
# 799       Greensboro, NC  “We have deeply held beliefs in rational think...
# 1047         Marrero, LA  Hello, I'm Kyle Green. In May, I was elected b...
# 1436  Canyon Country, CA  Eric Garcetti has failed to protect the people...
#
#                                           title  tag    created_date  \
# 799                    Hitchens Cultural Center  rep    June 1, 2019
# 1047         Louisiana Delegate for Bernie Fund  dem   June 22, 2016
# 1436  Recall Mayor of Los Angeles Eric Garcetti  dem   June 11, 2019
#
#        goal_int  raised_int       date  Year  Month Weekday Name
# 799     10000.0         0.0 2019-06-01  2019      6     Saturday
# 1047     3300.0      3352.0 2016-06-22  2016      6    Wednesday
# 1436  1000000.0         0.0 2019-06-11  2019      6      Tuesday

# %%
#the graveyard

graveyard = df[df['raised_int']==0]
sns.relplot(data=graveyard, x='weekday_name', y='goal_int', hue='tag')

# %% [markdown]
# # Common Words!

# %%
#campaigns with the word republican
top_N = 100000
rep_rslt =pd.DataFrame()
for index, row in df[df['tag']=='rep'].iterrows():
    txt = row['summary'].lower()
    words = nltk.tokenize.word_tokenize(txt)
    word_dist = nltk.FreqDist(words)
    stopwords = nltk.corpus.stopwords.words('english')
    words_except_stop_dist = nltk.FreqDist(w for w in words if w not in stopwords) 
    print('All frequencies, including STOPWORDS:')
    print('=' * 60)
    rslt = pd.DataFrame(word_dist.most_common(top_N),
                        columns=['Word', 'Frequency'])
    print(rslt)
    print('=' * 60)
    rslt = pd.DataFrame(words_except_stop_dist.most_common(top_N),columns=['Word', 'Frequency']).set_index('Word')
    rep_rslt=rep_rslt.append(rslt)
# Out:
# All frequencies, including STOPWORDS:
# ============================================================
#              Word  Frequency
# 0             smu          4
# 1              to          4
# 2               ,          3
# 3         crowder          2
# 4              on          2
# 5              at          2
# 6        mcfarlin          2
# 7               .          2
# 8             the          2
# 9         college          1
# 10    republicans          1
# 11             is          1
# 12       bringing          1
# 13       comedian          1
# 14         steven          1
# 15       thursday          1
# 16          march          1
# 17             22          1
# 18            7pm          1
# 19             in          1
# 20     auditorium          1
# 21            due          1
# 22             an          1
# 23      extremely          1
# 24           high          1
# 25         demand          1
# 26            see          1
# 27         louder          1
# 28           with          1
# 29           live          1
# 30             we          1
# 31            are          1
# 32        renting          1
# 33        largest          1
# 34          venue          1
# 35             's          1
# 36         campus          1
# 37  unfortunately          1
# 38           need          1
# 39            use          1
# 40            has          1
# 41    significant          1
# 42            ...          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#           Word  Frequency
# 0           we          5
# 1          our          2
# 2          and          2
# 3         then          2
# 4            .          2
# 5         that          2
# 6         note          1
# 7            :          1
# 8      reached          1
# 9         goal          1
# 10        some          1
# 11          in          1
# 12        less          1
# 13        than          1
# 14          40          1
# 15     minutes          1
# 16       after          1
# 17        went          1
# 18      public          1
# 19        with          1
# 20        this          1
# 21    campaign          1
# 22     stopped          1
# 23   accepting          1
# 24   donations          1
# 25     because          1
# 26         aim          1
# 27          is          1
# 28          to          1
# 29        fund          1
# 30  re-opening          1
# 31         the          1
# 32  bombed-out          1
# 33      office          1
# 34           ,          1
# 35     decided          1
# 36         had          1
# 37    gathered          1
# 38           a          1
# 39  reasonable          1
# 40      amount          1
# 41         for          1
# 42     purpose          1
# 43       there          1
# 44         are          1
# 45        many          1
# 46        wort          1
# 47         ...          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#           Word  Frequency
# 0            ,          3
# 1           to          3
# 2            .          2
# 3          and          2
# 4         help          2
# 5            ￼          1
# 6       moises          1
# 7      sanchez          1
# 8            a          1
# 9        texas          1
# 10       state          1
# 11     trooper          1
# 12         was          1
# 13        shot          1
# 14       while          1
# 15  responding          1
# 16          an          1
# 17    accident          1
# 18          he          1
# 19          is          1
# 20   currently          1
# 21          in          1
# 22      stable          1
# 23         but          1
# 24    critical          1
# 25   condition          1
# 26   following          1
# 27     surgery          1
# 28         him          1
# 29         his          1
# 30      family          1
# 31        need          1
# 32         all          1
# 33         the          1
# 34     support          1
# 35        they          1
# 36         can          1
# 37         get          1
# 38        them          1
# 39      during          1
# 40        this          1
# 41   difficult          1
# 42        time          1
# 43      please          1
# 44          by          1
# 45    donating          1
# 46           &          1
# 47    continue          1
# 48        pray          1
# 49         for          1
# 50           h          1
# 51         ...          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#            Word  Frequency
# 0             .          3
# 1            to          3
# 2            we          2
# 3           are          2
# 4            it          2
# 5          more          2
# 6           the          1
# 7    university          1
# 8            of          1
# 9      missouri          1
# 10            -          1
# 11      college          1
# 12  republicans          1
# 13           as          1
# 14          you          1
# 15          may          1
# 16         have          1
# 17         seen          1
# 18           in          1
# 19       recent          1
# 20         news          1
# 21            ,          1
# 22          has          1
# 23       become          1
# 24          and          1
# 25    difficult          1
# 26        voice          1
# 27          our          1
# 28     opinions          1
# 29       freely          1
# 30           on          1
# 31       campus          1
# 32           is          1
# 33          now          1
# 34        legal          1
# 35       report          1
# 36           ``          1
# 37      hateful          1
# 38       and/or          1
# 39      hurtful          1
# 40       speech          1
# 41           ''          1
# 42       mizzou          1
# 43           's          1
# 44       police          1
# 45   department          1
# 46       asking          1
# 47          for          1
# 48         your          1
# 49        suppo          1
# 50          ...          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#           Word  Frequency
# 0            ,          5
# 1       willis          4
# 2        karen          3
# 3          and          3
# 4         from          3
# 5        steve          2
# 6           of          2
# 7      brother          1
# 8      bennett          1
# 9          son          1
# 10     loretta          1
# 11      passed          1
# 12        away          1
# 13          on          1
# 14    november          1
# 15    13,2017.          1
# 16         had          1
# 17    suffered          1
# 18    numerous          1
# 19     medical          1
# 20      issues          1
# 21         for          1
# 22     several          1
# 23       years          1
# 24         his          1
# 25        only          1
# 26      income          1
# 27         was          1
# 28  disability          1
# 29        with          1
# 30     limited          1
# 31     support          1
# 32         her          1
# 33         mom          1
# 34           .          1
# 35           ’          1
# 36           s          1
# 37      father          1
# 38      donald          1
# 39        died          1
# 40         jus          1
# 41         ...          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#             Word  Frequency
# 0            the          6
# 1              .          3
# 2             of          3
# 3              ,          2
# 4             he          2
# 5   christianity          2
# 6          hello          1
# 7       everyone          1
# 8              i          1
# 9             'm          1
# 10         jesus          1
# 11           son          1
# 12           god          1
# 13       support          1
# 14            my          1
# 15         loyal          1
# 16        friend          1
# 17            ed          1
# 18            as          1
# 19          sets          1
# 20    historical          1
# 21        record          1
# 22      straight          1
# 23            by          1
# 24    re-writing          1
# 25       gospels          1
# 26           and          1
# 27         other          1
# 28           key          1
# 29         books          1
# 30           new          1
# 31     testament          1
# 32       through          1
# 33          lens          1
# 34        modern          1
# 35    republican          1
# 36             (          1
# 37            ``          1
# 38            ''          1
# 39             )          1
# 40     basically          1
# 41            's          1
# 42         going          1
# 43            to          1
# 44          take          1
# 45    situations          1
# 46            in          1
# 47             w          1
# 48           ...          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#           Word  Frequency
# 0         club          4
# 1          and          3
# 2           to          3
# 3         this          2
# 4           is          2
# 5         with          2
# 6      members          2
# 7            .          2
# 8           be          2
# 9      provide          2
# 10         for          2
# 11           ,          2
# 12       years          1
# 13        nohs          1
# 14       young          1
# 15  republican          1
# 16           ’          1
# 17           s          1
# 18         the          1
# 19     biggest          1
# 20          in          1
# 21      school          1
# 22     history          1
# 23          35          1
# 24  continuing          1
# 25        grow          1
# 26           a          1
# 27        size          1
# 28          we          1
# 29         are          1
# 30     seeking          1
# 31       funds          1
# 32        able          1
# 33        food          1
# 34    meetings          1
# 35        take          1
# 36       trips          1
# 37    t-shirts          1
# 38         all          1
# 39         any          1
# 40    donation          1
# 41       helps          1
# 42        will          1
# 43      greatl          1
# 44         ...          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#            Word  Frequency
# 0             ,          6
# 1            in          2
# 2            of          2
# 3           and          2
# 4             a          2
# 5           our          2
# 6          club          2
# 7          late          1
# 8          last          1
# 9         night          1
# 10           an          1
# 11          act          1
# 12         what          1
# 13          can          1
# 14         only          1
# 15           be          1
# 16    described          1
# 17           as          1
# 18       malice          1
# 19     domestic          1
# 20    terrorism          1
# 21        group          1
# 22       antifa          1
# 23      members          1
# 24   vandalized          1
# 25   historical          1
# 26   grassroots          1
# 27    manhattan          1
# 28           's          1
# 29        upper          1
# 30         east          1
# 31         side          1
# 32            .          1
# 33        doors          1
# 34         were          1
# 35   graffitied          1
# 36      windows          1
# 37      smashed          1
# 38         note          1
# 39  threatening          1
# 40       future          1
# 41     violence          1
# 42          was          1
# 43         left          1
# 44          for          1
# 45          the          1
# 46          ...          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#              Word  Frequency
# 0               .          3
# 1              my          3
# 2             the          3
# 3        facebook          2
# 4         twitter          2
# 5             has          2
# 6              to          2
# 7              me          2
# 8             was          2
# 9             and          2
# 10              &          1
# 11           done          1
# 12     everything          1
# 13       possible          1
# 14           shut          1
# 15           down          1
# 16        account          1
# 17        deleted          1
# 18         purged          1
# 19           from          1
# 20          100k+          1
# 21             2k          1
# 22           tell          1
# 23           that          1
# 24             's          1
# 25            not          1
# 26      corporate          1
# 27     censorship          1
# 28              ?          1
# 29            for          1
# 30           last          1
# 31              6          1
# 32          years          1
# 33       blogging          1
# 34           been          1
# 35           life          1
# 36             it          1
# 37           paid          1
# 38          bills          1
# 39              ,          1
# 40         helped          1
# 41         spread          1
# 42        message          1
# 43             of          1
# 44  compassionate          1
# 45              c          1
# 46            ...          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#              Word  Frequency
# 0              to          5
# 1        students          2
# 2    conservative          2
# 3            cpac          2
# 4               a          2
# 5             and          2
# 6       hillsdale          1
# 7         college          1
# 8     republicans          1
# 9            aims          1
# 10           take          1
# 11            the          1
# 12      political          1
# 13         action          1
# 14     conference          1
# 15              (          1
# 16              )          1
# 17          every          1
# 18           year          1
# 19             in          1
# 20     washington          1
# 21           d.c.          1
# 22            are          1
# 23           able          1
# 24         listen          1
# 25           vast          1
# 26          array          1
# 27             of          1
# 28       speakers          1
# 29          often          1
# 30           have          1
# 31  opportunities          1
# 32           meet          1
# 33        connect          1
# 34           with          1
# 35           them          1
# 36              .          1
# 37             is          1
# 38          great          1
# 39          place          1
# 40            for          1
# 41          stude          1
# 42            ...          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#           Word  Frequency
# 0            a          3
# 1            ,          3
# 2            .          3
# 3            i          2
# 4           my          2
# 5          and          2
# 6       update          1
# 7            :          1
# 8          set          1
# 9         goal          1
# 10    assuming          1
# 11      frugal          1
# 12     thrifty          1
# 13        trip          1
# 14           (          1
# 15   splitting          1
# 16       hotel          1
# 17        room          1
# 18       three          1
# 19        ways          1
# 20    choosing          1
# 21        less          1
# 22   desirable          1
# 23      flight          1
# 24        time          1
# 25         etc          1
# 26           )          1
# 27          'm          1
# 28         not          1
# 29       going          1
# 30          to          1
# 31      change          1
# 32    attitude          1
# 33     because          1
# 34          of          1
# 35        your          1
# 36  generosity          1
# 37         all          1
# 38       extra          1
# 39       funds          1
# 40        will          1
# 41          go          1
# 42      toward          1
# 43      fellow          1
# 44       young          1
# 45   deserving          1
# 46  delegation          1
# 47     members          1
# 48         you          1
# 49         can          1
# 50      donate          1
# 51           t          1
# 52         ...          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#             Word  Frequency
# 0            the          3
# 1             to          3
# 2              a          2
# 3              .          2
# 4            for          2
# 5            are          2
# 6            and          2
# 7             we          2
# 8      fairfield          1
# 9     university          1
# 10       college          1
# 11   republicans          1
# 12          will          1
# 13            be          1
# 14     traveling          1
# 15    washington          1
# 16            dc          1
# 17            in          1
# 18           few          1
# 19         weeks          1
# 20        attend          1
# 21          cpac          1
# 22             (          1
# 23  conservative          1
# 24     political          1
# 25        action          1
# 26    conference          1
# 27             )          1
# 28             ,          1
# 29          with          1
# 30         total          1
# 31            of          1
# 32            15          1
# 33          club          1
# 34       members          1
# 35         costs          1
# 36          trip          1
# 37          very          1
# 38          high          1
# 39         cover          1
# 40        travel          1
# 41         board          1
# 42        asking          1
# 43     donations          1
# 44          hope          1
# 45          that          1
# 46           ...          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#              Word  Frequency
# 0             the          4
# 1              to          4
# 2             and          3
# 3          temple          2
# 4      university          2
# 5              is          2
# 6         student          2
# 7       promoting          2
# 8         college          1
# 9     republicans          1
# 10              a          1
# 11   organization          1
# 12             on          1
# 13         campus          1
# 14           that          1
# 15      dedicated          1
# 16   conservative          1
# 17     republican          1
# 18         ideals          1
# 19           body          1
# 20              ,          1
# 21             in          1
# 22       addition          1
# 23      combating          1
# 24          truth          1
# 25           when          1
# 26             it          1
# 27          comes          1
# 28     liberalism          1
# 29  progressivism          1
# 30              .          1
# 31       proceeds          1
# 32           will          1
# 33            ...          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#            Word  Frequency
# 0             ,          4
# 1           the          2
# 2          back          2
# 3            we          2
# 4          will          2
# 5             ’          2
# 6       funding          2
# 7            to          2
# 8        events          2
# 9        eckerd          1
# 10      college          1
# 11  republicans          1
# 12          are          1
# 13           in          1
# 14       action          1
# 15        after          1
# 16           30          1
# 17        years          1
# 18            !          1
# 19           be          1
# 20    returning          1
# 21         this          1
# 22       coming          1
# 23       spring          1
# 24        2019.          1
# 25           re          1
# 26       asking          1
# 27            y          1
# 28          all          1
# 29          for          1
# 30          get          1
# 31         club          1
# 32      started          1
# 33           up          1
# 34        again          1
# 35            .          1
# 36           go          1
# 37      towards          1
# 38      hosting          1
# 39          our          1
# 40          own          1
# 41     meetings          1
# 42      parties          1
# 43          and          1
# 44    traveling          1
# 45        major          1
# 46    political          1
# 47        going          1
# 48          ...          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#              Word  Frequency
# 0          truman          2
# 1              of          2
# 2               a          2
# 3           about          2
# 4               ,          2
# 5              to          2
# 6               .          2
# 7              we          2
# 8             the          1
# 9           young          1
# 10     republican          1
# 11              ’          1
# 12              s          1
# 13           club          1
# 14       consists          1
# 15          group          1
# 16             15          1
# 17    responsible          1
# 18      motivated          1
# 19           high          1
# 20         school          1
# 21       students          1
# 22            who          1
# 23           wish          1
# 24        educate          1
# 25     themselves          1
# 26            and          1
# 27         others          1
# 28        current          1
# 29      political          1
# 30         issues          1
# 31             as          1
# 32     first-year          1
# 33   organization          1
# 34           have          1
# 35            had          1
# 36        limited          1
# 37  opportunities          1
# 38            for          1
# 39   fund-raising          1
# 40          would          1
# 41           like          1
# 42          broad          1
# 43            ...          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#            Word  Frequency
# 0          this          4
# 1            to          3
# 2           the          3
# 3             i          2
# 4           was          2
# 5       college          2
# 6             .          2
# 7        attend          2
# 8         april          1
# 9       elected          1
# 10        serve          1
# 11      florida          1
# 12   federation          1
# 13           of          1
# 14  republicans          1
# 15           as          1
# 16          2nd          1
# 17         vice          1
# 18   chairwoman          1
# 19         with          1
# 20      amazing          1
# 21  opportunity          1
# 22            ,          1
# 23      invited          1
# 24   republican          1
# 25     national          1
# 26   convention          1
# 27        which          1
# 28      happens          1
# 29   biannually          1
# 30         will          1
# 31           be          1
# 32           my          1
# 33         last          1
# 34       chance          1
# 35        event          1
# 36         that          1
# 37        takes          1
# 38        place          1
# 39          ...          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#          Word  Frequency
# 0          of          2
# 1         100          1
# 2           %          1
# 3         all          1
# 4    proceeds          1
# 5          go          1
# 6    directly          1
# 7          to          1
# 8         the          1
# 9     victims          1
# 10  hurricane          1
# 11   florence          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#            Word  Frequency
# 0             ,          4
# 1             .          4
# 2     augustana          3
# 3    university          3
# 4           are          3
# 5            at          2
# 6      students          2
# 7           the          2
# 8            we          2
# 9       student          2
# 10      leaders          1
# 11       strive          1
# 12           to          1
# 13      achieve          1
# 14      highest          1
# 15     possible          1
# 16     standard          1
# 17           of          1
# 18    community          1
# 19   excellence          1
# 20   leadership          1
# 21          and          1
# 22    diligence          1
# 23           as          1
# 24  republicans          1
# 25           no          1
# 26    different          1
# 27       almost          1
# 28          all          1
# 29       groups          1
# 30       funded          1
# 31       volunt          1
# 32          ...          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#             Word  Frequency
# 0            the          4
# 1        college          2
# 2    republicans          2
# 3            sju          2
# 4             in          2
# 5   philadelphia          2
# 6              .          2
# 7        chapter          2
# 8            and          2
# 9              ,          2
# 10            at          1
# 11          have          1
# 12           had          1
# 13             a          1
# 14         great          1
# 15      presence          1
# 16          area          1
# 17          this          1
# 18          year          1
# 19          were          1
# 20       awarded          1
# 21            of          1
# 22    excellence          1
# 23      continue          1
# 24            to          1
# 25      maintain          1
# 26          that          1
# 27        status          1
# 28           has          1
# 29     increased          1
# 30    membership          1
# 31        tabled          1
# 32     canvassed          1
# 33           for          1
# 34         local          1
# 35     elections          1
# 36          both          1
# 37            an          1
# 38           ...          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#            Word  Frequency
# 0           the          3
# 1             .          3
# 2       project          2
# 3          zero          2
# 4       waiting          2
# 5      families          2
# 6      children          2
# 7        foster          2
# 8        system          2
# 9            of          2
# 10         each          2
# 11         year          2
# 12        works          1
# 13           to          1
# 14      connect          1
# 15         with          1
# 16           in          1
# 17         care          1
# 18      through          1
# 19            a          1
# 20  combination          1
# 21       events          1
# 22          and          1
# 23     creation          1
# 24        short          1
# 25        films          1
# 26          are          1
# 27      created          1
# 28      however          1
# 29            ,          1
# 30         more          1
# 31        enter          1
# 32         hops          1
# 33         that          1
# 34          one          1
# 35          day          1
# 36        there          1
# 37         will          1
# 38           be          1
# 39          ...          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#             Word  Frequency
# 0            the          5
# 1             to          3
# 2             of          3
# 3              ,          3
# 4        members          2
# 5            and          2
# 6              .          2
# 7      president          2
# 8             we          1
# 9            are          1
# 10       raising          1
# 11         money          1
# 12          send          1
# 13          some          1
# 14           our          1
# 15          cpac          1
# 16            in          1
# 17    washington          1
# 18            dc          1
# 19            at          1
# 20           end          1
# 21      february          1
# 22         where          1
# 23          they          1
# 24           can          1
# 25       further          1
# 26         their          1
# 27     knowledge          1
# 28    leadership          1
# 29        skills          1
# 30          will          1
# 31          have          1
# 32        chance          1
# 33           see          1
# 34        united          1
# 35        states          1
# 36          vice          1
# 37          many          1
# 38         other          1
# 39  conservative          1
# 40       leaders          1
# 41          trip          1
# 42           wil          1
# 43           ...          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#        Word  Frequency
# 0   summary          1
# 1       was          1
# 2  nonetype          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#            Word  Frequency
# 0            to          4
# 1           the          2
# 2             .          2
# 3         bring          2
# 4             ,          2
# 5       college          1
# 6   republicans          1
# 7            at          1
# 8            uc          1
# 9         santa          1
# 10         cruz          1
# 11          are          1
# 12        proud          1
# 13     announce          1
# 14         they          1
# 15         will          1
# 16           be          1
# 17      raising          1
# 18        funds          1
# 19          for          1
# 20         2019          1
# 21            -          1
# 22         2020          1
# 23       school          1
# 24         year          1
# 25         with          1
# 26         past          1
# 27      support          1
# 28          our          1
# 29    community          1
# 30          has          1
# 31         made          1
# 32           it          1
# 33     possible          1
# 34        names          1
# 35         like          1
# 36        david          1
# 37     horowitz          1
# 38        cabot          1
# 39     phillips          1
# 40          and          1
# 41    christina          1
# 42         hoff          1
# 43      sommers          1
# 44         ucsc          1
# 45        going          1
# 46      forward          1
# 47           we          1
# 48         hope          1
# 49           no          1
# 50          ...          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#             Word  Frequency
# 0            the          3
# 1             of          2
# 2              ,          2
# 3    republicans          2
# 4            has          2
# 5             to          2
# 6   conservative          2
# 7              .          2
# 8         formed          1
# 9             in          1
# 10       january          1
# 11          2018          1
# 12       college          1
# 13        united          1
# 14       already          1
# 15         grown          1
# 16            be          1
# 17       largest          1
# 18       student          1
# 19  organization          1
# 20            at          1
# 21       arizona          1
# 22         state          1
# 23    university          1
# 24            we          1
# 25           are          1
# 26    upbringing          1
# 27             a          1
# 28           new          1
# 29    generation          1
# 30    millennial          1
# 31    revitalize          1
# 32          base          1
# 33          that          1
# 34          been          1
# 35     neglected          1
# 36         until          1
# 37         trump          1
# 38           era          1
# 39             c          1
# 40           ...          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#             Word  Frequency
# 0            the          4
# 1             to          3
# 2         campus          2
# 3            and          2
# 4           keep          2
# 5          texas          2
# 6            red          2
# 7             of          2
# 8              ,          2
# 9             we          2
# 10          help          1
# 11       college          1
# 12   republicans          1
# 13         serve          1
# 14            ut          1
# 15        austin          1
# 16           for          1
# 17       decades          1
# 18          come          1
# 19             !          1
# 20          next          1
# 21    generation          1
# 22         texan          1
# 23        voters          1
# 24       leaders          1
# 25            is          1
# 26       walking          1
# 27        around          1
# 28           our          1
# 29         right          1
# 30           now          1
# 31         daily          1
# 32         being          1
# 33           fed          1
# 34             a          1
# 35          diet          1
# 36       leftist          1
# 37          lies          1
# 38             .          1
# 39            if          1
# 40          want          1
# 41          need          1
# 42          make          1
# 43          sure          1
# 44          that          1
# 45  conservatism          1
# 46           ...          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#           Word  Frequency
# 0            :          2
# 1            i          2
# 2       steven          1
# 3           d.          1
# 4      bradley          1
# 5          age          1
# 6           63          1
# 7   occupation          1
# 8      cpa/cfo          1
# 9      retired          1
# 10          am          1
# 11           a          1
# 12  republican          1
# 13           .          1
# 14        have          1
# 15          be          1
# 16         ...          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#             Word  Frequency
# 0              ,          6
# 1             to          4
# 2             my          3
# 3              i          3
# 4             of          2
# 5          would          2
# 6           like          2
# 7            you          2
# 8              .          2
# 9           dear          1
# 10       friends          1
# 11        family          1
# 12         peers          1
# 13           and          1
# 14         other          1
# 15         great          1
# 16   influencers          1
# 17          life          1
# 18         first          1
# 19         thank          1
# 20           for          1
# 21        taking          1
# 22          your          1
# 23          time          1
# 24          read          1
# 25        letter          1
# 26            as          1
# 27          many          1
# 28          know          1
# 29          plan          1
# 30      continue          1
# 31     education          1
# 32         after          1
# 33          high          1
# 34        school          1
# 35            by          1
# 36      pursuing          1
# 37           the          1
# 38       medical          1
# 39         field          1
# 40  specifically          1
# 41        become          1
# 42             a          1
# 43     physician          1
# 44             ’          1
# 45           ...          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#             Word  Frequency
# 0             to          3
# 1            the          3
# 2           cpac          3
# 3            for          2
# 4             us          2
# 5           with          2
# 6       national          2
# 7             is          2
# 8          hello          1
# 9            all          1
# 10             !          1
# 11            we          1
# 12           are          1
# 13        asking          1
# 14     donations          1
# 15        assist          1
# 16           our          1
# 17        annual          1
# 18          trip          1
# 19  conservative          1
# 20     political          1
# 21        action          1
# 22    conference          1
# 23             (          1
# 24             )          1
# 25            at          1
# 26       gaylord          1
# 27    convention          1
# 28        center          1
# 29            in          1
# 30        harbor          1
# 31             .          1
# 32          2019          1
# 33      february          1
# 34            27          1
# 35             -          1
# 36         march          1
# 37            2.          1
# 38            an          1
# 39   opportunity          1
# 40         build          1
# 41   connections          1
# 42         other          1
# 43         conse          1
# 44           ...          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#             Word  Frequency
# 0              ,          4
# 1    republicans          2
# 2            the          2
# 3           have          2
# 4             we          2
# 5              .          2
# 6             to          2
# 7             on          2
# 8         campus          2
# 9           dear          1
# 10        fellow          1
# 11       bulldog          1
# 12            at          1
# 13           umd          1
# 14           had          1
# 15            an          1
# 16      eventful          1
# 17      semester          1
# 18           and          1
# 19           are          1
# 20       winding          1
# 21          down          1
# 22         after          1
# 23     elections          1
# 24         there          1
# 25            is          1
# 26         still          1
# 27        plenty          1
# 28            of          1
# 29          work          1
# 30            be          1
# 31          done          1
# 32           for          1
# 33            us          1
# 34       further          1
# 35        spread          1
# 36  conservative          1
# 37         voice          1
# 38     increased          1
# 39    membership          1
# 40        tabled          1
# 41  participated          1
# 42            in          1
# 43           ...          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#            Word  Frequency
# 0            to          3
# 1             .          2
# 2           the          1
# 3          ucsc          1
# 4       college          1
# 5   republicans          1
# 6          want          1
# 7         bring          1
# 8           you          1
# 9       amazing          1
# 10     speakers          1
# 11          and          1
# 12       events          1
# 13          our          1
# 14       campus          1
# 15           we          1
# 16         need          1
# 17        money          1
# 18         make          1
# 19         this          1
# 20       happen          1
# 21       thanks          1
# 22          for          1
# 23         your          1
# 24     generous          1
# 25      support          1
# 26            !          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#              Word  Frequency
# 0             for          3
# 1             our          2
# 2               ,          2
# 3         katelyn          2
# 4             has          2
# 5     congressman          2
# 6              in          2
# 7             and          2
# 8           niece          1
# 9            been          1
# 10       selected          1
# 11             as          1
# 12             an          1
# 13         intern          1
# 14          local          1
# 15           this          1
# 16         summer          1
# 17     washington          1
# 18             d.          1
# 19             c.          1
# 20   demonstrated          1
# 21  determination          1
# 22              a          1
# 23       positive          1
# 24       attitude          1
# 25      interning          1
# 26        hanford          1
# 27        valadao          1
# 28          while          1
# 29      attending          1
# 30            cos          1
# 31        working          1
# 32        visalia          1
# 33      emergency          1
# 34            aid          1
# 35              .          1
# 36            she          1
# 37       attended          1
# 38             uc          1
# 39          berke          1
# 40            ...          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#            Word  Frequency
# 0            to          3
# 1           for          3
# 2       college          2
# 3            at          2
# 4           the          2
# 5          will          2
# 6            be          2
# 7          used          2
# 8           and          2
# 9             ,          2
# 10  republicans          1
# 11      trinity          1
# 12           is          1
# 13    launching          1
# 14            a          1
# 15      capital          1
# 16     campaign          1
# 17            !          1
# 18        money          1
# 19       raised          1
# 20         host          1
# 21     speakers          1
# 22       events          1
# 23           on          1
# 24       campus          1
# 25            .          1
# 26         also          1
# 27        funds          1
# 28      provide          1
# 29        basic          1
# 30   operations          1
# 31         club          1
# 32         like          1
# 33    providing          1
# 34         food          1
# 35     meetings          1
# 36        fares          1
# 37        ubers          1
# 38           do          1
# 39         door          1
# 40     knocking          1
# 41        costs          1
# 42      marketi          1
# 43          ...          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#             Word  Frequency
# 0              .          4
# 1             we          3
# 2            the          2
# 3             to          2
# 4       students          2
# 5             on          2
# 6         campus          2
# 7            and          2
# 8             by          2
# 9           csuf          1
# 10   republicans          1
# 11          seek          1
# 12       support          1
# 13  conservative          1
# 14             ,          1
# 15    empowering          1
# 16          them          1
# 17            be          1
# 18        active          1
# 19            in          1
# 20     community          1
# 21           've          1
# 22         faced          1
# 23       attacks          1
# 24          from          1
# 25       liberal          1
# 26       student          1
# 27        groups          1
# 28        antifa          1
# 29           one          1
# 30           our          1
# 31           was          1
# 32    physically          1
# 33     assaulted          1
# 34             a          1
# 35     professor          1
# 36          were          1
# 37          even          1
# 38          sued          1
# 39    california          1
# 40     democrats          1
# 41             n          1
# 42           ...          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#             Word  Frequency
# 0             to          2
# 1            our          2
# 2             we          1
# 3            are          1
# 4        raising          1
# 5          money          1
# 6           fund          1
# 7          party          1
# 8       campaign          1
# 9              ,          1
# 10         serve          1
# 11  conservative          1
# 12      citizens          1
# 13            of          1
# 14          this          1
# 15        county          1
# 16             .          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#             Word  Frequency
# 0              .          3
# 1            the          2
# 2             to          2
# 3             my          1
# 4           name          1
# 5             is          1
# 6          avery          1
# 7        skiviat          1
# 8            and          1
# 9              i          1
# 10            am          1
# 11          part          1
# 12            of          1
# 13     political          1
# 14       science          1
# 15     community          1
# 16            at          1
# 17          penn          1
# 18         state          1
# 19       behrend          1
# 20           our          1
# 21  organization          1
# 22         wants          1
# 23        attend          1
# 24             a          1
# 25          trip          1
# 26       florida          1
# 27          from          1
# 28      december          1
# 29       19-22nd          1
# 30            we          1
# 31           are          1
# 32     attending          1
# 33       student          1
# 34        action          1
# 35        summit          1
# 36        hosted          1
# 37            by          1
# 38       turning          1
# 39         point          1
# 40           usa          1
# 41          this          1
# 42         event          1
# 43          will          1
# 44          have          1
# 45          over          1
# 46          4000          1
# 47       college          1
# 48      students          1
# 49        intere          1
# 50           ...          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#             Word  Frequency
# 0             we          4
# 1             to          4
# 2            the          3
# 3              .          3
# 4           room          3
# 5              a          3
# 6       torrance          2
# 7        sizzler          2
# 8             on          2
# 9             of          2
# 10          have          2
# 11          meet          1
# 12         every          1
# 13         third          1
# 14      thursday          1
# 15            at          1
# 16            in          1
# 17     sepulveda          1
# 18          blvd          1
# 19          last          1
# 20         month          1
# 21             ,          1
# 22          were          1
# 23       noticed          1
# 24           new          1
# 25        policy          1
# 26       changes          1
# 27     reserving          1
# 28           are          1
# 29           now          1
# 30         force          1
# 31           pay          1
# 32  non-refundae          1
# 33       deposit          1
# 34          book          1
# 35       meeting          1
# 36           min          1
# 37            50          1
# 38   memberships          1
# 39          year          1
# 40             b          1
# 41           ...          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#            Word  Frequency
# 0            to          8
# 1             ,          5
# 2             i          4
# 3            be          2
# 4          able          2
# 5          have          2
# 6             a          2
# 7           and          2
# 8        travel          2
# 9           for          2
# 10            .          2
# 11            ’          1
# 12            m          1
# 13      raising          1
# 14        money          1
# 15          fun          1
# 16     lifetime          1
# 17   experience          1
# 18  opportunity          1
# 19          the          1
# 20    dominican          1
# 21     republic          1
# 22            !          1
# 23           in          1
# 24        order          1
# 25           go          1
# 26          pay          1
# 27        three          1
# 28     specific          1
# 29        shots          1
# 30     passport          1
# 31        other          1
# 32       things          1
# ...
# 3               my          2
# 4   brother-in-law          2
# 5              ...          2
# 6              his          2
# 7             wife          2
# 8          several          1
# 9            years          1
# 10             ago          1
# 11        suffered          1
# 12          severe          1
# 13         strokes          1
# 14              is          1
# 15              an          1
# 16         invalid          1
# 17           makes          1
# 18            very          1
# 19          little          1
# 20           money          1
# 21             has          1
# 22              to          1
# 23             pay          1
# 24             for          1
# 25         medical          1
# 26        supplies          1
# 27   unfortunately          1
# 28            have          1
# 29               a          1
# 30        terminal          1
# 31         disease          1
# 32              'm          1
# 33            were          1
# 34         helping          1
# 35             him          1
# 36             out          1
# 37             but          1
# 38              ca          1
# 39             n't          1
# 40              do          1
# 41            that          1
# 42         anymore          1
# 43         because          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#          Word  Frequency
# 0           i          4
# 1           ,          3
# 2         but          2
# 3         are          2
# 4          to          2
# 5         and          2
# 6           .          2
# 7         our          2
# 8        kept          2
# 9        year          2
# 10         am          1
# 11       just          1
# 12        one          1
# 13      black          1
# 14      woman          1
# 15       know          1
# 16      there          1
# 17       many          1
# 18       more          1
# 19       with          1
# 20          a          1
# 21    college          1
# 22     degree          1
# 23     trying          1
# 24       stay          1
# 25     afloat          1
# 26   relevant          1
# 27        you          1
# 28       last          1
# 29       hope          1
# 30        see          1
# 31         if          1
# 32     anyone          1
# 33      cares          1
# 34      about          1
# 35     plight          1
# 36      could          1
# 37       tell          1
# 38  something          1
# 39        was          1
# 40      amiss          1
# 41   applying          1
# 42      after          1
# 43          (          1
# 44         10          1
# 45        yrs          1
# 46          )          1
# 47      being          1
# 48     denied          1
# 49        for          1
# 50  positions          1
# 51        ...          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#           Word  Frequency
# 0            i          4
# 1         that          4
# 2          and          2
# 3         this          2
# 4           as          2
# 5           of          2
# 6            .          2
# 7          for          2
# 8    president          2
# 9            ,          2
# 10     believe          1
# 11         the          1
# 12        2020          1
# 13    election          1
# 14         can          1
# 15          be          1
# 16         won          1
# 17          by          1
# 18         any          1
# 19    democrat          1
# 20           (          1
# 21    possibly          1
# 22  republican          1
# 23           )          1
# 24        runs          1
# 25        with          1
# 26        part          1
# 27       their          1
# 28    platform          1
# 29           a          1
# 30         man          1
# 31         has          1
# 32       voted          1
# 33       every          1
# 34     winning          1
# 35         was          1
# 36     capable          1
# 37      voting          1
# 38       until          1
# 39        find          1
# 40        have          1
# 41    sensible          1
# 42     outlook          1
# 43          on          1
# 44        life          1
# 45    politics          1
# 46         ...          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#            Word  Frequency
# 0    republican          4
# 1           the          4
# 2             a          2
# 3       support          2
# 4     candidate          2
# 5         josue          2
# 6        larose          2
# 7       florida          2
# 8            of          2
# 9           are          1
# 10          you          1
# 11           or          1
# 12    supporter          1
# 13            ,          1
# 14           if          1
# 15          yes          1
# 16       please          1
# 17  financially          1
# 18          for          1
# 19       senate          1
# 20        party          1
# 21           is          1
# 22   officially          1
# 23       asking          1
# 24          all          1
# 25  republicans          1
# 26       around          1
# 27       united          1
# 28       states          1
# 29      america          1
# 30           to          1
# 31          our          1
# 32     favorite          1
# 33            f          1
# 34          ...          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#               Word  Frequency
# 0              the          3
# 1              and          3
# 2                ,          2
# 3              for          2
# 4          dollars          2
# 5               of          2
# 6            every          1
# 7         american          1
# 8               no          1
# 9           matter          1
# 10           party          1
# 11              or          1
# 12      politics..          1
# 13            last          1
# 14               2          1
# 15           years          1
# 16            have          1
# 17             sat          1
# 18         watched          1
# 19             our          1
# 20            hard          1
# 21          earned          1
# 22             tax          1
# 23           spent          1
# 24          wasted          1
# 25              on          1
# 26       frivilous          1
# 27   non-objective          1
# 28     politically          1
# 29         pointed          1
# 30  investigations          1
# 31              to          1
# 32            tune          1
# 33               (          1
# 34              30          1
# 35         million          1
# 36               )          1
# 37          solely          1
# 38         purpose          1
# 39  delegitimizing          1
# 40               a          1
# 41            duly          1
# 42         elected          1
# 43           presi          1
# 44             ...          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#               Word  Frequency
# 0               to          4
# 1            their          3
# 2            right          2
# 3             have          2
# 4                a          2
# 5             that          2
# 6   disenfranchise          2
# 7             they          2
# 8             wing          1
# 9      republicans          1
# 10         devised          1
# 11            plan          1
# 12            will          1
# 13             try          1
# 14          single          1
# 15             out          1
# 16             and          1
# 17             the          1
# 18            poor          1
# 19         amongst          1
# 20              us          1
# 21               .          1
# 22          passed          1
# 23            bill          1
# 24              in          1
# 25           small          1
# 26      committees          1
# 27              is          1
# 28        designed          1
# 29          voters          1
# 30            from          1
# 31              be          1
# 32            able          1
# 33            cast          1
# 34          ballot          1
# 35            come          1
# 36           2020.          1
# 37             are          1
# 38           doing          1
# 39              so          1
# 40              by          1
# 41       requiring          1
# 42               c          1
# 43             ...          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#                 Word  Frequency
# 0                the          3
# 1                  i          2
# 2               have          2
# 3                 of          2
# 4         government          2
# 5                  ,          2
# 6                and          2
# 7                 to          2
# 8                for          1
# 9               last          1
# 10             seven          1
# 11             years          1
# 12              been          1
# 13           subject          1
# 14  unconstitutional          1
# 15      surveillance          1
# 16      interference          1
# 17       obstruction          1
# 18                 .          1
# 19                as          1
# 20                 a          1
# 21            result          1
# 22              this          1
# 23           blatant          1
# 24         disregard          1
# 25           america          1
# 26                's          1
# 27    constitutional          1
# 28         liberties          1
# 29           learned          1
# 30              much          1
# 31             about          1
# 32               how          1
# 33        interferes          1
# 34                in          1
# 35               our          1
# 36             daily          1
# 37             lives          1
# 38              what          1
# 39                we          1
# 40               can          1
# 41                do          1
# 42               ...          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#            Word  Frequency
# 0           the          4
# 1            to          3
# 2            in          2
# 3      virginia          2
# 4            of          2
# 5            at          2
# 6    republican          1
# 7      majority          1
# 8       general          1
# 9      assembly          1
# 10          has          1
# 11       fought          1
# 12          any          1
# 13       effort          1
# 14    introduce          1
# 15           or          1
# 16         pass          1
# 17      climate          1
# 18       action          1
# 19  legislation          1
# 20       reduce          1
# 21       carbon          1
# 22    emissions          1
# 23          and          1
# 24          opt          1
# 25            a          1
# 26        clean          1
# 27       energy          1
# 28       future          1
# 29        which          1
# 30     benefits          1
# 31          all          1
# 32           us          1
# 33            .          1
# 34           is          1
# 35          one          1
# 36       states          1
# 37         most          1
# 38         risk          1
# 39            :          1
# 40         from          1
# 41       rising          1
# 42          sea          1
# 43       levels          1
# 44        norfo          1
# 45          ...          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#               Word  Frequency
# 0              ...          4
# 1                a          3
# 2                .          3
# 3              the          2
# 4          america          2
# 5               on          2
# 6             that          2
# 7              for          2
# 8              has          2
# 9        september          1
# 10            11th          1
# 11         attacks          1
# 12             put          1
# 13      disastrous          1
# 14               ,          1
# 15  hyper-divisive          1
# 16           track          1
# 17              it          1
# 18              's          1
# 19            time          1
# 20              to          1
# 21           unite          1
# 22             and          1
# 23          change          1
# 24            fact          1
# 25              17          1
# 26           years          1
# 27          fought          1
# 28             war          1
# 29          terror          1
# 30        overseas          1
# 31          turned          1
# 32            into          1
# 33            full          1
# 34           blown          1
# 35           fight          1
# 36        american          1
# 37            soul          1
# 38            here          1
# 39              at          1
# 40            home          1
# 41            over          1
# 42           there          1
# 43              we          1
# 44             win          1
# 45            just          1
# 46           about          1
# 47           every          1
# 48               b          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#              Word  Frequency
# 0             and          3
# 1            rep.          3
# 2               ,          3
# 3            they          2
# 4            back          2
# 5               .          2
# 6       president          1
# 7           trump          1
# 8         tweeted          1
# 9              ``          1
# 10            why          1
# 11             do          1
# 12            n't          1
# 13             go          1
# 14           help          1
# 15            fix          1
# 16            the          1
# 17        totally          1
# 18         broken          1
# 19          crime          1
# 20       infested          1
# 21         places          1
# 22           from          1
# 23          which          1
# 24           came          1
# 25           then          1
# 26           come          1
# 27           show          1
# 28             us          1
# 29            how          1
# 30             it          1
# 31             is          1
# 32           done          1
# 33             ''          1
# 34             he          1
# 35            was          1
# 36        talking          1
# 37          about          1
# 38           four          1
# 39     democratic          1
# 40  congresswomen          1
# 41              ;          1
# 42     alexandria          1
# 43  ocasio-cortez          1
# 44          ilhan          1
# 45           omar          1
# 46         ayanna          1
# 47       pressley          1
# 48            ...          1
# ============================================================
# All frequencies, including STOPWORDS:
# ============================================================
#          Word  Frequency
# 0        have          3
# 1         and          2
# 2           ,          2
# 3           i          2
# 4        that          2
# 5         not          2
# 6           .          2
# 7          is          2
# 8          it          2
# 9         the          2
# 10         to          2
# 11       been          2
# 12     ladies          1
# 13  gentlemen          1
# 14       news          1
# 15        for          1
# 16        you          1
# 17        can          1
# 18       wait          1
# 19     global          1
# 20    warming          1
# 21       real          1
# 22         's          1
# 23     really          1
# 24  happening          1
# 25   greatest          1
# 26     threat          1
# 27       only          1
# 28        our          1
# 29   survival          1
# 30        but          1
# 31      every          1
# 32    species          1
# 33         on          1
# 34     planet          1
# 35         as          1
# 36       well          1
# 37      there          1
# 38   multiple          1
# 39   articles          1
# 40   recently          1
# 41  suggested          1
# 42       what          1
# 43        've          1
# 44   thinking          1
# 45       abou          1
# 46        ...          1
# ============================================================

# %%
rep_rslt.index.value_counts().head(20).sort_values(ascending=True).plot(kind='barh',figsize=(30,10))

# %%
# rep_rslt['count'] =1
# rep_rslt=rep_rslt.groupby('Word').agg({'count':'sum'})

# %%
rep_rslt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24590 entries, smu to !
# Data columns (total 1 columns):
# Frequency    24590 non-null int64
# dtypes: int64(1)
# memory usage: 384.2+ KB

# %%
rep_rslt=rep_rslt.reset_index()
rep_rslt['tag']='rep'
rep_rslt=rep_rslt.rename(columns={'count':'Frequency'})
rep_rslt['wd_pct']=rep_rslt['Frequency']/876
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-4540375c0002> in <module>
# ----> 1 rep_rslt=rep_rslt.reset_index()
#       2 rep_rslt['tag']='rep'
#       3 rep_rslt=rep_rslt.rename(columns={'count':'Frequency'})
#       4 rep_rslt['wd_pct']=rep_rslt['Frequency']/876
#       5 rep_rslt[20:30].plot(x='Word',y='Frequency',kind='barh',figsize=(30,10))
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    4429                 # to ndarray and maybe infer different dtype
#    4430                 level_values = _maybe_casted_values(lev, lab)
# -> 4431                 new_obj.insert(0, name, level_values)
#    4432
#    4433         new_obj.index = new_index
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    3471         value = self._sanitize_column(column, value, broadcast=False)
#    3472         self._data.insert(loc, column, value,
# -> 3473                           allow_duplicates=allow_duplicates)
#    3474
#    3475     def assign(self, **kwargs):
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/internals/managers.py in insert(self, loc, item, value, allow_duplicates)
#    1147         if not allow_duplicates and item in self.items:
#    1148             # Should this be a different kind of error??
# -> 1149             raise ValueError('cannot insert {}, already exists'.format(item))
#    1150
#    1151         if not isinstance(loc, int):
#
# ValueError: cannot insert level_0, already exists

# %%
rep_rslt.sort_values('wd_pct',ascending=False)
# Out:
#        level_0  index           Word  Frequency  tag    wd_pct
# 6530      6530   6530              ,         25  rep  0.028539
# 20092    20092  20092             --         23  rep  0.026256
# 18287    18287  18287             --         16  rep  0.018265
# 20933    20933  20933              !         13  rep  0.014840
# 22940    22940  22940              ,         12  rep  0.013699
# 18055    18055  18055              ,         12  rep  0.013699
# 11027    11027  11027              ,         10  rep  0.011416
# 15667    15667  15667              ,          9  rep  0.010274
# 6531      6531   6531              !          9  rep  0.010274
# 22731    22731  22731              !          9  rep  0.010274
# 7793      7793   7793              ,          8  rep  0.009132
# 8127      8127   8127              ,          8  rep  0.009132
# 5743      5743   5743              ,          8  rep  0.009132
# 6115      6115   6115              ,          8  rep  0.009132
# 6634      6634   6634              ,          8  rep  0.009132
# 12444    12444  12444              ,          7  rep  0.007991
# 6764      6764   6764              ,          7  rep  0.007991
# 12169    12169  12169              ,          7  rep  0.007991
# 1339      1339   1339              ,          7  rep  0.007991
# 5660      5660   5660              .          7  rep  0.007991
# 8810      8810   8810              ,          7  rep  0.007991
# 7377      7377   7377              !          7  rep  0.007991
# 19647    19647  19647              ,          7  rep  0.007991
# 7762      7762   7762              ,          7  rep  0.007991
# 9732      9732   9732              ,          7  rep  0.007991
# 15018    15018  15018              ,          7  rep  0.007991
# 4111      4111   4111              .          7  rep  0.007991
# 4650      4650   4650              ,          7  rep  0.007991
# 23979    23979  23979              ,          7  rep  0.007991
# 10566    10566  10566              ,          7  rep  0.007991
# ...        ...    ...            ...        ...  ...       ...
# 9946      9946   9946           feed          1  rep  0.001142
# 9945      9945   9945           help          1  rep  0.001142
# 9943      9943   9943            ...          1  rep  0.001142
# 9942      9942   9942             th          1  rep  0.001142
# 9941      9941   9941              :          1  rep  0.001142
# 9940      9940   9940        ferrari          1  rep  0.001142
# 9939      9939   9939       marianne          1  rep  0.001142
# 9938      9938   9938     statements          1  rep  0.001142
# 9956      9956   9956     republican          1  rep  0.001142
# 9958      9958   9958              .          1  rep  0.001142
# 1742      1742   1742           made          1  rep  0.001142
# 9959      9959   9959           fast          1  rep  0.001142
# 1743      1743   1743  international          1  rep  0.001142
# 1744      1744   1744          named          1  rep  0.001142
# 1745      1745   1745         valley          1  rep  0.001142
# 1746      1746   1746            ...          1  rep  0.001142
# 9972      9972   9972            ...          1  rep  0.001142
# 9971      9971   9971          purch          1  rep  0.001142
# 9970      9970   9970       kindness          1  rep  0.001142
# 9969      9969   9969           acts          1  rep  0.001142
# 9968      9968   9968         random          1  rep  0.001142
# 9967      9967   9967        perform          1  rep  0.001142
# 9966      9966   9966        located          1  rep  0.001142
# 9965      9965   9965          areas          1  rep  0.001142
# 9964      9964   9964         family          1  rep  0.001142
# 9963      9963   9963           send          1  rep  0.001142
# 9962      9962   9962           area          1  rep  0.001142
# 9961      9961   9961          chain          1  rep  0.001142
# 9960      9960   9960           food          1  rep  0.001142
# 24589    24589  24589              !          1  rep  0.001142
#
# [24590 rows x 6 columns]

# %%
rep_rslt.sort_values('wd_pct',ascending=False)[20:30].plot(x='Word',y='wd_pct',kind='barh',figsize=(30,20))

# %%
#campaigns with the word democrat
top_N = 500
txt = df[df['tag']=='dem']['summary'].str.lower().str.replace(r'\|', ' ').str.cat(sep=' ')
words = nltk.tokenize.word_tokenize(txt)
word_dist = nltk.FreqDist(words)
stopwords = nltk.corpus.stopwords.words('english')
words_except_stop_dist = nltk.FreqDist(w for w in words if w not in stopwords) 
print('All frequencies, including STOPWORDS:')
print('=' * 60)
rslt = pd.DataFrame(word_dist.most_common(top_N),
                    columns=['Word', 'Frequency'])
print(rslt)
print('=' * 60)
dem_rslt = pd.DataFrame(words_except_stop_dist.most_common(top_N),
                    columns=['Word', 'Frequency']).set_index('Word')
dem_rslt['tag']='dem'
dem_rslt['wd_pct']=dem_rslt['Frequency']/1316
# matplotlib.style.use('ggplot')
dem_rslt[20:30].plot.bar(rot=0,figsize=(30,10))
# Out:
# All frequencies, including STOPWORDS:
# ============================================================
#               Word  Frequency
# 0              the       1428
# 1                ,       1228
# 2               to       1104
# 3                .       1093
# 4              and        895
# 5                i        706
# 6               of        696
# 7                a        672
# 8               in        587
# 9              ...        570
# 10             for        463
# 11              is        396
# 12              my        293
# 13              we        285
# 14             our        236
# 15            this        234
# 16               !        232
# 17       democrats        230
# 18            have        226
# 19              as        218
# 20              on        212
# 21            that        185
# 22            will        184
# 23             are        180
# 24              am        178
# 25              be        175
# 26             was        150
# 27            help        149
# 28      democratic        145
# 29            with        138
# ..             ...        ...
# 470        project          8
# 471          below          8
# 472          white          8
# 473      francisco          8
# 474     nomination          8
# 475           vice          8
# 476        october          8
# 477            big          8
# 478             dc          8
# 479         attack          8
# 480         donors          8
# 481       michigan          8
# 482        seeking          8
# 483        dollars          8
# 484         giving          8
# 485          three          8
# 486           same          8
# 487          start          8
# 488          built          8
# 489            don          8
# 490          cause          8
# 491         should          8
# 492  investigation          8
# 493          water          8
# 494       platform          8
# 495          spent          8
# 496        outside          8
# 497           paso          8
# 498      financial          8
# 499        summary          8
#
# [500 rows x 2 columns]
# ============================================================

# %%
rep_rslt.head(10)
# Out:
#    level_0  index         Word  Frequency  tag    wd_pct
# 0        0      0          smu          4  rep  0.004566
# 1        1      1            ,          3  rep  0.003425
# 2        2      2      crowder          2  rep  0.002283
# 3        3      3     mcfarlin          2  rep  0.002283
# 4        4      4            .          2  rep  0.002283
# 5        5      5      college          1  rep  0.001142
# 6        6      6  republicans          1  rep  0.001142
# 7        7      7     bringing          1  rep  0.001142
# 8        8      8     comedian          1  rep  0.001142
# 9        9      9       steven          1  rep  0.001142

# %%
#all words
top_N = 500
txt = df['summary'].str.lower().str.replace(r'\|', ' ').str.cat(sep=' ')
words = nltk.tokenize.word_tokenize(txt)
word_dist = nltk.FreqDist(words)
stopwords = nltk.corpus.stopwords.words('english')
words_except_stop_dist = nltk.FreqDist(w for w in words if w not in stopwords) 
print('All frequencies, including STOPWORDS:')
print('=' * 60)
rslt = pd.DataFrame(word_dist.most_common(top_N),
                    columns=['Word', 'Frequency'])
print(rslt)
print('=' * 60)
rslt = pd.DataFrame(words_except_stop_dist.most_common(top_N),
                    columns=['Word', 'Frequency']).set_index('Word')
matplotlib.style.use('ggplot')
rslt[20:30].plot.bar(rot=0,figsize=(30,10))
# Out:
# All frequencies, including STOPWORDS:
# ============================================================
#            Word  Frequency
# 0           the       3333
# 1             ,       2911
# 2             .       2664
# 3            to       2615
# 4           and       2085
# 5             a       1711
# 6             i       1697
# 7            of       1616
# 8            in       1399
# 9           ...       1374
# 10          for       1102
# 11           is        964
# 12           my        706
# 13           we        646
# 14         this        546
# 15            !        540
# 16           on        519
# 17          our        499
# 18         that        496
# 19         have        491
# 20           as        467
# 21          are        458
# 22           am        412
# 23           be        409
# 24         will        406
# 25          was        376
# 26         with        370
# 27          you        360
# 28           it        335
# 29           's        323
# ..          ...        ...
# 470           '         20
# 471         car         20
# 472       white         20
# 473        stop         20
# 474  fundraiser         20
# 475    business         20
# 476     dollars         20
# 477        york         20
# 478     justice         20
# 479    possible         19
# 480        hope         19
# 481      events         19
# 482      worked         19
# 483     however         19
# 484       month         19
# 485         say         19
# 486      create         19
# 487          th         19
# 488  immigrants         19
# 489    platform         19
# 490     website         19
# 491        blue         19
# 492   supporter         19
# 493        kids         19
# 494        held         19
# 495       below         19
# 496        wife         19
# 497        four         19
# 498     decided         18
# 499         god         18
#
# [500 rows x 2 columns]
# ============================================================

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 500 entries, , to race
# Data columns (total 1 columns):
# Frequency    500 non-null int64
# dtypes: int64(1)
# memory usage: 7.8+ KB

# %%
words_df=rep_rslt.append(dem_rslt)
words_df=words_df.reset_index()

# %%
rslt=rslt.reset_index()

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
# Word         500 non-null object
# Frequency    500 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 7.9+ KB

# %%
# Out:
#          Word  Frequency
# 0           ,       2911
# 1           .       2664
# 2         ...       1374
# 3           !        540
# 4          's        323
# 5        help        311
# 6  republican        275
# 7   democrats        275
# 8           ’        270
# 9           :        255

# %%
ser_df=rslt
ser_df=ser_df.rename(columns={'Frequency':'total'})

# %%
ser_df.head(3)
# Out:
#   Word  total
# 0    ,   2911
# 1    .   2664
# 2  ...   1374

# %%
words_df=words_df.merge(ser_df,left_on='Word',right_on='Word',how='left')
words_df.head()
# Out:
#          Word  Frequency  tag    wd_pct   total
# 0           ,       1683  rep  0.659741  2911.0
# 1           .       1571  rep  0.615837  2664.0
# 2         ...        804  rep  0.315171  1374.0
# 3           !        308  rep  0.120737   540.0
# 4  republican        273  rep  0.107017   275.0

# %%
ser_df[ser_df['Word']=='republican']
# Out:
#          Word  total
# 6  republican    275

# %%
rslt[rslt['Word']=='republican']
# Out:
#          Word  Frequency
# 6  republican        275

# %%
words_df[words_df['Word']=='republican']
# Out:
#          Word  Frequency  tag    wd_pct  total
# 4  republican        273  rep  0.107017  275.0

# %%
ser=words_df.total

# %%
words_df['word_bin']=pd.qcut(ser, q=5,labels=['1','2','3','4','5'])

# sns.catplot(kind='bar',x='Frequency',y='Word',hue='tag',row='word_bin',data=words_df,height=20,aspect=2)

# %%
#making individual bins because 
words_df_3=words_df[words_df['word_bin']=='3']
words_df_1=words_df[words_df['word_bin']=='1']
words_df_2=words_df[words_df['word_bin']=='2']
words_df_4=words_df[words_df['word_bin']=='4']
words_df_5=words_df[words_df['word_bin']=='5']

# %%
words_df_3.Word.unique()
# Out:
# array(['nonetype', 'congress', 'start', '”', 'right', 'raised',
#        'presidential', 'story', 'left', 'come', 'governor', 'club', 'ago',
#        '#', 'small', 'way', 'long', 'change', 'together', 'week', 'keep',
#        'used', 'good', 'group', 'care', 'education', 'city', 'show',
#        'media', 'important', 'former', 'around', 'build', 'trying',
#        'must', 'law', 'issues', 'fellow', 'bring', 'november', 'friend',
#        'continue', 'dear', 'read', '5', 'helping', 'today', 'june',
#        'future', 'past', 'voters', 'still', 'part', 'little', 'put',
#        'news', 'become', 'cover', 'travel', 'funding', 'lives', 'strong',
#        'member', '4', 'ca', 'voting', 'nation', 'page', 'march',
#        'facebook', 'liberal', 'ever', 'lost', 'expenses', 'senator',
#        'hard', 'away', 'provide', 'getting', 'world', 'send', 'cost',
#        'delegates', 'hillary', 'dnc', 'progressive', 'honor', 'upcoming',
#        'san'], dtype=object)

# %%
sns.catplot(y="Word", x="wd_pct", hue="tag", kind="bar", 
            data=words_df_3[words_df_3.Word.isin(['$', '--','-', '?',"'m",'``',"''",';','“','”','nonetype'])==False], 
            height=7, aspect=11.7/8.27,palette='husl')

# %%
words_df_5.Word.unique()
# Out:
# array([',', '.', '...', '!', 'republican', "'s", '’', ':', 'help', '(',
#        ')', 'trump', 'republicans', 'people', 'money', 'support', 'state',
#        'years', 'party', '``', 'name', "''", 'campaign', "'m", 'need',
#        'political', 'time', 'president', 'get', 'want', 'family', 'like',
#        'would', 'us', '-', '?', 'one', 'many', 'new', 'america',
#        'national', 'year', 'college', 'make', 'country', 'county', '$',
#        '--', 'school', 'conservative', 'american', 'states', 'democratic',
#        'united', 'election', 'please', 'first', 'democrat', 'life', 'go',
#        'know', 'running', 'elected', 'great', 'democrats', 'vote', "n't",
#        'community', 'raise', 'hello', 'funds', 'hi', 'convention',
#        'raising', 'district', 'friends', 'work', 'since', 'young', 'fund',
#        'house', 'high', 'delegate', '2016', 'bernie', 'sanders'],
#       dtype=object)

# %%
sns.catplot(y="Word", x="wd_pct", hue="tag", kind="bar", 
            data=words_df_5[words_df_5.Word.isin([',', '.',"'s", '’', ':','(',')',"'m","''",'``','“',"'ve",';','(',')',"n't",'--','-'])==False], 
            height=7, aspect=11.7/8.27,palette='husl')

# %%
sns.catplot(y="Word", x="wd_pct", hue="tag", kind="bar", 
            data=words_df_4[words_df_4.Word.isin([',', '.',"'s", '’', ':','(',')',"'m","''",'``','“',"'ve",';'])==False], 
            height=7, aspect=11.7/8.27,palette='husl')

# %%
ser
