# %%
import pandas as pd
import requests
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import re
import time
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support import expected_conditions as EC
import seaborn as sns
import nltk
nltk.download('punkt')
nltk.download('stopwords')
sns.set(style='whitegrid',palette='husl')
matplotlib.rcParams['pdf.fonttype'] = 42

# %matplotlib inline
# Out:
# [nltk_data] Downloading package punkt to /Users/lilyliu-
# [nltk_data]     krason/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/lilyliu-
# [nltk_data]     krason/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# !pip install nltk

# %%
df=pd.read_csv('merged_cleaned.csv',thousands=',')

# %%
df=df.drop(columns=['raised','goal'])

# %%
df.head(3)
# Out:
#    Unnamed: 0                                               link  \
# 0           0  https://www.gofundme.com/steven-crowder-live-a...
# 1           1  https://www.gofundme.com/reopen-a-nc-republica...
# 2           3                     https://www.gofundme.com/mugop
#
#         location                                            summary  \
# 0     Dallas, TX  SMU College Republicans is bringing comedian S...
# 1  Brookline, MA  NOTE: We reached our goal and then some in les...
# 2   Columbia, MO  We are the University of Missouri - College Re...
#
#                                 title  tag        created_date  goal_int  \
# 0         Steven Crowder Live at SMU!  rep       March 7, 2018    6500.0
# 1  Dems help reopen a NC Repub office  rep    October 16, 2016   10000.0
# 2          Mizzou College Republicans  rep   November 17, 2015    5000.0
#
#    raised_int
# 0      2710.0
# 1     12857.0
# 2      3649.0

# %%
#converting dates
df['date']=pd.to_datetime(df.created_date,infer_datetime_format=True)

# %%
df.head(3)
# Out:
#    Unnamed: 0                                               link  \
# 0           0  https://www.gofundme.com/steven-crowder-live-a...
# 1           1  https://www.gofundme.com/reopen-a-nc-republica...
# 2           3                     https://www.gofundme.com/mugop
#
#         location                                            summary  \
# 0     Dallas, TX  SMU College Republicans is bringing comedian S...
# 1  Brookline, MA  NOTE: We reached our goal and then some in les...
# 2   Columbia, MO  We are the University of Missouri - College Re...
#
#                                 title  tag        created_date  goal_int  \
# 0         Steven Crowder Live at SMU!  rep       March 7, 2018    6500.0
# 1  Dems help reopen a NC Repub office  rep    October 16, 2016   10000.0
# 2          Mizzou College Republicans  rep   November 17, 2015    5000.0
#
#    raised_int       date
# 0      2710.0 2018-03-07
# 1     12857.0 2016-10-16
# 2      3649.0 2015-11-17

# %%
# df = df.set_index('date')

# %%
#creating Year, Month, Weekday Name
df['Year'] = df.date.dt.year
df['Month'] = df.date.dt.month
df['Weekday Name'] = df.date.dt.weekday_name

# %%
df.head(3)
# Out:
#    Unnamed: 0                                               link  \
# 0           0  https://www.gofundme.com/steven-crowder-live-a...
# 1           1  https://www.gofundme.com/reopen-a-nc-republica...
# 2           3                     https://www.gofundme.com/mugop
#
#         location                                            summary  \
# 0     Dallas, TX  SMU College Republicans is bringing comedian S...
# 1  Brookline, MA  NOTE: We reached our goal and then some in les...
# 2   Columbia, MO  We are the University of Missouri - College Re...
#
#                                 title  tag        created_date  goal_int  \
# 0         Steven Crowder Live at SMU!  rep       March 7, 2018    6500.0
# 1  Dems help reopen a NC Repub office  rep    October 16, 2016   10000.0
# 2          Mizzou College Republicans  rep   November 17, 2015    5000.0
#
#    raised_int       date  Year  Month Weekday Name
# 0      2710.0 2018-03-07  2018      3    Wednesday
# 1     12857.0 2016-10-16  2016     10       Sunday
# 2      3649.0 2015-11-17  2015     11      Tuesday

# %%
#adding state in hoping for some pretty colors

# %% [markdown]
# # Using Crosstab to Compare "Democrat" vs "Republican"

# %%
pd.crosstab(index=df.Year,columns=df.tag).plot(kind='barh',stacked=True,title='Campaigns Created By Year Containing Word')

# %%
pd.crosstab(index=df.Month,columns=df.tag).plot(kind='barh',stacked=True,width=0.7,title='Campaigns Created By Month Containing Word',figsize=(10,10))

# %%
pd.crosstab(index=df['Weekday Name'],columns=df.tag).plot(kind='barh',stacked=True,width=0.7,title='Campaigns Created By Day of Week Containing Word',figsize=(10,10))

# %%
df.groupby('tag')['goal_int'].sum()
# Out:
# tag
# dem    5.063720e+09
# rep    1.649724e+10
# Name: goal_int, dtype: float64

# %%
sns.lmplot(x='Month',y='goal_int',hue='tag',data=df)

# %% [markdown]
# # Aggregate Graphs

# %%
# #using seaborn time series formatting
# sns.set(rc={'figure.figsize':(11, 4)})

# %%
df['Weekday Name'] = pd.Categorical(df['Weekday Name'], categories=
    ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday', 'Sunday'],
    ordered=True)

# %%
created_by_day = df['Weekday Name'].value_counts()
created_by_day = created_by_day.sort_index(ascending=False)
created_by_day.plot(kind='barh',width=0.8,title= "Day of the Week Campaigns Are Created")
plt.savefig("agg_day_of_week.pdf")

# %%
rep_year=df[df['tag']=='rep'].Year.value_counts().rename_axis('Year').reset_index(name='rep_counts')
dem_year =df[df['tag']=='dem'].Year.value_counts().rename_axis('Year').reset_index(name='dem_counts')

# %%
#total amount raised
#what is this scale though? How do I change this?
df.groupby('Year')['raised_int'].sum().plot(kind='barh',title='Total Amount Raised by Campaigns that Mention "Democrat" or "Republican"')

# plt.savefig("total_amount_raised.pdf")

# %%
data=pd.DataFrame(df.groupby('Year')['tag'].value_counts())

# %%
df.groupby('tag')['raised_int'].sum().plot(kind='barh',title='Total Raised by Campaigns by Word Mention')

# %%
#another way not as good as crosstab
year_df=rep_year.merge(dem_year, left_on='Year',right_on='Year')
year_df.sort_values('Year').set_index('Year').plot(kind='barh',stacked=True,width=0.8,title='Campaigns Created By Word Mention',figsize=(10,10))
# plt.savefig("campaigns_stacked.pdf")

# %%
# #some other BS I did
rep_Month=df[df['tag']=='rep'].Month.value_counts().rename_axis('Month').reset_index(name='rep_counts')
dem_Month =df[df['tag']=='dem'].Month.value_counts().rename_axis('Month').reset_index(name='dem_counts')
Month_df=rep_Month.merge(dem_Month, left_on='Month',right_on='Month')
Month_df.sort_values('Month').set_index('Month').sort_values(by='Month',ascending=False).plot(kind='barh',stacked=True,width=0.7,title='Campaigns Created By Word Mention')
plt.savefig("campaigns_stacked2.1.pdf")

# %%
df.sample(5, random_state=0)
# Out:
#       Unnamed: 0                                               link  \
# 799          903  https://www.gofundme.com/establish-hitchens-cu...
# 1047         249          https://www.gofundme.com/greenforbernie16
# 1436         878  https://www.gofundme.com/recall-mayor-of-los-a...
# 54            61                https://www.gofundme.com/1oi4td52o0
# 793          894  https://www.gofundme.com/xbhak-trump-loves-imm...
#
#                 location                                            summary  \
# 799       Greensboro, NC  “We have deeply held beliefs in rational think...
# 1047         Marrero, LA  Hello, I'm Kyle Green. In May, I was elected b...
# 1436  Canyon Country, CA  Eric Garcetti has failed to protect the people...
# 54            Dallas, TX  My goal is to train our youth in the art of gu...
# 793     Grand Rapids, MI  MISSION: TO EMPOWER THE REPUBLICAN IMMIGRANTS ...
#
#                                           title  tag    created_date  \
# 799                    Hitchens Cultural Center  rep    June 1, 2019
# 1047         Louisiana Delegate for Bernie Fund  dem   June 22, 2016
# 1436  Recall Mayor of Los Angeles Eric Garcetti  dem   June 11, 2019
# 54           Gun Training For Young Republicans  rep   June 27, 2019
# 793                      TRUMP LOVES IMMIGRANTS  rep    June 6, 2019
#
#        goal_int  raised_int       date  Year  Month Weekday Name
# 799     10000.0         0.0 2019-06-01  2019      6     Saturday
# 1047     3300.0      3352.0 2016-06-22  2016      6    Wednesday
# 1436  1000000.0         0.0 2019-06-11  2019      6      Tuesday
# 54      10000.0         0.0 2019-06-27  2019      6     Thursday
# 793      1000.0         0.0 2019-06-06  2019      6     Thursday

# %%
rep_Weekday_Name=df[df['tag']=='rep']['Weekday Name'].value_counts().rename_axis('Weekday Name').reset_index(name='rep_counts')
dem_Weekday_Name =df[df['tag']=='dem']['Weekday Name'].value_counts().rename_axis('Weekday Name').reset_index(name='dem_counts')
Weekday_Name_df=rep_Weekday_Name.merge(dem_Weekday_Name, left_on='Weekday Name',right_on='Weekday Name')
Weekday_Name_df.sort_values('Weekday Name').set_index('Weekday Name').plot(kind='barh',stacked=True,width=0.8,title='Campaigns Created By Word Mention')

plt.savefig("output.pdf")

# %%
df.groupby('tag')['Weekday Name'].value_counts()
# Out:
# tag  Weekday Name
# dem  Tuesday         110
#      Wednesday        97
#      Monday           93
#      Thursday         89
#      Sunday           87
#      Friday           73
#      Saturday         69
# rep  Tuesday         139
#      Thursday        136
#      Wednesday       133
#      Monday          130
#      Saturday        116
#      Sunday          112
#      Friday          110
# Name: Weekday Name, dtype: int64

# %%
#playing with groupbys 
df.groupby('tag')['Weekday Name'].value_counts().plot(kind='barh',stacked=True,width=0.8,title='Campaigns Created By Word Mention')

# %%
df.sample(3, random_state=0)
# Out:
#       Unnamed: 0                                               link  \
# 799          903  https://www.gofundme.com/establish-hitchens-cu...
# 1047         249          https://www.gofundme.com/greenforbernie16
# 1436         878  https://www.gofundme.com/recall-mayor-of-los-a...
#
#                 location                                            summary  \
# 799       Greensboro, NC  “We have deeply held beliefs in rational think...
# 1047         Marrero, LA  Hello, I'm Kyle Green. In May, I was elected b...
# 1436  Canyon Country, CA  Eric Garcetti has failed to protect the people...
#
#                                           title  tag    created_date  \
# 799                    Hitchens Cultural Center  rep    June 1, 2019
# 1047         Louisiana Delegate for Bernie Fund  dem   June 22, 2016
# 1436  Recall Mayor of Los Angeles Eric Garcetti  dem   June 11, 2019
#
#        goal_int  raised_int       date  Year  Month Weekday Name
# 799     10000.0         0.0 2019-06-01  2019      6     Saturday
# 1047     3300.0      3352.0 2016-06-22  2016      6    Wednesday
# 1436  1000000.0         0.0 2019-06-11  2019      6      Tuesday

# %%
#the graveyard
data = df[df['raised_int']==0]
sns.relplot(data=data, x='Weekday Name', y='goal_int', hue='tag')

# %% [markdown]
# # Common Words!

# %%
#campaigns with the word republican
top_N = 500
txt = df[df['tag']=='rep']['summary'].str.lower().str.replace(r'\|', ' ').str.cat(sep=' ')
words = nltk.tokenize.word_tokenize(txt)
word_dist = nltk.FreqDist(words)
stopwords = nltk.corpus.stopwords.words('english')
words_except_stop_dist = nltk.FreqDist(w for w in words if w not in stopwords) 
print('All frequencies, including STOPWORDS:')
print('=' * 60)
rslt = pd.DataFrame(word_dist.most_common(top_N),
                    columns=['Word', 'Frequency'])
print(rslt)
print('=' * 60)
rep_rslt = pd.DataFrame(words_except_stop_dist.most_common(top_N),
                    columns=['Word', 'Frequency']).set_index('Word')
rep_rslt['tag']='rep'
rep_rslt['wd_pct']=rep_rslt['Frequency']/2551
# matplotlib.style.use('ggplot')
rep_rslt[20:30].plot.bar(rot=0,figsize=(30,10))
# Out:
# All frequencies, including STOPWORDS:
# ============================================================
#             Word  Frequency
# 0            the       1905
# 1              ,       1683
# 2              .       1571
# 3             to       1511
# 4            and       1190
# 5              a       1039
# 6              i        991
# 7             of        920
# 8             in        812
# 9            ...        804
# 10           for        639
# 11            is        568
# 12            my        413
# 13            we        361
# 14          this        312
# 15          that        311
# 16             !        308
# 17            on        307
# 18           are        278
# 19    republican        273
# 20          have        265
# 21           our        263
# 22            as        249
# 23           you        238
# 24            be        234
# 25            am        234
# 26          with        232
# 27           was        226
# 28          will        222
# 29            it        198
# ..           ...        ...
# 470    represent         12
# 471  information         12
# 472    socialist         12
# 473      without         12
# 474         cost         12
# 475         team         12
# 476    campaigns         12
# 477            2         12
# 478    supporter         12
# 479     involved         12
# 480      process         12
# 481        white         12
# 482       middle         12
# 483         true         12
# 484     anything         12
# 485      dollars         12
# 486           10         12
# 487         join         12
# 488     official         12
# 489         york         12
# 490       months         12
# 491     activist         12
# 492         race         12
# 493    dedicated         11
# 494         tell         11
# 495         paid         11
# 496         half         11
# 497       taking         11
# 498       summer         11
# 499      january         11
#
# [500 rows x 2 columns]
# ============================================================

# %%
#campaigns with the word democrat
top_N = 500
txt = df[df['tag']=='dem']['summary'].str.lower().str.replace(r'\|', ' ').str.cat(sep=' ')
words = nltk.tokenize.word_tokenize(txt)
word_dist = nltk.FreqDist(words)
stopwords = nltk.corpus.stopwords.words('english')
words_except_stop_dist = nltk.FreqDist(w for w in words if w not in stopwords) 
print('All frequencies, including STOPWORDS:')
print('=' * 60)
rslt = pd.DataFrame(word_dist.most_common(top_N),
                    columns=['Word', 'Frequency'])
print(rslt)
print('=' * 60)
dem_rslt = pd.DataFrame(words_except_stop_dist.most_common(top_N),
                    columns=['Word', 'Frequency']).set_index('Word')
dem_rslt['tag']='dem'
dem_rslt['wd_pct']=dem_rslt['Frequency']/1316
# matplotlib.style.use('ggplot')
dem_rslt[20:30].plot.bar(rot=0,figsize=(30,10))
# Out:
# All frequencies, including STOPWORDS:
# ============================================================
#               Word  Frequency
# 0              the       1428
# 1                ,       1228
# 2               to       1104
# 3                .       1093
# 4              and        895
# 5                i        706
# 6               of        696
# 7                a        672
# 8               in        587
# 9              ...        570
# 10             for        463
# 11              is        396
# 12              my        293
# 13              we        285
# 14             our        236
# 15            this        234
# 16               !        232
# 17       democrats        230
# 18            have        226
# 19              as        218
# 20              on        212
# 21            that        185
# 22            will        184
# 23             are        180
# 24              am        178
# 25              be        175
# 26             was        150
# 27            help        149
# 28      democratic        145
# 29            with        138
# ..             ...        ...
# 470        project          8
# 471          below          8
# 472          white          8
# 473      francisco          8
# 474     nomination          8
# 475           vice          8
# 476        october          8
# 477            big          8
# 478             dc          8
# 479         attack          8
# 480         donors          8
# 481       michigan          8
# 482        seeking          8
# 483        dollars          8
# 484         giving          8
# 485          three          8
# 486           same          8
# 487          start          8
# 488          built          8
# 489            don          8
# 490          cause          8
# 491         should          8
# 492  investigation          8
# 493          water          8
# 494       platform          8
# 495          spent          8
# 496        outside          8
# 497           paso          8
# 498      financial          8
# 499        summary          8
#
# [500 rows x 2 columns]
# ============================================================

# %%
#all words
top_N = 500
txt = df['summary'].str.lower().str.replace(r'\|', ' ').str.cat(sep=' ')
words = nltk.tokenize.word_tokenize(txt)
word_dist = nltk.FreqDist(words)
stopwords = nltk.corpus.stopwords.words('english')
words_except_stop_dist = nltk.FreqDist(w for w in words if w not in stopwords) 
print('All frequencies, including STOPWORDS:')
print('=' * 60)
rslt = pd.DataFrame(word_dist.most_common(top_N),
                    columns=['Word', 'Frequency'])
print(rslt)
print('=' * 60)
rslt = pd.DataFrame(words_except_stop_dist.most_common(top_N),
                    columns=['Word', 'Frequency']).set_index('Word')
matplotlib.style.use('ggplot')
rslt[20:30].plot.bar(rot=0,figsize=(30,10))
# Out:
# All frequencies, including STOPWORDS:
# ============================================================
#            Word  Frequency
# 0           the       3333
# 1             ,       2911
# 2             .       2664
# 3            to       2615
# 4           and       2085
# 5             a       1711
# 6             i       1697
# 7            of       1616
# 8            in       1399
# 9           ...       1374
# 10          for       1102
# 11           is        964
# 12           my        706
# 13           we        646
# 14         this        546
# 15            !        540
# 16           on        519
# 17          our        499
# 18         that        496
# 19         have        491
# 20           as        467
# 21          are        458
# 22           am        412
# 23           be        409
# 24         will        406
# 25          was        376
# 26         with        370
# 27          you        360
# 28           it        335
# 29           's        323
# ..          ...        ...
# 470           '         20
# 471         car         20
# 472       white         20
# 473        stop         20
# 474  fundraiser         20
# 475    business         20
# 476     dollars         20
# 477        york         20
# 478     justice         20
# 479    possible         19
# 480        hope         19
# 481      events         19
# 482      worked         19
# 483     however         19
# 484       month         19
# 485         say         19
# 486      create         19
# 487          th         19
# 488  immigrants         19
# 489    platform         19
# 490     website         19
# 491        blue         19
# 492   supporter         19
# 493        kids         19
# 494        held         19
# 495       below         19
# 496        wife         19
# 497        four         19
# 498     decided         18
# 499         god         18
#
# [500 rows x 2 columns]
# ============================================================

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 500 entries, , to race
# Data columns (total 1 columns):
# Frequency    500 non-null int64
# dtypes: int64(1)
# memory usage: 7.8+ KB

# %%
words_df=rep_rslt.append(dem_rslt)
words_df=words_df.reset_index()

# %%
rslt=rslt.reset_index()

# %%
rslt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
# Word         500 non-null object
# Frequency    500 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 7.9+ KB

# %%
ser_df=rslt
ser_df=ser_df.rename(columns={'Frequency':'total'})
ser_df=ser_df.drop(columns='index')
# Out:
#               Word  total
# 0              the   1428
# 1                ,   1228
# 2               to   1104
# 3                .   1093
# 4              and    895
# 5                i    706
# 6               of    696
# 7                a    672
# 8               in    587
# 9              ...    570
# 10             for    463
# 11              is    396
# 12              my    293
# 13              we    285
# 14             our    236
# 15            this    234
# 16               !    232
# 17       democrats    230
# 18            have    226
# 19              as    218
# 20              on    212
# 21            that    185
# 22            will    184
# 23             are    180
# 24              am    178
# 25              be    175
# 26             was    150
# 27            help    149
# 28      democratic    145
# 29            with    138
# ..             ...    ...
# 470        project      8
# 471          below      8
# 472          white      8
# 473      francisco      8
# 474     nomination      8
# 475           vice      8
# 476        october      8
# 477            big      8
# 478             dc      8
# 479         attack      8
# 480         donors      8
# 481       michigan      8
# 482        seeking      8
# 483        dollars      8
# 484         giving      8
# 485          three      8
# 486           same      8
# 487          start      8
# 488          built      8
# 489            don      8
# 490          cause      8
# 491         should      8
# 492  investigation      8
# 493          water      8
# 494       platform      8
# 495          spent      8
# 496        outside      8
# 497           paso      8
# 498      financial      8
# 499        summary      8
#
# [500 rows x 2 columns]

# %%
words_df=words_df.merge(ser_df,left_on='Word',right_on='Word',how='left')
words_df.head()
# Out:
#          Word  Frequency  tag    wd_pct   total
# 0           ,       1683  rep  0.659741  1228.0
# 1           .       1571  rep  0.615837  1093.0
# 2         ...        804  rep  0.315171   570.0
# 3           !        308  rep  0.120737   232.0
# 4  republican        273  rep  0.107017     NaN

# %%
ser_df[ser_df['Word']==',']
# Out:
#          Word  total
# 137  democrat     78

# %%
rslt[rslt['Word']==',']
# Out:
#    index Word  Frequency
# 1      1    ,       1228

# %%
words_df[words_df['Word']=='democrat']
# Out:
#          Word  Frequency  tag    wd_pct  total
# 57   democrat         49  rep  0.019208   78.0
# 520  democrat         78  dem  0.059271   78.0

# %%
ser=words_df.total

# %%
words_df['word_bin']=pd.qcut(ser, q=4,labels=['1','2','3','4'])

sns.catplot(kind='bar',x='Frequency',y='Word',hue='tag',row='word_bin',data=words_df,height=20,aspect=2)

# %%
#making individual bins because 
words_df_3=words_df[words_df['word_bin']=='3']
words_df_1=words_df[words_df['word_bin']=='1']
words_df_2=words_df[words_df['word_bin']=='2']
words_df_4=words_df[words_df['word_bin']=='4']

# %%
words_df.head(3)
# Out:
#   Word  Frequency  tag    wd_pct word_bin
# 0    ,       1683  rep  0.659741        4
# 1    .       1571  rep  0.615837        4
# 2  ...        804  rep  0.315171        4

# %%
words_df_3.tag.unique()
# Out:
# array(['rep', 'dem'], dtype=object)

# %%
words_df_3.Word.unique()
# Out:
# array(['republicans', 'years', '``', "''", 'campaign', "'m", 'need',
#        'political', 'time', 'president', 'get', 'want', 'family', 'would',
#        'us', '?', 'one', 'america', 'county', 'school', 'democrat',
#        'elected'], dtype=object)

# %%
sum(words_df_3.Word.isin(['$', '--','-', '?',"'m"])==False)
# Out:
# 43

# %%
words_df[words_df['Word']=='republican']
# Out:
#          Word  Frequency  tag    wd_pct  total word_bin
# 4  republican        273  rep  0.107017  275.0        4

# %%
# Out:
#          Word  Frequency
# 6  republican        275

# %%
sns.catplot(y="Word", x="wd_pct", hue="tag", kind="bar", 
            data=words_df_3[words_df_3.Word.isin(['$', '--','-', '?',"'m",'``',"''",])==False], 
            height=7, aspect=11.7/8.27,palette='husl')

# %%
words_df_4.Word.unique()
# Out:
# array([',', '.', '...', '!', 'republican', "'s", '’', ':', 'help', '(',
#        ')', 'trump', 'people', 'money', 'support', 'state', 'party',
#        'name', 'national', 'democratic', 'democrats', 'convention'],
#       dtype=object)

# %%
sns.catplot(y="Word", x="wd_pct", hue="tag", kind="bar", 
            data=words_df_4[words_df_4.Word.isin([',', '.',"'s", '’', ':','(',')',"'m","''",'``'])==False], 
            height=7, aspect=11.7/8.27,palette='husl')

# %%
ser
