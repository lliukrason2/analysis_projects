# %%
import pandas as pd
import requests
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import re
from datetime import datetime, timedelta
import time
import seaborn as sns
sns.set(style='whitegrid',palette='husl')
matplotlib.rcParams['pdf.fonttype'] = 42

# %matplotlib inline

# %%
df=pd.read_csv('tabula-psychiatry_residency.csv',thousands=',')

# %%
df.columns = df.columns.str.replace("ERAS", "")

# %%
df.columns=df.columns.str.replace(r"\.1", "_applications_per_program")

# %%
df=df.rename(columns={'Unnamed: 0':'race'})

# %%
df.columns=df.columns.str.replace(" ",'')

# %%
df[df.columns[1:]]=df[df.columns[1:]].apply(pd.to_numeric)

# %%
#make a total row
df.loc['Total',:]= df.sum(axis=0)

# %%
df['pct_14']=df['2014']/(df['2014']['Total'])*100

# %%
df['pct_15']=df['2015']/(df['2015']['Total'])*100
df['pct_16']=df['2016']/(df['2016']['Total'])*100
df['pct_17']=df['2017']/(df['2017']['Total'])*100
df['pct_18']=df['2018']/(df['2018']['Total'])*100

# %%
df['race']['Total']='Total'
# Out:
# /Users/lilyliu-krason/.pyenv/versions/3.7.1/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df[['race','pct_14','pct_15','pct_16','pct_17','pct_18']][:-1]
# Out:
#                                          race     pct_14     pct_15  \
# 0            American Indian or Alaska Native   0.467687   0.678253
# 1                                       Asian  36.670918  36.116999
# 2                   Black or African American  11.883503  11.403137
# 3     Hispanic, Latino, or of Spanish\rOrigin   6.653912   7.248834
# 4  Native Hawaiian or Other Pacific\rIslander   0.106293   0.084782
# 5                                       White  31.122449  33.234421
# 6                        Other Race/Ethnicity   4.761905   5.150487
# 7                      Unknown Race/Ethnicity   8.333333   6.083086
#
#       pct_16     pct_17     pct_18
# 0   0.606061   0.674060   0.626263
# 1  34.025974  34.181344  33.131313
# 2  10.476190  11.415525  11.212121
# 3   8.484848   8.066971   8.828283
# 4   0.064935   0.152207   0.202020
# 5  33.614719  34.485758  35.393939
# 6   4.675325   3.718200   4.383838
# 7   8.051948   7.305936   6.222222

# %%
sns.catplot(kind='bar',row='race',data=df[['race','pct_14','pct_15','pct_16','pct_17','pct_18']][:-1],height=20,aspect=2)

# %%
df[['race','pct_14','pct_15','pct_16','pct_17','pct_18']][:-1].plot(kind='barh',x='race')

# %%
# Out:
#                                          race    2014    2015    2016    2017  \
# 0            American Indian or Alaska Native    22.0    32.0    28.0    31.0
# 1                                       Asian  1725.0  1704.0  1572.0  1572.0
# 2                   Black or African American   559.0   538.0   484.0   525.0
# 3     Hispanic, Latino, or of Spanish\rOrigin   313.0   342.0   392.0   371.0
# 4  Native Hawaiian or Other Pacific\rIslander     5.0     4.0     3.0     7.0
# 5                                       White  1464.0  1568.0  1553.0  1586.0
# 6                        Other Race/Ethnicity   224.0   243.0   216.0   171.0
# 7                      Unknown Race/Ethnicity   392.0   287.0   372.0   336.0
#
#      2018  2014_applications_per_program  2015_applications_per_program  \
# 0    31.0                            3.4                            4.5
# 1  1640.0                          317.6                          358.9
# 2   555.0                           65.4                           65.8
# 3   437.0                           40.7                           50.3
# 4    10.0                            1.3                            1.1
# 5  1752.0                          199.1                          236.7
# 6   217.0                           40.8                           43.3
# 7   308.0                           60.7                           49.5
#
#    2016_applications_per_program  2017_applications_per_program  \
# 0                            5.8                            7.5
# 1                          369.2                          370.7
# 2                           66.8                           80.0
# 3                           63.0                           67.3
# 4                            1.2                            2.0
# 5                          268.2                          311.7
# 6                           50.5                           34.9
# 7                            0.0                            0.0
#
#    2018_applications_per_program     pct_14     pct_15     pct_16     pct_17  \
# 0                            5.2   0.467687   0.678253   0.606061   0.674060
# 1                          344.5  36.670918  36.116999  34.025974  34.181344
# 2                           69.6  11.883503  11.403137  10.476190  11.415525
# 3                           76.8   6.653912   7.248834   8.484848   8.066971
# 4                            2.5   0.106293   0.084782   0.064935   0.152207
# 5                          313.2  31.122449  33.234421  33.614719  34.485758
# 6                           40.1   4.761905   5.150487   4.675325   3.718200
# 7                            0.0   8.333333   6.083086   8.051948   7.305936
#
#       pct_18
# 0   0.626263
# 1  33.131313
# 2  11.212121
# 3   8.828283
# 4   0.202020
# 5  35.393939
# 6   4.383838
# 7   6.222222

# %%
#pct columns
#plot
# Out:
#                                          race  2014  2015  2016  2017  2018  \
# 0            American Indian or Alaska Native    22    32    28    31    31
# 1                                       Asian  1725  1704  1572  1572  1640
# 2                   Black or African American   559   538   484   525   555
# 3     Hispanic, Latino, or of Spanish\rOrigin   313   342   392   371   437
# 4  Native Hawaiian or Other Pacific\rIslander     5     4     3     7    10
#
#    2014_applications_per_program  2015_applications_per_program  \
# 0                            3.4                            4.5
# 1                          317.6                          358.9
# 2                           65.4                           65.8
# 3                           40.7                           50.3
# 4                            1.3                            1.1
#
#    2016_applications_per_program  2017_applications_per_program  \
# 0                            5.8                            7.5
# 1                          369.2                          370.7
# 2                           66.8                           80.0
# 3                           63.0                           67.3
# 4                            1.2                            2.0
#
#    2018_applications_per_program
# 0                            5.2
# 1                          344.5
# 2                           69.6
# 3                           76.8
# 4                            2.5
